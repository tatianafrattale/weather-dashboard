# %%
#Import dependencies 
import pandas as pd
import numpy as np
import requests
import json

# %%
# List of cities for API calls 
cities_list = ["Montgomery", "Juneau", "Phoenix", "Odessa", "Sacramento", "Denver", "Hartford", "Dover", "Tallahassee", "Atlanta", "Honolulu", "Boise",
          "Springfield", "Indianapolis", "Allen", "Topeka", "Frankfort", "Chesapeake", "Augusta", "Annapolis", "Boston", "Lansing", "Passaic",
          "Jackson", "Roanoke", "Helena", "Lincoln", "Lynchburg", "Concord", "Trenton", "Albuquerque", "Albany", "Raleigh", "Bismarck, Columbus",
          "Auburn", "Salem", "Harrisburg", "Providence", "Columbia", "Pierre", "Nashville", "Austin", "Provo", "Montpelier", "Richmond", "Olympia",
          "Charleston", "Madison, Cheyenne", "Mobile", "Huntsville", "Tucson", "Mesa", "Scottsdale", "Fayetteville", "Jonesboro", "Norfolk",
          "Bakersfield", "Stockton", "Greeley, Westminster", "Aurora", "Loveland", "Stamford", "Norwalk", "Wilmington", "Jacksonville",
          "Miami", "Tampa", "Orlando", "Hollywood", "Lawrence", "Flint", "Troy", "Wyoming", "Duluth", "Plymouth", "Omaha", "Henderson", "Nashua",
          "Clifton", "Elizabeth", "Buffalo", "Rochester", "Yonkers", "Schenectady", "Durham", "Charlotte", "Greensboro", "Asheville", "Gastonia",
          "Akron", "Parma", "Tulsa", "Edmond", "Salem", "Beaverton", "Scranton", "Chattanooga", "Houston", "Dallas", "Arlington", "Plano", "Mesquite",
          "Brownsville", "Pasadena", "Waco", "Carrollton", "Milwaukee", "Tyler", "Murfreesboro", "Pawtucket", "Erie", "Beaverton", "Canton", 
          "Lawton", "Cleveland", "Cincinnati", "Danbury", "Camden", "Newark", "Manchester", "Sparks", "Missoula", "Billings", "Independence", 
          "Gulfport", "Minneapolis", "Southfield", "Kalamazoo", "Westland", "Dearborn", "Somerville", "Newton", "Worcester", "Cambridge", "Lafayette",
          "Kenner", "Shreveport", "Brockton", "Quincy", "Olathe", "Wichita", "Waterloo", "Davenport", "Muncie", "Fishers", "Gary", "Hammond","Bloomington",
          "Palatine", "Joliet", "Rockford", "Chicago", "Peoria", "Elgin", "Roswell", "Macon", "Savannah", "Lauderhill", "Melbourne", "Largo", "Clearwater",
          "Miramar", "Hialeah", "Waterbury", "Longmont", "Boulder", "Centennial", "Arvada", "Pueblo", "Thornton", "Lakewood", "Napa", "Tracy", "Alhambra",
          "Temecula", "Antioch", "Burbank", "Murrieta", "Fairfield", "Carlsbad", "Inglewood", "Downey", "Victorville", "Vallejo", "Roseville", "Visalia",
          "Sunnyvale", "Escondido", "Hayward", "Torrance", "Pomona", "Salinas", "Corona", "Glendale", "Irvine", "Oceanside", "Fontana", "Oxnard", "Modesto",
          "Fremont", "Anaheim", "Oakland", "Fresno", "Springdale", "Avondale", "Yuma", "Surprise", "Tempe", "Gilbert", "Gainesville", "Plantation"]

# %%
# API url template
#api.openweathermap.org/data/2.5/weather?q=atlanta&appid=a6501ad09aae11365e9abba37620e112
weather_json= []
url = "https://api.openweathermap.org/data/2.5/weather?q="
api_key = "&units=imperial&appid=a6501ad09aae11365e9abba37620e112"

#Iterate through cities list for API Calls
for city in cities_list: 
    
    api_url = url +city+ api_key
    weather_data = requests.get(api_url).json()
    
    if "name"  in weather_data: 
        weather_json.append(weather_data)


# Check weather data
weather_json
# Out:
# [{'coord': {'lon': -77.1997, 'lat': 39.1501},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 60.87,
#    'feels_like': 60.22,
#    'temp_min': 55.62,
#    'temp_max': 65.84,
#    'pressure': 1016,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1632958407,
#   'sys': {'type': 2,
#    'id': 2001892,
#    'country': 'US',
#    'sunrise': 1632913383,
#    'sunset': 1632956092},
#   'timezone': -14400,
#   'id': 4362716,
#   'name': 'Montgomery',
#   'cod': 200},
#  {'coord': {'lon': -134.4197, 'lat': 58.3019},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 43.79,
#    'feels_like': 42.21,
#    'temp_min': 43.11,
#    'temp_max': 44.65,
#    'pressure': 999,
#    'humidity': 91},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 50},
#   'rain': {'1h': 1.16},
#   'clouds': {'all': 90},
#   'dt': 1632958504,
#   'sys': {'type': 2,
#    'id': 2012984,
#    'country': 'US',
#    'sunrise': 1632927511,
#    'sunset': 1632969423},
#   'timezone': -28800,
#   'id': 5554072,
#   'name': 'Juneau',
#   'cod': 200},
#  {'coord': {'lon': -112.074, 'lat': 33.4484},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 84.87,
#    'feels_like': 84,
#    'temp_min': 81.77,
#    'temp_max': 87.84,
#    'pressure': 1007,
#    'humidity': 39},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 324, 'gust': 8.01},
#   'clouds': {'all': 75},
#   'dt': 1632957809,
#   'sys': {'type': 2,
#    'id': 2008537,
#    'country': 'US',
#    'sunrise': 1632921680,
#    'sunset': 1632964531},
#   'timezone': -25200,
#   'id': 5308655,
#   'name': 'Phoenix',
#   'cod': 200},
#  {'coord': {'lon': 30.7326, 'lat': 46.4775},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 53.53,
#    'feels_like': 52.16,
#    'temp_min': 52.92,
#    'temp_max': 53.53,
#    'pressure': 1028,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 8.95, 'deg': 50},
#   'clouds': {'all': 0},
#   'dt': 1632958504,
#   'sys': {'type': 1,
#    'id': 8915,
#    'country': 'UA',
#    'sunrise': 1632974049,
#    'sunset': 1633016390},
#   'timezone': 10800,
#   'id': 698740,
#   'name': 'Odesa',
#   'cod': 200},
#  {'coord': {'lon': -121.3177, 'lat': 38.4666},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 82.9,
#    'feels_like': 80.49,
#    'temp_min': 78.85,
#    'temp_max': 86.29,
#    'pressure': 1013,
#    'humidity': 20},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 286, 'gust': 4},
#   'clouds': {'all': 1},
#   'dt': 1632958479,
#   'sys': {'type': 2,
#    'id': 2002655,
#    'country': 'US',
#    'sunrise': 1632923968,
#    'sunset': 1632966679},
#   'timezone': -25200,
#   'id': 5389519,
#   'name': 'Sacramento',
#   'cod': 200},
#  {'coord': {'lon': -104.9847, 'lat': 39.7392},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 55.51,
#    'feels_like': 54.34,
#    'temp_min': 46.83,
#    'temp_max': 64.06,
#    'pressure': 1014,
#    'humidity': 76},
#   'visibility': 3278,
#   'wind': {'speed': 1.99, 'deg': 22, 'gust': 3},
#   'clouds': {'all': 94},
#   'dt': 1632957983,
#   'sys': {'type': 2,
#    'id': 2004334,
#    'country': 'US',
#    'sunrise': 1632920064,
#    'sunset': 1632962745},
#   'timezone': -21600,
#   'id': 5419384,
#   'name': 'Denver',
#   'cod': 200},
#  {'coord': {'lon': -72.7662, 'lat': 41.7668},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 56.66,
#    'feels_like': 55.6,
#    'temp_min': 53.28,
#    'temp_max': 59.95,
#    'pressure': 1014,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 3.51, 'deg': 314, 'gust': 7.54},
#   'clouds': {'all': 60},
#   'dt': 1632958211,
#   'sys': {'type': 2,
#    'id': 2007105,
#    'country': 'US',
#    'sunrise': 1632912356,
#    'sunset': 1632954991},
#   'timezone': -14400,
#   'id': 4835806,
#   'name': 'Hartford',
#   'cod': 200},
#  {'coord': {'lon': -75.5244, 'lat': 39.1582},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 60.17,
#    'feels_like': 59.18,
#    'temp_min': 55.09,
#    'temp_max': 64.94,
#    'pressure': 1016,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 300},
#   'clouds': {'all': 1},
#   'dt': 1632958475,
#   'sys': {'type': 1,
#    'id': 3847,
#    'country': 'US',
#    'sunrise': 1632912981,
#    'sunset': 1632955690},
#   'timezone': -14400,
#   'id': 4142290,
#   'name': 'Dover',
#   'cod': 200},
#  {'coord': {'lon': -84.2807, 'lat': 30.4383},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 78.24,
#    'feels_like': 79.43,
#    'temp_min': 75.67,
#    'temp_max': 80.64,
#    'pressure': 1015,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 4.21, 'deg': 211, 'gust': 11.5},
#   'clouds': {'all': 87},
#   'dt': 1632958437,
#   'sys': {'type': 2,
#    'id': 2006015,
#    'country': 'US',
#    'sunrise': 1632914969,
#    'sunset': 1632957904},
#   'timezone': -14400,
#   'id': 4174715,
#   'name': 'Tallahassee',
#   'cod': 200},
#  {'coord': {'lon': -84.388, 'lat': 33.749},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 77.23,
#    'feels_like': 77.49,
#    'temp_min': 69.93,
#    'temp_max': 81.03,
#    'pressure': 1016,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 311, 'gust': 5.01},
#   'clouds': {'all': 1},
#   'dt': 1632958051,
#   'sys': {'type': 2,
#    'id': 2006620,
#    'country': 'US',
#    'sunrise': 1632915036,
#    'sunset': 1632957888},
#   'timezone': -14400,
#   'id': 4180439,
#   'name': 'Atlanta',
#   'cod': 200},
#  {'coord': {'lon': -157.8583, 'lat': 21.3069},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 84.16,
#    'feels_like': 86.76,
#    'temp_min': 81.64,
#    'temp_max': 84.88,
#    'pressure': 1014,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 60},
#   'clouds': {'all': 75},
#   'dt': 1632958100,
#   'sys': {'type': 2,
#    'id': 2010198,
#    'country': 'US',
#    'sunrise': 1632932526,
#    'sunset': 1632975656},
#   'timezone': -36000,
#   'id': 5856195,
#   'name': 'Honolulu',
#   'cod': 200},
#  {'coord': {'lon': -116.2035, 'lat': 43.6135},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 63.5,
#    'feels_like': 61.11,
#    'temp_min': 59.81,
#    'temp_max': 66.49,
#    'pressure': 1021,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 13.8, 'deg': 320},
#   'clouds': {'all': 1},
#   'dt': 1632958506,
#   'sys': {'type': 1,
#    'id': 3479,
#    'country': 'US',
#    'sunrise': 1632922818,
#    'sunset': 1632965374},
#   'timezone': -21600,
#   'id': 5586437,
#   'name': 'Boise',
#   'cod': 200},
#  {'coord': {'lon': -93.2982, 'lat': 37.2153},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.57,
#    'feels_like': 79.09,
#    'temp_min': 74.39,
#    'temp_max': 80.46,
#    'pressure': 1013,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 5.99, 'deg': 96, 'gust': 11.99},
#   'clouds': {'all': 1},
#   'dt': 1632958214,
#   'sys': {'type': 2,
#    'id': 2016620,
#    'country': 'US',
#    'sunrise': 1632917222,
#    'sunset': 1632959979},
#   'timezone': -18000,
#   'id': 4409896,
#   'name': 'Springfield',
#   'cod': 200},
#  {'coord': {'lon': -86.158, 'lat': 39.7684},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 73.04,
#    'feels_like': 73.44,
#    'temp_min': 68.49,
#    'temp_max': 76.78,
#    'pressure': 1017,
#    'humidity': 72,
#    'sea_level': 1017,
#    'grnd_level': 992},
#   'visibility': 10000,
#   'wind': {'speed': 5.17, 'deg': 78, 'gust': 8.59},
#   'clouds': {'all': 4},
#   'dt': 1632958385,
#   'sys': {'type': 2,
#    'id': 2037844,
#    'country': 'US',
#    'sunrise': 1632915543,
#    'sunset': 1632958231},
#   'timezone': -14400,
#   'id': 4259418,
#   'name': 'Indianapolis',
#   'cod': 200},
#  {'coord': {'lon': -85.0144, 'lat': 41.0706},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 69.94,
#    'feels_like': 68.79,
#    'temp_min': 64.8,
#    'temp_max': 73.51,
#    'pressure': 1019,
#    'humidity': 46},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 20},
#   'clouds': {'all': 20},
#   'dt': 1632958309,
#   'sys': {'type': 1,
#    'id': 4161,
#    'country': 'US',
#    'sunrise': 1632915288,
#    'sunset': 1632957937},
#   'timezone': -14400,
#   'id': 4917555,
#   'name': 'Allen',
#   'cod': 200},
#  {'coord': {'lon': -95.678, 'lat': 39.0483},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.53,
#    'feels_like': 79.52,
#    'temp_min': 74.68,
#    'temp_max': 80.38,
#    'pressure': 1012,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 10.36, 'deg': 110},
#   'clouds': {'all': 1},
#   'dt': 1632958209,
#   'sys': {'type': 2,
#    'id': 2039861,
#    'country': 'US',
#    'sunrise': 1632917819,
#    'sunset': 1632960523},
#   'timezone': -18000,
#   'id': 4280539,
#   'name': 'Topeka',
#   'cod': 200},
#  {'coord': {'lon': 28.4833, 'lat': -27.2667},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 57,
#    'feels_like': 56.26,
#    'temp_min': 57,
#    'temp_max': 57,
#    'pressure': 1020,
#    'humidity': 82,
#    'sea_level': 1020,
#    'grnd_level': 854},
#   'visibility': 10000,
#   'wind': {'speed': 13.38, 'deg': 73, 'gust': 27.36},
#   'rain': {'1h': 0.18},
#   'clouds': {'all': 100},
#   'dt': 1632958508,
#   'sys': {'country': 'ZA', 'sunrise': 1632973582, 'sunset': 1633017936},
#   'timezone': 7200,
#   'id': 1003764,
#   'name': 'Frankfort',
#   'cod': 200},
#  {'coord': {'lon': -76.2749, 'lat': 36.819},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 66.49,
#    'feels_like': 65.93,
#    'temp_min': 62.31,
#    'temp_max': 69.78,
#    'pressure': 1016,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 57, 'gust': 4},
#   'clouds': {'all': 1},
#   'dt': 1632958508,
#   'sys': {'type': 2,
#    'id': 2040363,
#    'country': 'US',
#    'sunrise': 1632913128,
#    'sunset': 1632955903},
#   'timezone': -14400,
#   'id': 4752186,
#   'name': 'Chesapeake',
#   'cod': 200},
#  {'coord': {'lon': 10.8833, 'lat': 48.3667},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 49.75,
#    'feels_like': 46,
#    'temp_min': 45.32,
#    'temp_max': 53.26,
#    'pressure': 1027,
#    'humidity': 90},
#   'visibility': 10000,
#   'wind': {'speed': 9.22, 'deg': 240},
#   'clouds': {'all': 90},
#   'dt': 1632958509,
#   'sys': {'type': 1,
#    'id': 1308,
#    'country': 'DE',
#    'sunrise': 1632978856,
#    'sunset': 1633021109},
#   'timezone': 7200,
#   'id': 2954172,
#   'name': 'Augsburg',
#   'cod': 200},
#  {'coord': {'lon': -76.4922, 'lat': 38.9785},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 62.17,
#    'feels_like': 61.47,
#    'temp_min': 56.52,
#    'temp_max': 67.87,
#    'pressure': 1017,
#    'humidity': 72},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1632958509,
#   'sys': {'type': 1,
#    'id': 5056,
#    'country': 'US',
#    'sunrise': 1632913210,
#    'sunset': 1632955925},
#   'timezone': -14400,
#   'id': 4347242,
#   'name': 'Annapolis',
#   'cod': 200},
#  {'coord': {'lon': -71.0598, 'lat': 42.3584},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 57.06,
#    'feels_like': 55.76,
#    'temp_min': 52.95,
#    'temp_max': 60.13,
#    'pressure': 1015,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 41, 'gust': 11.99},
#   'clouds': {'all': 51},
#   'dt': 1632958095,
#   'sys': {'type': 2,
#    'id': 2013408,
#    'country': 'US',
#    'sunrise': 1632911956,
#    'sunset': 1632954573},
#   'timezone': -14400,
#   'id': 4930956,
#   'name': 'Boston',
#   'cod': 200},
#  {'coord': {'lon': -84.5555, 'lat': 42.7325},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 64.98,
#    'feels_like': 64.42,
#    'temp_min': 59.22,
#    'temp_max': 68.38,
#    'pressure': 1019,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 50},
#   'clouds': {'all': 1},
#   'dt': 1632958172,
#   'sys': {'type': 1,
#    'id': 4665,
#    'country': 'US',
#    'sunrise': 1632915203,
#    'sunset': 1632957802},
#   'timezone': -14400,
#   'id': 4998830,
#   'name': 'Lansing',
#   'cod': 200},
#  {'coord': {'lon': -74.3657, 'lat': 41.0668},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 58.05,
#    'feels_like': 56.93,
#    'temp_min': 52.38,
#    'temp_max': 63.64,
#    'pressure': 1016,
#    'humidity': 72,
#    'sea_level': 1016,
#    'grnd_level': 980},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 325, 'gust': 13.22},
#   'clouds': {'all': 22},
#   'dt': 1632958510,
#   'sys': {'type': 2,
#    'id': 2002024,
#    'country': 'US',
#    'sunrise': 1632912730,
#    'sunset': 1632955385},
#   'timezone': -14400,
#   'id': 5102445,
#   'name': 'Passaic',
#   'cod': 200},
#  {'coord': {'lon': -122.8345, 'lat': 42.4165},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 70.99,
#    'feels_like': 69.33,
#    'temp_min': 67.14,
#    'temp_max': 73.15,
#    'pressure': 1019,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1632958510,
#   'sys': {'type': 1,
#    'id': 4869,
#    'country': 'US',
#    'sunrise': 1632924392,
#    'sunset': 1632966983},
#   'timezone': -25200,
#   'id': 5733351,
#   'name': 'Jackson',
#   'cod': 200},
#  {'coord': {'lon': -79.9414, 'lat': 37.271},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 69.96,
#    'feels_like': 70.47,
#    'temp_min': 66.97,
#    'temp_max': 72.25,
#    'pressure': 1017,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.77, 'deg': 317, 'gust': 1.72},
#   'clouds': {'all': 15},
#   'dt': 1632958511,
#   'sys': {'type': 2,
#    'id': 2012917,
#    'country': 'US',
#    'sunrise': 1632914015,
#    'sunset': 1632956776},
#   'timezone': -14400,
#   'id': 4782167,
#   'name': 'Roanoke',
#   'cod': 200},
#  {'coord': {'lon': -112.0361, 'lat': 46.5927},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 61.5,
#    'feels_like': 58.68,
#    'temp_min': 56.23,
#    'temp_max': 65.41,
#    'pressure': 1019,
#    'humidity': 28},
#   'visibility': 10000,
#   'wind': {'speed': 11.99, 'deg': 289, 'gust': 18.99},
#   'clouds': {'all': 1},
#   'dt': 1632958511,
#   'sys': {'type': 2,
#    'id': 2003996,
#    'country': 'US',
#    'sunrise': 1632921868,
#    'sunset': 1632964324},
#   'timezone': -21600,
#   'id': 5656882,
#   'name': 'Helena',
#   'cod': 200},
#  {'coord': {'lon': -96.667, 'lat': 40.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 77.52,
#    'feels_like': 78.12,
#    'temp_min': 74.73,
#    'temp_max': 79.86,
#    'pressure': 1010,
#    'humidity': 67},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 111, 'gust': 5.99},
#   'clouds': {'all': 75},
#   'dt': 1632958413,
#   'sys': {'type': 2,
#    'id': 2007392,
#    'country': 'US',
#    'sunrise': 1632918082,
#    'sunset': 1632960735},
#   'timezone': -18000,
#   'id': 5072006,
#   'name': 'Lincoln',
#   'cod': 200},
#  {'coord': {'lon': -79.1423, 'lat': 37.4138},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 70.21,
#    'feels_like': 70.88,
#    'temp_min': 64.67,
#    'temp_max': 72.93,
#    'pressure': 1017,
#    'humidity': 84},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1632958373,
#   'sys': {'type': 1,
#    'id': 4798,
#    'country': 'US',
#    'sunrise': 1632913825,
#    'sunset': 1632956582},
#   'timezone': -14400,
#   'id': 4771075,
#   'name': 'Lynchburg',
#   'cod': 200},
#  {'coord': {'lon': -122.0311, 'lat': 37.978},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.84,
#    'feels_like': 78.84,
#    'temp_min': 65.77,
#    'temp_max': 87.71,
#    'pressure': 1012,
#    'humidity': 23},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 273, 'gust': 4},
#   'clouds': {'all': 1},
#   'dt': 1632958382,
#   'sys': {'type': 2,
#    'id': 2009331,
#    'country': 'US',
#    'sunrise': 1632924132,
#    'sunset': 1632966857},
#   'timezone': -25200,
#   'id': 5339111,
#   'name': 'Concord',
#   'cod': 200},
#  {'coord': {'lon': -74.7429, 'lat': 40.217},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 61.57,
#    'feels_like': 60.49,
#    'temp_min': 57.04,
#    'temp_max': 66.16,
#    'pressure': 1014,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 348, 'gust': 5.01},
#   'clouds': {'all': 90},
#   'dt': 1632958475,
#   'sys': {'type': 2,
#    'id': 2021152,
#    'country': 'US',
#    'sunrise': 1632912808,
#    'sunset': 1632955488},
#   'timezone': -14400,
#   'id': 5105496,
#   'name': 'Trenton',
#   'cod': 200},
#  {'coord': {'lon': -106.6511, 'lat': 35.0845},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 76.75,
#    'feels_like': 75.4,
#    'temp_min': 71.04,
#    'temp_max': 79.63,
#    'pressure': 994,
#    'humidity': 27},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 278, 'gust': 5.01},
#   'clouds': {'all': 40},
#   'dt': 1632958304,
#   'sys': {'type': 2,
#    'id': 2006845,
#    'country': 'US',
#    'sunrise': 1632920399,
#    'sunset': 1632963209},
#   'timezone': -21600,
#   'id': 5454711,
#   'name': 'Albuquerque',
#   'cod': 200},
#  {'coord': {'lon': -73.9662, 'lat': 42.6001},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 54.91,
#    'feels_like': 53.82,
#    'temp_min': 51.62,
#    'temp_max': 57.85,
#    'pressure': 1014,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 2.55, 'deg': 357, 'gust': 4.94},
#   'clouds': {'all': 97},
#   'dt': 1632958512,
#   'sys': {'type': 2,
#    'id': 19530,
#    'country': 'US',
#    'sunrise': 1632912657,
#    'sunset': 1632955266},
#   'timezone': -14400,
#   'id': 5106841,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': -78.6386, 'lat': 35.7721},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 73.76,
#    'feels_like': 74.55,
#    'temp_min': 69.17,
#    'temp_max': 77.52,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 80},
#   'clouds': {'all': 20},
#   'dt': 1632958001,
#   'sys': {'type': 2,
#    'id': 2033877,
#    'country': 'US',
#    'sunrise': 1632913682,
#    'sunset': 1632956484},
#   'timezone': -14400,
#   'id': 4487042,
#   'name': 'Raleigh',
#   'cod': 200},
#  {'coord': {'lon': -100.7837, 'lat': 46.8083},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 62.44,
#    'feels_like': 61.34,
#    'temp_min': 56.26,
#    'temp_max': 62.44,
#    'pressure': 1014,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 12.66, 'deg': 320},
#   'clouds': {'all': 1},
#   'dt': 1632958513,
#   'sys': {'type': 1,
#    'id': 3441,
#    'country': 'US',
#    'sunrise': 1632919169,
#    'sunset': 1632961624},
#   'timezone': -18000,
#   'id': 5688025,
#   'name': 'Bismarck',
#   'cod': 200},
#  {'coord': {'lon': -122.2284, 'lat': 47.3073},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 56.82,
#    'feels_like': 55.92,
#    'temp_min': 53.71,
#    'temp_max': 59.83,
#    'pressure': 1019,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 230},
#   'clouds': {'all': 90},
#   'dt': 1632958308,
#   'sys': {'type': 2,
#    'id': 2003694,
#    'country': 'US',
#    'sunrise': 1632924329,
#    'sunset': 1632966754},
#   'timezone': -25200,
#   'id': 5785965,
#   'name': 'Auburn',
#   'cod': 200},
#  {'coord': {'lon': 78.1667, 'lat': 11.65},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 73.65,
#    'feels_like': 74.95,
#    'temp_min': 73.65,
#    'temp_max': 73.65,
#    'pressure': 1009,
#    'humidity': 90,
#    'sea_level': 1009,
#    'grnd_level': 977},
#   'visibility': 10000,
#   'wind': {'speed': 2.01, 'deg': 289, 'gust': 2.15},
#   'clouds': {'all': 84},
#   'dt': 1632958268,
#   'sys': {'country': 'IN', 'sunrise': 1632962172, 'sunset': 1633005503},
#   'timezone': 19800,
#   'id': 1257629,
#   'name': 'Salem',
#   'cod': 200},
#  {'coord': {'lon': -76.8844, 'lat': 40.2737},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 60.04,
#    'feels_like': 59.18,
#    'temp_min': 55.31,
#    'temp_max': 63.37,
#    'pressure': 1016,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1632958235,
#   'sys': {'type': 2,
#    'id': 2001523,
#    'country': 'US',
#    'sunrise': 1632913323,
#    'sunset': 1632956000},
#   'timezone': -14400,
#   'id': 5192726,
#   'name': 'Harrisburg',
#   'cod': 200},
#  {'coord': {'lon': -71.4128, 'lat': 41.824},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 56.03,
#    'feels_like': 54.91,
#    'temp_min': 52.05,
#    'temp_max': 60.49,
#    'pressure': 1011,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 340},
#   'clouds': {'all': 75},
#   'dt': 1632958316,
#   'sys': {'type': 2,
#    'id': 2007908,
#    'country': 'US',
#    'sunrise': 1632912032,
#    'sunset': 1632954666},
#   'timezone': -14400,
#   'id': 5224151,
#   'name': 'Providence',
#   'cod': 200},
#  {'coord': {'lon': -81.0348, 'lat': 34.0007},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 77.94,
#    'feels_like': 78.67,
#    'temp_min': 74.16,
#    'temp_max': 82.08,
#    'pressure': 1015,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1632958514,
#   'sys': {'type': 2,
#    'id': 2037653,
#    'country': 'US',
#    'sunrise': 1632914234,
#    'sunset': 1632957081},
#   'timezone': -14400,
#   'id': 4575352,
#   'name': 'Columbia',
#   'cod': 200},
#  {'coord': {'lon': -100.351, 'lat': 44.3683},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.06,
#    'feels_like': 80.96,
#    'temp_min': 61.72,
#    'temp_max': 80.06,
#    'pressure': 1014,
#    'humidity': 51},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 139, 'gust': 10},
#   'clouds': {'all': 90},
#   'dt': 1632958515,
#   'sys': {'type': 2,
#    'id': 2001526,
#    'country': 'US',
#    'sunrise': 1632919023,
#    'sunset': 1632961562},
#   'timezone': -18000,
#   'id': 5767918,
#   'name': 'Pierre',
#   'cod': 200},
#  {'coord': {'lon': -86.7844, 'lat': 36.1659},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.64,
#    'feels_like': 79.07,
#    'temp_min': 73.33,
#    'temp_max': 82.51,
#    'pressure': 1004,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 84, 'gust': 7},
#   'clouds': {'all': 1},
#   'dt': 1632958201,
#   'sys': {'type': 2,
#    'id': 2001447,
#    'country': 'US',
#    'sunrise': 1632915643,
#    'sunset': 1632958431},
#   'timezone': -18000,
#   'id': 4644585,
#   'name': 'Nashville',
#   'cod': 200},
#  {'coord': {'lon': -97.7431, 'lat': 30.2672},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.05,
#    'feels_like': 90.3,
#    'temp_min': 82.02,
#    'temp_max': 88.57,
#    'pressure': 1008,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 90, 'gust': 5.99},
#   'clouds': {'all': 1},
#   'dt': 1632958294,
#   'sys': {'type': 2,
#    'id': 2003218,
#    'country': 'US',
#    'sunrise': 1632918199,
#    'sunset': 1632961134},
#   'timezone': -18000,
#   'id': 4671654,
#   'name': 'Austin',
#   'cod': 200},
#  {'coord': {'lon': -111.6585, 'lat': 40.2338},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 57.94,
#    'feels_like': 55.13,
#    'temp_min': 51.91,
#    'temp_max': 62.6,
#    'pressure': 1020,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 258, 'gust': 4},
#   'clouds': {'all': 75},
#   'dt': 1632958273,
#   'sys': {'type': 2,
#    'id': 2009866,
#    'country': 'US',
#    'sunrise': 1632921674,
#    'sunset': 1632964337},
#   'timezone': -21600,
#   'id': 5780026,
#   'name': 'Provo',
#   'cod': 200},
#  {'coord': {'lon': -72.5754, 'lat': 44.2601},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 49.41,
#    'feels_like': 49.41,
#    'temp_min': 46.65,
#    'temp_max': 52.36,
#    'pressure': 1016,
#    'humidity': 49},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 313, 'gust': 2.13},
#   'clouds': {'all': 99},
#   'dt': 1632958516,
#   'sys': {'type': 2,
#    'id': 2007222,
#    'country': 'US',
#    'sunrise': 1632912350,
#    'sunset': 1632954906},
#   'timezone': -14400,
#   'id': 5238685,
#   'name': 'Montpelier',
#   'cod': 200},
#  {'coord': {'lon': -77.4603, 'lat': 37.5538},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 63.61,
#    'feels_like': 63.14,
#    'temp_min': 59.29,
#    'temp_max': 67.21,
#    'pressure': 1017,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 50},
#   'clouds': {'all': 1},
#   'dt': 1632958291,
#   'sys': {'type': 2,
#    'id': 2008466,
#    'country': 'US',
#    'sunrise': 1632913423,
#    'sunset': 1632956177},
#   'timezone': -14400,
#   'id': 4781708,
#   'name': 'Richmond',
#   'cod': 200},
#  {'coord': {'lon': -122.9007, 'lat': 47.0379},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 56.48,
#    'feels_like': 55.22,
#    'temp_min': 52.57,
#    'temp_max': 59.81,
#    'pressure': 1018,
#    'humidity': 72},
#   'visibility': 10000,
#   'wind': {'speed': 10.36, 'deg': 210, 'gust': 19.57},
#   'clouds': {'all': 90},
#   'dt': 1632957998,
#   'sys': {'type': 1,
#    'id': 5197,
#    'country': 'US',
#    'sunrise': 1632924486,
#    'sunset': 1632966920},
#   'timezone': -25200,
#   'id': 5805687,
#   'name': 'Olympia',
#   'cod': 200},
#  {'coord': {'lon': -79.9309, 'lat': 32.7766},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 78.19,
#    'feels_like': 79.29,
#    'temp_min': 73.63,
#    'temp_max': 80.78,
#    'pressure': 1015,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 289, 'gust': 5.01},
#   'clouds': {'all': 1},
#   'dt': 1632958517,
#   'sys': {'type': 2,
#    'id': 2034523,
#    'country': 'US',
#    'sunrise': 1632913953,
#    'sunset': 1632956832},
#   'timezone': -14400,
#   'id': 4574324,
#   'name': 'Charleston',
#   'cod': 200},
#  {'coord': {'lon': -86.5667, 'lat': 34.7334},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 76.39,
#    'feels_like': 77.34,
#    'temp_min': 72.27,
#    'temp_max': 80.02,
#    'pressure': 1014,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1632958517,
#   'sys': {'type': 2,
#    'id': 2034804,
#    'country': 'US',
#    'sunrise': 1632915572,
#    'sunset': 1632958398},
#   'timezone': -18000,
#   'id': 4074277,
#   'name': 'Madison',
#   'cod': 200},
#  {'coord': {'lon': -88.2, 'lat': 30.7835},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 76.82,
#    'feels_like': 78.1,
#    'temp_min': 75.45,
#    'temp_max': 78.64,
#    'pressure': 1016,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 170},
#   'clouds': {'all': 75},
#   'dt': 1632958420,
#   'sys': {'type': 2,
#    'id': 2003944,
#    'country': 'US',
#    'sunrise': 1632915914,
#    'sunset': 1632958840},
#   'timezone': -18000,
#   'id': 4076607,
#   'name': 'Mobile',
#   'cod': 200},
#  {'coord': {'lon': -86.5861, 'lat': 34.7304},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 76.86,
#    'feels_like': 77.86,
#    'temp_min': 72.72,
#    'temp_max': 80.47,
#    'pressure': 1014,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1632958518,
#   'sys': {'type': 2,
#    'id': 2009569,
#    'country': 'US',
#    'sunrise': 1632915577,
#    'sunset': 1632958403},
#   'timezone': -18000,
#   'id': 4068590,
#   'name': 'Huntsville',
#   'cod': 200},
#  {'coord': {'lon': -110.9265, 'lat': 32.2217},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.24,
#    'feels_like': 82.31,
#    'temp_min': 79.66,
#    'temp_max': 88.38,
#    'pressure': 1010,
#    'humidity': 31},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 273, 'gust': 1.99},
#   'clouds': {'all': 1},
#   'dt': 1632958140,
#   'sys': {'type': 2,
#    'id': 2007774,
#    'country': 'US',
#    'sunrise': 1632921389,
#    'sunset': 1632964271},
#   'timezone': -25200,
#   'id': 5318313,
#   'name': 'Tucson',
#   'cod': 200},
#  {'coord': {'lon': -111.8226, 'lat': 33.4223},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.52,
#    'feels_like': 82.92,
#    'temp_min': 80.58,
#    'temp_max': 87.82,
#    'pressure': 1010,
#    'humidity': 34},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 205},
#   'clouds': {'all': 1},
#   'dt': 1632958181,
#   'sys': {'type': 2,
#    'id': 2011301,
#    'country': 'US',
#    'sunrise': 1632921619,
#    'sunset': 1632964471},
#   'timezone': -25200,
#   'id': 5304391,
#   'name': 'Mesa',
#   'cod': 200},
#  {'coord': {'lon': -111.899, 'lat': 33.5092},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.15,
#    'feels_like': 82.85,
#    'temp_min': 81.16,
#    'temp_max': 87.1,
#    'pressure': 1008,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 241, 'gust': 5.99},
#   'clouds': {'all': 1},
#   'dt': 1632958519,
#   'sys': {'type': 2,
#    'id': 2020223,
#    'country': 'US',
#    'sunrise': 1632921639,
#    'sunset': 1632964488},
#   'timezone': -25200,
#   'id': 5313457,
#   'name': 'Scottsdale',
#   'cod': 200},
#  {'coord': {'lon': -78.8784, 'lat': 35.0527},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 78.22,
#    'feels_like': 78.75,
#    'temp_min': 71.2,
#    'temp_max': 81.59,
#    'pressure': 1015,
#    'humidity': 64},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 40},
#   'clouds': {'all': 1},
#   'dt': 1632958232,
#   'sys': {'type': 2,
#    'id': 2031362,
#    'country': 'US',
#    'sunrise': 1632913730,
#    'sunset': 1632956551},
#   'timezone': -14400,
#   'id': 4466033,
#   'name': 'Fayetteville',
#   'cod': 200},
#  {'coord': {'lon': -90.7043, 'lat': 35.8423},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 83.55,
#    'feels_like': 85.39,
#    'temp_min': 80.67,
#    'temp_max': 85.84,
#    'pressure': 1013,
#    'humidity': 54},
#   'visibility': 10000,
#   'wind': {'speed': 5.99, 'deg': 150},
#   'clouds': {'all': 40},
#   'dt': 1632958306,
#   'sys': {'type': 2,
#    'id': 47702,
#    'country': 'US',
#    'sunrise': 1632916580,
#    'sunset': 1632959375},
#   'timezone': -18000,
#   'id': 4116834,
#   'name': 'Jonesboro',
#   'cod': 200},
#  {'coord': {'lon': -71.2495, 'lat': 42.1668},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 55.81,
#    'feels_like': 54.66,
#    'temp_min': 51.85,
#    'temp_max': 59.61,
#    'pressure': 1014,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1632958519,
#   'sys': {'type': 2,
#    'id': 2001661,
#    'country': 'US',
#    'sunrise': 1632911998,
#    'sunset': 1632954621},
#   'timezone': -14400,
#   'id': 4945455,
#   'name': 'Norfolk',
#   'cod': 200},
#  {'coord': {'lon': -119.0187, 'lat': 35.3733},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 77.58,
#    'feels_like': 76.21,
#    'temp_min': 74.03,
#    'temp_max': 84.18,
#    'pressure': 1012,
#    'humidity': 25},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 15, 'gust': 8.99},
#   'clouds': {'all': 1},
#   'dt': 1632958520,
#   'sys': {'type': 2,
#    'id': 2019205,
#    'country': 'US',
#    'sunrise': 1632923373,
#    'sunset': 1632966170},
#   'timezone': -25200,
#   'id': 5325738,
#   'name': 'Bakersfield',
#   'cod': 200},
#  {'coord': {'lon': -121.2908, 'lat': 37.9577},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 81.91,
#    'feels_like': 79.86,
#    'temp_min': 78.46,
#    'temp_max': 85.15,
#    'pressure': 1013,
#    'humidity': 21},
#   'visibility': 10000,
#   'wind': {'speed': 12.66, 'deg': 320},
#   'clouds': {'all': 1},
#   'dt': 1632958462,
#   'sys': {'type': 1,
#    'id': 5789,
#    'country': 'US',
#    'sunrise': 1632923954,
#    'sunset': 1632966679},
#   'timezone': -25200,
#   'id': 5399020,
#   'name': 'Stockton',
#   'cod': 200},
#  {'coord': {'lon': -104.7091, 'lat': 40.4233},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 55.09,
#    'feels_like': 53.26,
#    'temp_min': 47.32,
#    'temp_max': 60.58,
#    'pressure': 1016,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 8.01, 'deg': 345, 'gust': 15.99},
#   'clouds': {'all': 40},
#   'dt': 1632958490,
#   'sys': {'type': 2,
#    'id': 2009345,
#    'country': 'US',
#    'sunrise': 1632920008,
#    'sunset': 1632962668},
#   'timezone': -21600,
#   'id': 5577592,
#   'name': 'Greeley',
#   'cod': 200},
#  {'coord': {'lon': -104.8319, 'lat': 39.7294},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 54.82,
#    'feels_like': 53.49,
#    'temp_min': 46.38,
#    'temp_max': 59.86,
#    'pressure': 1013,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 51},
#   'clouds': {'all': 75},
#   'dt': 1632958271,
#   'sys': {'type': 2,
#    'id': 2006451,
#    'country': 'US',
#    'sunrise': 1632920027,
#    'sunset': 1632962708},
#   'timezone': -21600,
#   'id': 5412347,
#   'name': 'Aurora',
#   'cod': 200},
#  {'coord': {'lon': -105.075, 'lat': 40.3978},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 54.37,
#    'feels_like': 52.52,
#    'temp_min': 47.91,
#    'temp_max': 59.45,
#    'pressure': 1018,
#    'humidity': 64},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 41, 'gust': 20},
#   'clouds': {'all': 90},
#   'dt': 1632958521,
#   'sys': {'type': 2,
#    'id': 2041409,
#    'country': 'US',
#    'sunrise': 1632920095,
#    'sunset': 1632962756},
#   'timezone': -21600,
#   'id': 5579368,
#   'name': 'Loveland',
#   'cod': 200},
#  {'coord': {'lon': -73.5387, 'lat': 41.0534},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 60.24,
#    'feels_like': 59.45,
#    'temp_min': 54.48,
#    'temp_max': 67.24,
#    'pressure': 1016,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 359, 'gust': 5.01},
#   'clouds': {'all': 90},
#   'dt': 1632958425,
#   'sys': {'type': 2,
#    'id': 2020132,
#    'country': 'US',
#    'sunrise': 1632912531,
#    'sunset': 1632955187},
#   'timezone': -14400,
#   'id': 4843564,
#   'name': 'Stamford',
#   'cod': 200},
#  {'coord': {'lon': -118.0817, 'lat': 33.9022},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 74.17,
#    'feels_like': 74.07,
#    'temp_min': 67.17,
#    'temp_max': 84.96,
#    'pressure': 1011,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 295, 'gust': 11.01},
#   'clouds': {'all': 40},
#   'dt': 1632958522,
#   'sys': {'type': 2,
#    'id': 2005748,
#    'country': 'US',
#    'sunrise': 1632923128,
#    'sunset': 1632965965},
#   'timezone': -25200,
#   'id': 5377995,
#   'name': 'Norwalk',
#   'cod': 200},
#  {'coord': {'lon': -77.9447, 'lat': 34.2257},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 77.36,
#    'feels_like': 78.28,
#    'temp_min': 74.93,
#    'temp_max': 78.71,
#    'pressure': 1015,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 30},
#   'clouds': {'all': 1},
#   'dt': 1632958360,
#   'sys': {'type': 1,
#    'id': 4521,
#    'country': 'US',
#    'sunrise': 1632913495,
#    'sunset': 1632956337},
#   'timezone': -14400,
#   'id': 4499379,
#   'name': 'Wilmington',
#   'cod': 200},
#  {'coord': {'lon': -81.6556, 'lat': 30.3322},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 79.43,
#    'feels_like': 79.43,
#    'temp_min': 75.99,
#    'temp_max': 81.25,
#    'pressure': 1015,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 130, 'gust': 3},
#   'clouds': {'all': 75},
#   'dt': 1632958404,
#   'sys': {'type': 2,
#    'id': 2037733,
#    'country': 'US',
#    'sunrise': 1632914337,
#    'sunset': 1632957276},
#   'timezone': -14400,
#   'id': 4160021,
#   'name': 'Jacksonville',
#   'cod': 200},
#  {'coord': {'lon': -80.1937, 'lat': 25.7743},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 81.41,
#    'feels_like': 84.97,
#    'temp_min': 79.99,
#    'temp_max': 83.01,
#    'pressure': 1014,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 146, 'gust': 5.01},
#   'clouds': {'all': 75},
#   'dt': 1632958044,
#   'sys': {'type': 2,
#    'id': 2009372,
#    'country': 'US',
#    'sunrise': 1632913933,
#    'sunset': 1632956979},
#   'timezone': -14400,
#   'id': 4164138,
#   'name': 'Miami',
#   'cod': 200},
#  {'coord': {'lon': -82.4584, 'lat': 27.9475},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 81.82,
#    'feels_like': 85.1,
#    'temp_min': 78.15,
#    'temp_max': 84.97,
#    'pressure': 1014,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 120},
#   'clouds': {'all': 90},
#   'dt': 1632958328,
#   'sys': {'type': 2,
#    'id': 2005199,
#    'country': 'US',
#    'sunrise': 1632914502,
#    'sunset': 1632957497},
#   'timezone': -14400,
#   'id': 4174757,
#   'name': 'Tampa',
#   'cod': 200},
#  {'coord': {'lon': -81.3792, 'lat': 28.5383},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 79.65,
#    'feels_like': 79.65,
#    'temp_min': 75.74,
#    'temp_max': 82.36,
#    'pressure': 1015,
#    'humidity': 67},
#   'visibility': 10000,
#   'wind': {'speed': 9.22, 'deg': 70},
#   'clouds': {'all': 20},
#   'dt': 1632958195,
#   'sys': {'type': 1,
#    'id': 5234,
#    'country': 'US',
#    'sunrise': 1632914249,
#    'sunset': 1632957231},
#   'timezone': -14400,
#   'id': 4167147,
#   'name': 'Orlando',
#   'cod': 200},
#  {'coord': {'lon': -118.3267, 'lat': 34.0983},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 73.89,
#    'feels_like': 73.85,
#    'temp_min': 66.2,
#    'temp_max': 85.46,
#    'pressure': 1011,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 246, 'gust': 7},
#   'clouds': {'all': 1},
#   'dt': 1632958383,
#   'sys': {'type': 2,
#    'id': 2034962,
#    'country': 'US',
#    'sunrise': 1632923190,
#    'sunset': 1632966021},
#   'timezone': -25200,
#   'id': 5357527,
#   'name': 'Hollywood',
#   'cod': 200},
#  {'coord': {'lon': -95.2353, 'lat': 38.9717},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.4,
#    'feels_like': 79.38,
#    'temp_min': 75.25,
#    'temp_max': 80.73,
#    'pressure': 1013,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 110},
#   'clouds': {'all': 1},
#   'dt': 1632958382,
#   'sys': {'type': 1,
#    'id': 4784,
#    'country': 'US',
#    'sunrise': 1632917712,
#    'sunset': 1632960418},
#   'timezone': -18000,
#   'id': 4274277,
#   'name': 'Lawrence',
#   'cod': 200},
#  {'coord': {'lon': -83.6875, 'lat': 43.0125},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 62.04,
#    'feels_like': 60.82,
#    'temp_min': 56.79,
#    'temp_max': 68.07,
#    'pressure': 1020,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 10},
#   'clouds': {'all': 1},
#   'dt': 1632958261,
#   'sys': {'type': 1,
#    'id': 4123,
#    'country': 'US',
#    'sunrise': 1632914999,
#    'sunset': 1632957590},
#   'timezone': -14400,
#   'id': 4992982,
#   'name': 'Flint',
#   'cod': 200},
#  {'coord': {'lon': -83.1499, 'lat': 42.6056},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 61.99,
#    'feels_like': 61.09,
#    'temp_min': 55.89,
#    'temp_max': 68.38,
#    'pressure': 1019,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 4.56, 'deg': 49, 'gust': 7.61},
#   'clouds': {'all': 0},
#   'dt': 1632958514,
#   'sys': {'type': 2,
#    'id': 2005451,
#    'country': 'US',
#    'sunrise': 1632914863,
#    'sunset': 1632957467},
#   'timezone': -14400,
#   'id': 5012639,
#   'name': 'Troy',
#   'cod': 200},
#  {'coord': {'lon': -107.5009, 'lat': 43.0002},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 41.83,
#    'feels_like': 39.16,
#    'temp_min': 41.83,
#    'temp_max': 41.83,
#    'pressure': 1023,
#    'humidity': 96,
#    'sea_level': 1023,
#    'grnd_level': 814},
#   'visibility': 51,
#   'wind': {'speed': 4.32, 'deg': 270, 'gust': 4.72},
#   'clouds': {'all': 100},
#   'dt': 1632958524,
#   'sys': {'type': 2,
#    'id': 2004410,
#    'country': 'US',
#    'sunrise': 1632920718,
#    'sunset': 1632963298},
#   'timezone': -21600,
#   'id': 5843591,
#   'name': 'State of Wyoming',
#   'cod': 200},
#  {'coord': {'lon': -92.1066, 'lat': 46.7833},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 59.88,
#    'feels_like': 59.67,
#    'temp_min': 54.9,
#    'temp_max': 71.01,
#    'pressure': 1018,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 27, 'gust': 5.99},
#   'clouds': {'all': 90},
#   'dt': 1632958393,
#   'sys': {'type': 2,
#    'id': 2005285,
#    'country': 'US',
#    'sunrise': 1632917084,
#    'sunset': 1632959545},
#   'timezone': -18000,
#   'id': 5024719,
#   'name': 'Duluth',
#   'cod': 200},
#  {'coord': {'lon': -70.8328, 'lat': 41.8334},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 54.82,
#    'feels_like': 53.82,
#    'temp_min': 51.75,
#    'temp_max': 60.46,
#    'pressure': 1015,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1632958525,
#   'sys': {'type': 2,
#    'id': 2002008,
#    'country': 'US',
#    'sunrise': 1632911893,
#    'sunset': 1632954526},
#   'timezone': -14400,
#   'id': 4947607,
#   'name': 'Plymouth',
#   'cod': 200},
#  {'coord': {'lon': -95.9378, 'lat': 41.2586},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.13,
#    'feels_like': 78.71,
#    'temp_min': 75.25,
#    'temp_max': 80.33,
#    'pressure': 1012,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 197, 'gust': 8.99},
#   'clouds': {'all': 1},
#   'dt': 1632958416,
#   'sys': {'type': 2,
#    'id': 2003015,
#    'country': 'US',
#    'sunrise': 1632917914,
#    'sunset': 1632960553},
#   'timezone': -18000,
#   'id': 5074472,
#   'name': 'Omaha',
#   'cod': 200},
#  {'coord': {'lon': -114.9819, 'lat': 36.0397},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 82.06,
#    'feels_like': 79.7,
#    'temp_min': 79.79,
#    'temp_max': 85.17,
#    'pressure': 1013,
#    'humidity': 14},
#   'visibility': 10000,
#   'wind': {'speed': 10.36, 'deg': 30, 'gust': 16.11},
#   'clouds': {'all': 1},
#   'dt': 1632958261,
#   'sys': {'type': 2,
#    'id': 38662,
#    'country': 'US',
#    'sunrise': 1632922413,
#    'sunset': 1632965193},
#   'timezone': -25200,
#   'id': 5505411,
#   'name': 'Henderson',
#   'cod': 200},
#  {'coord': {'lon': -71.4676, 'lat': 42.7654},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 55.69,
#    'feels_like': 54.54,
#    'temp_min': 52.05,
#    'temp_max': 59.49,
#    'pressure': 1014,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 352, 'gust': 3},
#   'clouds': {'all': 90},
#   'dt': 1632958405,
#   'sys': {'type': 2,
#    'id': 2023708,
#    'country': 'US',
#    'sunrise': 1632912060,
#    'sunset': 1632954664},
#   'timezone': -14400,
#   'id': 5090046,
#   'name': 'Nashua',
#   'cod': 200},
#  {'coord': {'lon': -74.1638, 'lat': 40.8584},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.49,
#    'feels_like': 61.16,
#    'temp_min': 56.57,
#    'temp_max': 66.69,
#    'pressure': 1015,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 316, 'gust': 8.99},
#   'clouds': {'all': 90},
#   'dt': 1632958526,
#   'sys': {'type': 2,
#    'id': 2009441,
#    'country': 'US',
#    'sunrise': 1632912678,
#    'sunset': 1632955340},
#   'timezone': -14400,
#   'id': 5096699,
#   'name': 'Clifton',
#   'cod': 200},
#  {'coord': {'lon': -74.2107, 'lat': 40.664},
#   'weather': [{'id': 804,
# ...
#   'clouds': {'all': 1},
#   'dt': 1632958456,
#   'sys': {'type': 2,
#    'id': 2010997,
#    'country': 'US',
#    'sunrise': 1632923965,
#    'sunset': 1632966667},
#   'timezone': -25200,
#   'id': 5388881,
#   'name': 'Roseville',
#   'cod': 200},
#  {'coord': {'lon': -119.2921, 'lat': 36.3302},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.82,
#    'feels_like': 78.82,
#    'temp_min': 75.15,
#    'temp_max': 82.06,
#    'pressure': 1012,
#    'humidity': 31},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 140, 'gust': 7},
#   'clouds': {'all': 1},
#   'dt': 1632958355,
#   'sys': {'type': 2,
#    'id': 2033989,
#    'country': 'US',
#    'sunrise': 1632923452,
#    'sunset': 1632966223},
#   'timezone': -25200,
#   'id': 5406567,
#   'name': 'Visalia',
#   'cod': 200},
#  {'coord': {'lon': -122.0363, 'lat': 37.3688},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 77.2,
#    'feels_like': 76.12,
#    'temp_min': 65.62,
#    'temp_max': 83.28,
#    'pressure': 1013,
#    'humidity': 32},
#   'visibility': 10000,
#   'wind': {'speed': 5.99, 'deg': 269, 'gust': 11.99},
#   'clouds': {'all': 1},
#   'dt': 1632958290,
#   'sys': {'type': 2,
#    'id': 2038854,
#    'country': 'US',
#    'sunrise': 1632924125,
#    'sunset': 1632966866},
#   'timezone': -25200,
#   'id': 5400075,
#   'name': 'Sunnyvale',
#   'cod': 200},
#  {'coord': {'lon': -117.0864, 'lat': 33.1192},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 71.98,
#    'feels_like': 71.83,
#    'temp_min': 64.71,
#    'temp_max': 81.97,
#    'pressure': 1008,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 8.01, 'deg': 234},
#   'clouds': {'all': 1},
#   'dt': 1632958267,
#   'sys': {'type': 2,
#    'id': 2005618,
#    'country': 'US',
#    'sunrise': 1632922879,
#    'sunset': 1632965737},
#   'timezone': -25200,
#   'id': 5346827,
#   'name': 'Escondido',
#   'cod': 200},
#  {'coord': {'lon': -122.0808, 'lat': 37.6688},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 76.19,
#    'feels_like': 75.34,
#    'temp_min': 66.56,
#    'temp_max': 83.26,
#    'pressure': 1014,
#    'humidity': 39},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 327, 'gust': 8.01},
#   'clouds': {'all': 1},
#   'dt': 1632958556,
#   'sys': {'type': 2,
#    'id': 2002977,
#    'country': 'US',
#    'sunrise': 1632924140,
#    'sunset': 1632966873},
#   'timezone': -25200,
#   'id': 5355933,
#   'name': 'Hayward',
#   'cod': 200},
#  {'coord': {'lon': -118.3406, 'lat': 33.8359},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 72,
#    'feels_like': 72.23,
#    'temp_min': 67.19,
#    'temp_max': 82.76,
#    'pressure': 1011,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 7, 'deg': 232, 'gust': 10},
#   'clouds': {'all': 40},
#   'dt': 1632958317,
#   'sys': {'type': 2,
#    'id': 2032800,
#    'country': 'US',
#    'sunrise': 1632923190,
#    'sunset': 1632966028},
#   'timezone': -25200,
#   'id': 5403022,
#   'name': 'Torrance',
#   'cod': 200},
#  {'coord': {'lon': -117.7523, 'lat': 34.0553},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 75.97,
#    'feels_like': 75.81,
#    'temp_min': 64.49,
#    'temp_max': 85.17,
#    'pressure': 1011,
#    'humidity': 54},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 247, 'gust': 11.99},
#   'clouds': {'all': 1},
#   'dt': 1632958557,
#   'sys': {'type': 2,
#    'id': 2008971,
#    'country': 'US',
#    'sunrise': 1632923051,
#    'sunset': 1632965884},
#   'timezone': -25200,
#   'id': 5384170,
#   'name': 'Pomona',
#   'cod': 200},
#  {'coord': {'lon': -121.6555, 'lat': 36.6777},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 68.63,
#    'feels_like': 67.87,
#    'temp_min': 59.83,
#    'temp_max': 81.57,
#    'pressure': 1015,
#    'humidity': 57},
#   'visibility': 10000,
#   'wind': {'speed': 12.66, 'deg': 310},
#   'clouds': {'all': 1},
#   'dt': 1632958489,
#   'sys': {'type': 1,
#    'id': 5885,
#    'country': 'US',
#    'sunrise': 1632924024,
#    'sunset': 1632966785},
#   'timezone': -25200,
#   'id': 5391295,
#   'name': 'Salinas',
#   'cod': 200},
#  {'coord': {'lon': -117.5664, 'lat': 33.8753},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 76.71,
#    'feels_like': 76.44,
#    'temp_min': 66.49,
#    'temp_max': 87.13,
#    'pressure': 1011,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 13.8, 'deg': 270, 'gust': 24.16},
#   'clouds': {'all': 1},
#   'dt': 1632958274,
#   'sys': {'type': 1,
#    'id': 3262,
#    'country': 'US',
#    'sunrise': 1632923004,
#    'sunset': 1632965842},
#   'timezone': -25200,
#   'id': 5339631,
#   'name': 'Corona',
#   'cod': 200},
#  {'coord': {'lon': -112.186, 'lat': 33.5387},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 84.49,
#    'feels_like': 83.62,
#    'temp_min': 81.54,
#    'temp_max': 87.15,
#    'pressure': 1006,
#    'humidity': 39},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 209, 'gust': 5.99},
#   'clouds': {'all': 20},
#   'dt': 1632958470,
#   'sys': {'type': 2,
#    'id': 2033143,
#    'country': 'US',
#    'sunrise': 1632921708,
#    'sunset': 1632964556},
#   'timezone': -25200,
#   'id': 5295985,
#   'name': 'Glendale',
#   'cod': 200},
#  {'coord': {'lon': -117.8231, 'lat': 33.6695},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 74.3,
#    'feels_like': 74.62,
#    'temp_min': 67.32,
#    'temp_max': 84.63,
#    'pressure': 1011,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 210},
#   'clouds': {'all': 75},
#   'dt': 1632958558,
#   'sys': {'type': 2,
#    'id': 2009264,
#    'country': 'US',
#    'sunrise': 1632923063,
#    'sunset': 1632965906},
#   'timezone': -25200,
#   'id': 5359777,
#   'name': 'Irvine',
#   'cod': 200},
#  {'coord': {'lon': -117.3795, 'lat': 33.1959},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 73.06,
#    'feels_like': 73.17,
#    'temp_min': 66.76,
#    'temp_max': 82.69,
#    'pressure': 1011,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 311, 'gust': 10},
#   'clouds': {'all': 1},
#   'dt': 1632958374,
#   'sys': {'type': 2,
#    'id': 2009310,
#    'country': 'US',
#    'sunrise': 1632922951,
#    'sunset': 1632965806},
#   'timezone': -25200,
#   'id': 5378771,
#   'name': 'Oceanside',
#   'cod': 200},
#  {'coord': {'lon': -117.4351, 'lat': 34.0922},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 77.67,
#    'feels_like': 77.34,
#    'temp_min': 66.67,
#    'temp_max': 85.42,
#    'pressure': 1010,
#    'humidity': 47},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 260, 'gust': 13},
#   'clouds': {'all': 1},
#   'dt': 1632958558,
#   'sys': {'type': 2,
#    'id': 2002705,
#    'country': 'US',
#    'sunrise': 1632922976,
#    'sunset': 1632965808},
#   'timezone': -25200,
#   'id': 5349755,
#   'name': 'Fontana',
#   'cod': 200},
#  {'coord': {'lon': -119.177, 'lat': 34.1975},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 72.81,
#    'feels_like': 72.84,
#    'temp_min': 67.84,
#    'temp_max': 85.48,
#    'pressure': 1012,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 270},
#   'clouds': {'all': 1},
#   'dt': 1632958559,
#   'sys': {'type': 1,
#    'id': 5254,
#    'country': 'US',
#    'sunrise': 1632923395,
#    'sunset': 1632966224},
#   'timezone': -25200,
#   'id': 5380184,
#   'name': 'Oxnard',
#   'cod': 200},
#  {'coord': {'lon': -120.9969, 'lat': 37.6391},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 80.42,
#    'feels_like': 79.12,
#    'temp_min': 78.78,
#    'temp_max': 84.13,
#    'pressure': 1013,
#    'humidity': 25},
#   'visibility': 10000,
#   'wind': {'speed': 14.97, 'deg': 330},
#   'clouds': {'all': 1},
#   'dt': 1632958359,
#   'sys': {'type': 1,
#    'id': 4949,
#    'country': 'US',
#    'sunrise': 1632923879,
#    'sunset': 1632966613},
#   'timezone': -25200,
#   'id': 5373900,
#   'name': 'Modesto',
#   'cod': 200},
#  {'coord': {'lon': -121.9886, 'lat': 37.5483},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 77.18,
#    'feels_like': 76.48,
#    'temp_min': 66.81,
#    'temp_max': 83.93,
#    'pressure': 1013,
#    'humidity': 40},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 240, 'gust': 8.99},
#   'clouds': {'all': 1},
#   'dt': 1632958302,
#   'sys': {'type': 2,
#    'id': 2036492,
#    'country': 'US',
#    'sunrise': 1632924116,
#    'sunset': 1632966852},
#   'timezone': -25200,
#   'id': 5350734,
#   'name': 'Fremont',
#   'cod': 200},
#  {'coord': {'lon': -117.9145, 'lat': 33.8353},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 74.75,
#    'feels_like': 74.75,
#    'temp_min': 66.94,
#    'temp_max': 85.41,
#    'pressure': 1010,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 247, 'gust': 8.99},
#   'clouds': {'all': 40},
#   'dt': 1632958419,
#   'sys': {'type': 2,
#    'id': 2001654,
#    'country': 'US',
#    'sunrise': 1632923087,
#    'sunset': 1632965926},
#   'timezone': -25200,
#   'id': 5323810,
#   'name': 'Anaheim',
#   'cod': 200},
#  {'coord': {'lon': -83.3999, 'lat': 42.6667},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 62.2,
#    'feels_like': 61.03,
#    'temp_min': 56.14,
#    'temp_max': 68,
#    'pressure': 1020,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 20},
#   'clouds': {'all': 1},
#   'dt': 1632958177,
#   'sys': {'type': 1,
#    'id': 5424,
#    'country': 'US',
#    'sunrise': 1632914924,
#    'sunset': 1632957526},
#   'timezone': -14400,
#   'id': 5004223,
#   'name': 'Oakland',
#   'cod': 200},
#  {'coord': {'lon': -119.8343, 'lat': 36.6666},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 80.06,
#    'feels_like': 78.73,
#    'temp_min': 77.41,
#    'temp_max': 83.95,
#    'pressure': 1014,
#    'humidity': 22},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 0},
#   'clouds': {'all': 20},
#   'dt': 1632958210,
#   'sys': {'type': 2,
#    'id': 2019405,
#    'country': 'US',
#    'sunrise': 1632923586,
#    'sunset': 1632966348},
#   'timezone': -25200,
#   'id': 5350964,
#   'name': 'Fresno',
#   'cod': 200},
#  {'coord': {'lon': -94.1288, 'lat': 36.1867},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 76.91,
#    'feels_like': 77.45,
#    'temp_min': 73.96,
#    'temp_max': 78.91,
#    'pressure': 1014,
#    'humidity': 67},
#   'visibility': 10000,
#   'wind': {'speed': 6.91, 'deg': 130, 'gust': 14.97},
#   'clouds': {'all': 1},
#   'dt': 1632958560,
#   'sys': {'type': 1,
#    'id': 3318,
#    'country': 'US',
#    'sunrise': 1632917407,
#    'sunset': 1632960192},
#   'timezone': -18000,
#   'id': 4132093,
#   'name': 'Springdale',
#   'cod': 200},
#  {'coord': {'lon': -112.3496, 'lat': 33.4356},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 85.12,
#    'feels_like': 83.77,
#    'temp_min': 82.18,
#    'temp_max': 88.12,
#    'pressure': 1009,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 250},
#   'clouds': {'all': 75},
#   'dt': 1632958550,
#   'sys': {'type': 1,
#    'id': 4294,
#    'country': 'US',
#    'sunrise': 1632921746,
#    'sunset': 1632964597},
#   'timezone': -25200,
#   'id': 5552301,
#   'name': 'Avondale',
#   'cod': 200},
#  {'coord': {'lon': -114.6244, 'lat': 32.7253},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 89.6,
#    'feels_like': 85.96,
#    'temp_min': 89.02,
#    'temp_max': 90.37,
#    'pressure': 1007,
#    'humidity': 20},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 40},
#   'dt': 1632958310,
#   'sys': {'type': 1,
#    'id': 5136,
#    'country': 'US',
#    'sunrise': 1632922283,
#    'sunset': 1632965151},
#   'timezone': -25200,
#   'id': 5322053,
#   'name': 'Yuma',
#   'cod': 200},
#  {'coord': {'lon': -112.3332, 'lat': 33.6306},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 84.29,
#    'feels_like': 83.43,
#    'temp_min': 81.45,
#    'temp_max': 87.39,
#    'pressure': 1005,
#    'humidity': 39},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 214, 'gust': 5.01},
#   'clouds': {'all': 20},
#   'dt': 1632958561,
#   'sys': {'type': 2,
#    'id': 2011266,
#    'country': 'US',
#    'sunrise': 1632921745,
#    'sunset': 1632964590},
#   'timezone': -25200,
#   'id': 5316428,
#   'name': 'Surprise',
#   'cod': 200},
#  {'coord': {'lon': -111.9093, 'lat': 33.4148},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 84.54,
#    'feels_like': 83.21,
#    'temp_min': 81.43,
#    'temp_max': 87.37,
#    'pressure': 1007,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 295, 'gust': 7},
#   'clouds': {'all': 75},
#   'dt': 1632958562,
#   'sys': {'type': 2,
#    'id': 2040762,
#    'country': 'US',
#    'sunrise': 1632921640,
#    'sunset': 1632964492},
#   'timezone': -25200,
#   'id': 5317058,
#   'name': 'Tempe',
#   'cod': 200},
#  {'coord': {'lon': -111.789, 'lat': 33.3528},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 84.56,
#    'feels_like': 82.96,
#    'temp_min': 81.23,
#    'temp_max': 87.17,
#    'pressure': 1010,
#    'humidity': 34},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 315, 'gust': 5.01},
#   'clouds': {'all': 75},
#   'dt': 1632958562,
#   'sys': {'type': 2,
#    'id': 2005405,
#    'country': 'US',
#    'sunrise': 1632921610,
#    'sunset': 1632964464},
#   'timezone': -25200,
#   'id': 5295903,
#   'name': 'Gilbert',
#   'cod': 200},
#  {'coord': {'lon': -82.3248, 'lat': 29.6516},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 78.91,
#    'feels_like': 78.91,
#    'temp_min': 74.93,
#    'temp_max': 82.94,
#    'pressure': 1016,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 20},
#   'dt': 1632958194,
#   'sys': {'type': 2,
#    'id': 2007294,
#    'country': 'US',
#    'sunrise': 1632914490,
#    'sunset': 1632957445},
#   'timezone': -14400,
#   'id': 4156404,
#   'name': 'Gainesville',
#   'cod': 200},
#  {'coord': {'lon': -80.2318, 'lat': 26.1342},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 81.46,
#    'feels_like': 85.06,
#    'temp_min': 80.01,
#    'temp_max': 83.01,
#    'pressure': 1014,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 80},
#   'clouds': {'all': 20},
#   'dt': 1632958563,
#   'sys': {'type': 2,
#    'id': 2016126,
#    'country': 'US',
#    'sunrise': 1632913946,
#    'sunset': 1632956984},
#   'timezone': -14400,
#   'id': 4168782,
#   'name': 'Plantation',
#   'cod': 200}]

# %%
# Check weather data
print(weather_json)



#Check legth ofw weather data
len(weather_json)
# Out:
# [{'coord': {'lon': -77.1997, 'lat': 39.1501}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 60.87, 'feels_like': 60.22, 'temp_min': 55.62, 'temp_max': 65.84, 'pressure': 1016, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 1}, 'dt': 1632958407, 'sys': {'type': 2, 'id': 2001892, 'country': 'US', 'sunrise': 1632913383, 'sunset': 1632956092}, 'timezone': -14400, 'id': 4362716, 'name': 'Montgomery', 'cod': 200}, {'coord': {'lon': -134.4197, 'lat': 58.3019}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 43.79, 'feels_like': 42.21, 'temp_min': 43.11, 'temp_max': 44.65, 'pressure': 999, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 50}, 'rain': {'1h': 1.16}, 'clouds': {'all': 90}, 'dt': 1632958504, 'sys': {'type': 2, 'id': 2012984, 'country': 'US', 'sunrise': 1632927511, 'sunset': 1632969423}, 'timezone': -28800, 'id': 5554072, 'name': 'Juneau', 'cod': 200}, {'coord': {'lon': -112.074, 'lat': 33.4484}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 84.87, 'feels_like': 84, 'temp_min': 81.77, 'temp_max': 87.84, 'pressure': 1007, 'humidity': 39}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 324, 'gust': 8.01}, 'clouds': {'all': 75}, 'dt': 1632957809, 'sys': {'type': 2, 'id': 2008537, 'country': 'US', 'sunrise': 1632921680, 'sunset': 1632964531}, 'timezone': -25200, 'id': 5308655, 'name': 'Phoenix', 'cod': 200}, {'coord': {'lon': 30.7326, 'lat': 46.4775}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 53.53, 'feels_like': 52.16, 'temp_min': 52.92, 'temp_max': 53.53, 'pressure': 1028, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 8.95, 'deg': 50}, 'clouds': {'all': 0}, 'dt': 1632958504, 'sys': {'type': 1, 'id': 8915, 'country': 'UA', 'sunrise': 1632974049, 'sunset': 1633016390}, 'timezone': 10800, 'id': 698740, 'name': 'Odesa', 'cod': 200}, {'coord': {'lon': -121.3177, 'lat': 38.4666}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 82.9, 'feels_like': 80.49, 'temp_min': 78.85, 'temp_max': 86.29, 'pressure': 1013, 'humidity': 20}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 286, 'gust': 4}, 'clouds': {'all': 1}, 'dt': 1632958479, 'sys': {'type': 2, 'id': 2002655, 'country': 'US', 'sunrise': 1632923968, 'sunset': 1632966679}, 'timezone': -25200, 'id': 5389519, 'name': 'Sacramento', 'cod': 200}, {'coord': {'lon': -104.9847, 'lat': 39.7392}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 55.51, 'feels_like': 54.34, 'temp_min': 46.83, 'temp_max': 64.06, 'pressure': 1014, 'humidity': 76}, 'visibility': 3278, 'wind': {'speed': 1.99, 'deg': 22, 'gust': 3}, 'clouds': {'all': 94}, 'dt': 1632957983, 'sys': {'type': 2, 'id': 2004334, 'country': 'US', 'sunrise': 1632920064, 'sunset': 1632962745}, 'timezone': -21600, 'id': 5419384, 'name': 'Denver', 'cod': 200}, {'coord': {'lon': -72.7662, 'lat': 41.7668}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 56.66, 'feels_like': 55.6, 'temp_min': 53.28, 'temp_max': 59.95, 'pressure': 1014, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 3.51, 'deg': 314, 'gust': 7.54}, 'clouds': {'all': 60}, 'dt': 1632958211, 'sys': {'type': 2, 'id': 2007105, 'country': 'US', 'sunrise': 1632912356, 'sunset': 1632954991}, 'timezone': -14400, 'id': 4835806, 'name': 'Hartford', 'cod': 200}, {'coord': {'lon': -75.5244, 'lat': 39.1582}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 60.17, 'feels_like': 59.18, 'temp_mi ...
# 211

# %%
#Write out json to text file 
with open ('weather_data.txt', 'w') as convert_file:
    convert_file.write(json.dumps(weather_json))
