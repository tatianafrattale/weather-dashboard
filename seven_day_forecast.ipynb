# %%
#Import dependencies 
import pandas as pd
import numpy as np
import requests
import json
import time

# %%
# List of cities for API calls 
cities_list = ["Montgomery", "Juneau", "Phoenix", "Odessa", "Sacramento", "Denver", "Hartford", "Dover", "Tallahassee", "Atlanta", "Honolulu", "Boise",
          "Springfield", "Indianapolis", "Allen", "Topeka", "Frankfort", "Chesapeake", "Augusta", "Annapolis", "Boston", "Lansing", "Passaic",
          "Jackson", "Roanoke", "Helena", "Lincoln", "Lynchburg", "Concord", "Trenton", "Albuquerque", "Albany", "Raleigh", "Bismarck, Columbus",
          "Auburn", "Salem", "Harrisburg", "Providence", "Columbia", "Pierre", "Nashville", "Austin", "Provo", "Montpelier", "Richmond", "Olympia",
          "Charleston", "Madison, Cheyenne", "Mobile", "Huntsville", "Tucson", "Mesa", "Scottsdale", "Fayetteville", "Jonesboro", "Norfolk",
          "Bakersfield", "Stockton", "Greeley, Westminster", "Aurora", "Loveland", "Stamford", "Norwalk", "Wilmington", "Jacksonville",
          "Miami", "Tampa", "Orlando", "Hollywood", "Lawrence", "Flint", "Troy", "Wyoming", "Duluth", "Plymouth", "Omaha", "Henderson", "Nashua",
          "Clifton", "Elizabeth", "Buffalo", "Rochester", "Yonkers", "Schenectady", "Durham", "Charlotte", "Greensboro", "Asheville", "Gastonia",
          "Akron", "Parma", "Tulsa", "Edmond", "Salem", "Beaverton", "Scranton", "Chattanooga", "Houston", "Dallas", "Arlington", "Plano", "Mesquite",
          "Brownsville", "Pasadena", "Waco", "Carrollton", "Milwaukee", "Tyler", "Murfreesboro", "Pawtucket", "Erie", "Beaverton", "Canton", 
          "Lawton", "Cleveland", "Cincinnati", "Danbury", "Camden", "Newark", "Manchester", "Sparks", "Missoula", "Billings", "Independence", 
          "Gulfport", "Minneapolis", "Southfield", "Kalamazoo", "Westland", "Dearborn", "Somerville", "Newton", "Worcester", "Cambridge", "Lafayette",
          "Kenner", "Shreveport", "Brockton", "Quincy", "Olathe", "Wichita", "Waterloo", "Davenport", "Muncie", "Fishers", "Gary", "Hammond","Bloomington",
          "Palatine", "Joliet", "Rockford", "Chicago", "Peoria", "Elgin", "Roswell", "Macon", "Savannah", "Lauderhill", "Melbourne", "Largo", "Clearwater",
          "Miramar", "Hialeah", "Waterbury", "Longmont", "Boulder", "Centennial", "Arvada", "Pueblo", "Thornton", "Lakewood", "Napa", "Tracy", "Alhambra",
          "Temecula", "Antioch", "Burbank", "Murrieta", "Fairfield", "Carlsbad", "Inglewood", "Downey", "Victorville", "Vallejo", "Roseville", "Visalia",
          "Sunnyvale", "Escondido", "Hayward", "Torrance", "Pomona", "Salinas", "Corona", "Glendale", "Irvine", "Oceanside", "Fontana", "Oxnard", "Modesto",
          "Fremont", "Anaheim", "Oakland", "Fresno", "Springdale", "Avondale", "Yuma", "Surprise", "Tempe", "Gilbert", "Gainesville", "Plantation"]

# %%
# API url template
#api.openweathermap.org/data/2.5/weather?q=atlanta&appid=a6501ad09aae11365e9abba37620e112
url = "https://api.openweathermap.org/data/2.5/forecast/daily?q="
api_key = "&cnt=7&units=imperial&appid=a6501ad09aae11365e9abba37620e112"

# %%
#Iterate through cities list for API Calls
weather_json= []

for city in cities_list: 
    
    api_url = url +city+ api_key
    weather_data = requests.get(api_url).json()
    time.sleep(1)
    if "name"  not in weather_data: 
        weather_json.append(weather_data)
        

# Check weather data
weather_json
# Out:
# [{'city': {'id': 4362716,
#    'name': 'Montgomery',
#    'coord': {'lon': -77.1997, 'lat': 39.1501},
#    'country': 'US',
#    'population': 971777,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 23.4490818,
#   'cnt': 7,
#   'list': [{'dt': 1633363200,
#     'sunrise': 1633345663,
#     'sunset': 1633387614,
#     'temp': {'day': 76.6,
#      'min': 64.36,
#      'max': 78.51,
#      'night': 68.92,
#      'eve': 72.88,
#      'morn': 64.45},
#     'feels_like': {'day': 77.11, 'night': 69.78, 'eve': 73.72, 'morn': 64.87},
#     'pressure': 1014,
#     'humidity': 67,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 6.78,
#     'deg': 203,
#     'gust': 19.64,
#     'clouds': 100,
#     'pop': 0.88,
#     'rain': 9.32},
#    {'dt': 1633449600,
#     'sunrise': 1633432120,
#     'sunset': 1633473920,
#     'temp': {'day': 68.34,
#      'min': 62.35,
#      'max': 69.76,
#      'night': 65.77,
#      'eve': 68.25,
#      'morn': 62.73},
#     'feels_like': {'day': 68.97, 'night': 66.6, 'eve': 68.92, 'morn': 63.27},
#     'pressure': 1022,
#     'humidity': 87,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.76,
#     'deg': 61,
#     'gust': 15.77,
#     'clouds': 100,
#     'pop': 0.69,
#     'rain': 1.45},
#    {'dt': 1633536000,
#     'sunrise': 1633518578,
#     'sunset': 1633560226,
#     'temp': {'day': 65.26,
#      'min': 64.29,
#      'max': 65.77,
#      'night': 64.49,
#      'eve': 65.77,
#      'morn': 64.56},
#     'feels_like': {'day': 66, 'night': 65.19, 'eve': 66.47, 'morn': 65.32},
#     'pressure': 1027,
#     'humidity': 96,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.96,
#     'deg': 81,
#     'gust': 15.61,
#     'clouds': 100,
#     'pop': 0.68,
#     'rain': 1.01},
#    {'dt': 1633622400,
#     'sunrise': 1633605035,
#     'sunset': 1633646533,
#     'temp': {'day': 67.64,
#      'min': 64.04,
#      'max': 72.91,
#      'night': 65.16,
#      'eve': 72.91,
#      'morn': 64.04},
#     'feels_like': {'day': 68.29, 'night': 65.79, 'eve': 73.38, 'morn': 64.74},
#     'pressure': 1026,
#     'humidity': 89,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 5.32,
#     'deg': 144,
#     'gust': 8.28,
#     'clouds': 100,
#     'pop': 0.2,
#     'rain': 0.37},
#    {'dt': 1633708800,
#     'sunrise': 1633691493,
#     'sunset': 1633732840,
#     'temp': {'day': 71.58,
#      'min': 64.58,
#      'max': 74.43,
#      'night': 65.46,
#      'eve': 72.01,
#      'morn': 64.58},
#     'feels_like': {'day': 72.19, 'night': 66.04, 'eve': 72.77, 'morn': 65.25},
#     'pressure': 1020,
#     'humidity': 80,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 4.43,
#     'deg': 182,
#     'gust': 8.21,
#     'clouds': 63,
#     'pop': 0.91,
#     'rain': 4.55},
#    {'dt': 1633795200,
#     'sunrise': 1633777952,
#     'sunset': 1633819148,
#     'temp': {'day': 65.7,
#      'min': 62.92,
#      'max': 65.7,
#      'night': 62.98,
#      'eve': 64.85,
#      'morn': 64.26},
#     'feels_like': {'day': 66.34, 'night': 63.48, 'eve': 65.55, 'morn': 65.03},
#     'pressure': 1021,
#     'humidity': 93,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 7.94,
#     'deg': 118,
#     'gust': 21.05,
#     'clouds': 100,
#     'pop': 0.97,
#     'rain': 16.93},
#    {'dt': 1633881600,
#     'sunrise': 1633864410,
#     'sunset': 1633905457,
#     'temp': {'day': 65.25,
#      'min': 60.94,
#      'max': 69.89,
#      'night': 63.93,
#      'eve': 69.85,
#      'morn': 60.94},
#     'feels_like': {'day': 65.79, 'night': 64.2, 'eve': 70.3, 'morn': 61.25},
#     'pressure': 1024,
#     'humidity': 92,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 10.49,
#     'deg': 102,
#     'gust': 23,
#     'clouds': 99,
#     'pop': 0.98,
#     'rain': 1.28}]},
#  {'city': {'id': 5554072,
#    'name': 'Juneau',
#    'coord': {'lon': -134.4197, 'lat': 58.3019},
#    'country': 'US',
#    'population': 31275,
#    'timezone': -28800},
#   'cod': '200',
#   'message': 17.2525455,
#   'cnt': 7,
#   'list': [{'dt': 1633377600,
#     'sunrise': 1633360169,
#     'sunset': 1633400568,
#     'temp': {'day': 43.92,
#      'min': 34.77,
#      'max': 44.65,
#      'night': 34.77,
#      'eve': 43.3,
#      'morn': 36.28},
#     'feels_like': {'day': 43.92, 'night': 30.94, 'eve': 41.2, 'morn': 36.28},
#     'pressure': 1019,
#     'humidity': 78,
#     'weather': [{'id': 600,
#       'main': 'Snow',
#       'description': 'light snow',
#       'icon': '13d'}],
#     'speed': 4.43,
#     'deg': 1,
#     'gust': 4.56,
#     'clouds': 33,
#     'pop': 0.36,
#     'snow': 0.11},
#    {'dt': 1633464000,
#     'sunrise': 1633446702,
#     'sunset': 1633486798,
#     'temp': {'day': 45.34,
#      'min': 34.05,
#      'max': 46.58,
#      'night': 35.47,
#      'eve': 38.97,
#      'morn': 34.21},
#     'feels_like': {'day': 44.22, 'night': 32.32, 'eve': 35.8, 'morn': 29.89},
#     'pressure': 1015,
#     'humidity': 66,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 4.76,
#     'deg': 15,
#     'gust': 5.21,
#     'clouds': 1,
#     'pop': 0},
#    {'dt': 1633550400,
#     'sunrise': 1633533235,
#     'sunset': 1633573029,
#     'temp': {'day': 45.93,
#      'min': 33.93,
#      'max': 45.93,
#      'night': 36.9,
#      'eve': 38.14,
#      'morn': 34.02},
#     'feels_like': {'day': 45.93, 'night': 34.54, 'eve': 38.14, 'morn': 30.72},
#     'pressure': 1017,
#     'humidity': 62,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 3.87,
#     'deg': 5,
#     'gust': 3.98,
#     'clouds': 10,
#     'pop': 0},
#    {'dt': 1633636800,
#     'sunrise': 1633619768,
#     'sunset': 1633659260,
#     'temp': {'day': 40.64,
#      'min': 37.6,
#      'max': 40.98,
#      'night': 39.85,
#      'eve': 39.74,
#      'morn': 38.35},
#     'feels_like': {'day': 38.03, 'night': 37.99, 'eve': 37.27, 'morn': 35.73},
#     'pressure': 1011,
#     'humidity': 97,
#     'weather': [{'id': 616,
#       'main': 'Snow',
#       'description': 'rain and snow',
#       'icon': '13d'}],
#     'speed': 4.52,
#     'deg': 91,
#     'gust': 5.66,
#     'clouds': 100,
#     'pop': 0.93,
#     'rain': 2.33,
#     'snow': 3.2},
#    {'dt': 1633723200,
#     'sunrise': 1633706302,
#     'sunset': 1633745492,
#     'temp': {'day': 41.5,
#      'min': 39.88,
#      'max': 41.5,
#      'night': 41.2,
#      'eve': 41.23,
#      'morn': 40.12},
#     'feels_like': {'day': 39.33, 'night': 38.08, 'eve': 37.6, 'morn': 37.81},
#     'pressure': 1004,
#     'humidity': 99,
#     'weather': [{'id': 616,
#       'main': 'Snow',
#       'description': 'rain and snow',
#       'icon': '13d'}],
#     'speed': 5.44,
#     'deg': 112,
#     'gust': 11.81,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 16.72,
#     'snow': 2.13},
#    {'dt': 1633809600,
#     'sunrise': 1633792836,
#     'sunset': 1633831724,
#     'temp': {'day': 43.3,
#      'min': 41,
#      'max': 43.34,
#      'night': 41.79,
#      'eve': 42.1,
#      'morn': 41.88},
#     'feels_like': {'day': 38.75, 'night': 38.21, 'eve': 38.3, 'morn': 36.63},
#     'pressure': 1004,
#     'humidity': 99,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 8.52,
#     'deg': 145,
#     'gust': 15.08,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 28.84},
#    {'dt': 1633896000,
#     'sunrise': 1633879371,
#     'sunset': 1633917957,
#     'temp': {'day': 43.9,
#      'min': 37.17,
#      'max': 43.9,
#      'night': 37.17,
#      'eve': 38.52,
#      'morn': 40.86},
#     'feels_like': {'day': 43.9, 'night': 34.7, 'eve': 36.61, 'morn': 39.16},
#     'pressure': 1012,
#     'humidity': 84,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 4.27,
#     'deg': 141,
#     'gust': 10.33,
#     'clouds': 93,
#     'pop': 0.91,
#     'rain': 3.66}]},
#  {'city': {'id': 5308655,
#    'name': 'Phoenix',
#    'coord': {'lon': -112.074, 'lat': 33.4484},
#    'country': 'US',
#    'population': 1445632,
#    'timezone': -25200},
#   'cod': '200',
#   'message': 0.0924452,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633353889,
#     'sunset': 1633396124,
#     'temp': {'day': 91.38,
#      'min': 80.8,
#      'max': 93.72,
#      'night': 83.61,
#      'eve': 91.67,
#      'morn': 80.8},
#     'feels_like': {'day': 87.94, 'night': 82.9, 'eve': 88.59, 'morn': 79.48},
#     'pressure': 1012,
#     'humidity': 22,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 12.03,
#     'deg': 186,
#     'gust': 15.48,
#     'clouds': 95,
#     'pop': 0.71,
#     'rain': 1.18},
#    {'dt': 1633460400,
#     'sunrise': 1633440332,
#     'sunset': 1633482444,
#     'temp': {'day': 84.7,
#      'min': 74.35,
#      'max': 89.02,
#      'night': 80.71,
#      'eve': 88.21,
#      'morn': 74.5},
#     'feels_like': {'day': 84.36, 'night': 80.82, 'eve': 86.52, 'morn': 74.61},
#     'pressure': 1012,
#     'humidity': 42,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 8.23,
#     'deg': 76,
#     'gust': 10.54,
#     'clouds': 1,
#     'pop': 1,
#     'rain': 7.65},
#    {'dt': 1633546800,
#     'sunrise': 1633526775,
#     'sunset': 1633568765,
#     'temp': {'day': 83.8,
#      'min': 76.51,
#      'max': 89.49,
#      'night': 84.9,
#      'eve': 89.49,
#      'morn': 76.51},
#     'feels_like': {'day': 82.8, 'night': 82.2, 'eve': 85.77, 'morn': 76.32},
#     'pressure': 1013,
#     'humidity': 38,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 7.81,
#     'deg': 98,
#     'gust': 9.53,
#     'clouds': 2,
#     'pop': 0.22},
#    {'dt': 1633633200,
#     'sunrise': 1633613218,
#     'sunset': 1633655086,
#     'temp': {'day': 84.81,
#      'min': 81.18,
#      'max': 88.83,
#      'night': 82.9,
#      'eve': 88.83,
#      'morn': 81.43},
#     'feels_like': {'day': 82.13, 'night': 80.44, 'eve': 84.92, 'morn': 80.02},
#     'pressure': 1012,
#     'humidity': 24,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 6.26,
#     'deg': 188,
#     'gust': 8.79,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633719600,
#     'sunrise': 1633699662,
#     'sunset': 1633741408,
#     'temp': {'day': 79.77,
#      'min': 73.35,
#      'max': 81.86,
#      'night': 73.35,
#      'eve': 80.49,
#      'morn': 76.17},
#     'feels_like': {'day': 79.77, 'night': 71.51, 'eve': 78.78, 'morn': 74.86},
#     'pressure': 1013,
#     'humidity': 31,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 15.57,
#     'deg': 249,
#     'gust': 18.28,
#     'clouds': 66,
#     'pop': 0},
#    {'dt': 1633806000,
#     'sunrise': 1633786106,
#     'sunset': 1633827730,
#     'temp': {'day': 76.87,
#      'min': 70.54,
#      'max': 83.37,
#      'night': 77.79,
#      'eve': 83.37,
#      'morn': 70.54},
#     'feels_like': {'day': 75.25, 'night': 76.26, 'eve': 80.69, 'morn': 68.61},
#     'pressure': 1015,
#     'humidity': 21,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 7.96,
#     'deg': 268,
#     'gust': 10.33,
#     'clouds': 46,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633872551,
#     'sunset': 1633914053,
#     'temp': {'day': 82.27,
#      'min': 73.71,
#      'max': 88.21,
#      'night': 81.93,
#      'eve': 88.21,
#      'morn': 73.71},
#     'feels_like': {'day': 79.88, 'night': 79.61, 'eve': 84.42, 'morn': 71.91},
#     'pressure': 1014,
#     'humidity': 15,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 5.77,
#     'deg': 52,
#     'gust': 7.45,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 698740,
#    'name': 'Odesa',
#    'coord': {'lon': 30.7326, 'lat': 46.4775},
#    'country': 'UA',
#    'population': 1001558,
#    'timezone': 10800},
#   'cod': '200',
#   'message': 20.6367589,
#   'cnt': 7,
#   'list': [{'dt': 1633424400,
#     'sunrise': 1633406442,
#     'sunset': 1633447802,
#     'temp': {'day': 58.41,
#      'min': 44.53,
#      'max': 62.11,
#      'night': 57.52,
#      'eve': 61.65,
#      'morn': 48.06},
#     'feels_like': {'day': 56.07, 'night': 55.47, 'eve': 59.67, 'morn': 44.11},
#     'pressure': 1029,
#     'humidity': 45,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 18.45,
#     'deg': 93,
#     'gust': 21.88,
#     'clouds': 0,
#     'pop': 0},
#    {'dt': 1633510800,
#     'sunrise': 1633492921,
#     'sunset': 1633534086,
#     'temp': {'day': 57.58,
#      'min': 55.56,
#      'max': 60.3,
#      'night': 56.71,
#      'eve': 60.08,
#      'morn': 56.77},
#     'feels_like': {'day': 55.67, 'night': 55.04, 'eve': 58.23, 'morn': 54.82},
#     'pressure': 1029,
#     'humidity': 56,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 20,
#     'deg': 85,
#     'gust': 23.98,
#     'clouds': 50,
#     'pop': 0.01},
#    {'dt': 1633597200,
#     'sunrise': 1633579401,
#     'sunset': 1633620370,
#     'temp': {'day': 54.57,
#      'min': 51.73,
#      'max': 56.97,
#      'night': 55.71,
#      'eve': 56.21,
#      'morn': 52.61},
#     'feels_like': {'day': 52.32, 'night': 53.6, 'eve': 54.16, 'morn': 50.2},
#     'pressure': 1028,
#     'humidity': 55,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 20.56,
#     'deg': 89,
#     'gust': 24.72,
#     'clouds': 0,
#     'pop': 0},
#    {'dt': 1633683600,
#     'sunrise': 1633665881,
#     'sunset': 1633706655,
#     'temp': {'day': 56.1,
#      'min': 54.5,
#      'max': 57.74,
#      'night': 55.44,
#      'eve': 57.34,
#      'morn': 54.5},
#     'feels_like': {'day': 54.19, 'night': 53.13, 'eve': 55.18, 'morn': 52.84},
#     'pressure': 1027,
#     'humidity': 59,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 18.63,
#     'deg': 66,
#     'gust': 24.05,
#     'clouds': 100,
#     'pop': 0.02},
#    {'dt': 1633770000,
#     'sunrise': 1633752362,
#     'sunset': 1633792940,
#     'temp': {'day': 54.75,
#      'min': 54.09,
#      'max': 58.73,
#      'night': 54.86,
#      'eve': 58.73,
#      'morn': 54.41},
#     'feels_like': {'day': 52.03, 'night': 51.93, 'eve': 56.23, 'morn': 51.91},
#     'pressure': 1025,
#     'humidity': 45,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 16.58,
#     'deg': 33,
#     'gust': 23.44,
#     'clouds': 100,
#     'pop': 0.01},
#    {'dt': 1633856400,
#     'sunrise': 1633838843,
#     'sunset': 1633879227,
#     'temp': {'day': 51.3,
#      'min': 44.92,
#      'max': 52.32,
#      'night': 48.06,
#      'eve': 52.07,
#      'morn': 44.92},
#     'feels_like': {'day': 48.33, 'night': 43.38, 'eve': 49.1, 'morn': 38.19},
#     'pressure': 1027,
#     'humidity': 47,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 17.45,
#     'deg': 2,
#     'gust': 23.15,
#     'clouds': 34,
#     'pop': 0},
#    {'dt': 1633942800,
#     'sunrise': 1633925324,
#     'sunset': 1633965513,
#     'temp': {'day': 53.74,
#      'min': 43.2,
#      'max': 57.87,
#      'night': 53.06,
#      'eve': 56.95,
#      'morn': 43.2},
#     'feels_like': {'day': 50.56, 'night': 49.89, 'eve': 53.8, 'morn': 36.91},
#     'pressure': 1023,
#     'humidity': 37,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 12.08,
#     'deg': 329,
#     'gust': 18.68,
#     'clouds': 7,
#     'pop': 0}]},
#  {'city': {'id': 5389519,
#    'name': 'Sacramento',
#    'coord': {'lon': -121.3177, 'lat': 38.4666},
#    'country': 'US',
#    'population': 1418788,
#    'timezone': -25200},
#   'cod': '200',
#   'message': 34.253251,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633356240,
#     'sunset': 1633398210,
#     'temp': {'day': 86.38,
#      'min': 63.46,
#      'max': 91.38,
#      'night': 68.95,
#      'eve': 89.1,
#      'morn': 64.11},
#     'feels_like': {'day': 82.96, 'night': 66.87, 'eve': 85.93, 'morn': 61.39},
#     'pressure': 1012,
#     'humidity': 15,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 5.03,
#     'deg': 229,
#     'gust': 9.44,
#     'clouds': 14,
#     'pop': 0},
#    {'dt': 1633460400,
#     'sunrise': 1633442695,
#     'sunset': 1633484517,
#     'temp': {'day': 82.65,
#      'min': 60.87,
#      'max': 85.82,
#      'night': 61.48,
#      'eve': 76.06,
#      'morn': 61.54},
#     'feels_like': {'day': 80.15, 'night': 59.83, 'eve': 74.59, 'morn': 59.22},
#     'pressure': 1012,
#     'humidity': 15,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 12.15,
#     'deg': 241,
#     'gust': 18.01,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633546800,
#     'sunrise': 1633529150,
#     'sunset': 1633570825,
#     'temp': {'day': 70.45,
#      'min': 57.43,
#      'max': 76.73,
#      'night': 60.71,
#      'eve': 75.92,
#      'morn': 57.43},
#     'feels_like': {'day': 69.44, 'night': 58.93, 'eve': 74.95, 'morn': 56.07},
#     'pressure': 1015,
#     'humidity': 48,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 7.4,
#     'deg': 244,
#     'gust': 14.85,
#     'clouds': 89,
#     'pop': 0},
#    {'dt': 1633633200,
#     'sunrise': 1633615606,
#     'sunset': 1633657134,
#     'temp': {'day': 64.9,
#      'min': 52.61,
#      'max': 71.29,
#      'night': 52.61,
#      'eve': 70.03,
#      'morn': 57.45},
#     'feels_like': {'day': 62.89, 'night': 50.95, 'eve': 68, 'morn': 55.62},
#     'pressure': 1015,
#     'humidity': 38,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 9.46,
#     'deg': 224,
#     'gust': 17.92,
#     'clouds': 100,
#     'pop': 0.03},
#    {'dt': 1633719600,
#     'sunrise': 1633702062,
#     'sunset': 1633743443,
#     'temp': {'day': 61.63,
#      'min': 48.16,
#      'max': 69.76,
#      'night': 54.14,
#      'eve': 69.76,
#      'morn': 48.16},
#     'feels_like': {'day': 59.61, 'night': 52.59, 'eve': 67.66, 'morn': 45.91},
#     'pressure': 1019,
#     'humidity': 45,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 9.15,
#     'deg': 231,
#     'gust': 19.15,
#     'clouds': 21,
#     'pop': 0},
#    {'dt': 1633806000,
#     'sunrise': 1633788519,
#     'sunset': 1633829753,
#     'temp': {'day': 65.37,
#      'min': 50.63,
#      'max': 75.72,
#      'night': 59.18,
#      'eve': 75.72,
#      'morn': 50.63},
#     'feels_like': {'day': 63.39, 'night': 57.2, 'eve': 74.08, 'morn': 49.3},
#     'pressure': 1020,
#     'humidity': 38,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 8.48,
#     'deg': 322,
#     'gust': 10.56,
#     'clouds': 15,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633874976,
#     'sunset': 1633916064,
#     'temp': {'day': 71.65,
#      'min': 53.62,
#      'max': 81,
#      'night': 61.72,
#      'eve': 81,
#      'morn': 53.62},
#     'feels_like': {'day': 69.75, 'night': 59.52, 'eve': 79.07, 'morn': 51.22},
#     'pressure': 1019,
#     'humidity': 26,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 4.88,
#     'deg': 297,
#     'gust': 5.32,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 5419384,
#    'name': 'Denver',
#    'coord': {'lon': -104.9847, 'lat': 39.7392},
#    'country': 'US',
#    'population': 600158,
#    'timezone': -21600},
#   'cod': '200',
#   'message': 0.1464937,
#   'cnt': 7,
#   'list': [{'dt': 1633370400,
#     'sunrise': 1633352353,
#     'sunset': 1633394258,
#     'temp': {'day': 74.89,
#      'min': 58.53,
#      'max': 78.55,
#      'night': 67.62,
#      'eve': 72.91,
#      'morn': 59.23},
#     'feels_like': {'day': 72.79, 'night': 65.12, 'eve': 70.9, 'morn': 56.32},
#     'pressure': 1018,
#     'humidity': 15,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 10.47,
#     'deg': 115,
#     'gust': 19.77,
#     'clouds': 2,
#     'pop': 0},
#    {'dt': 1633456800,
#     'sunrise': 1633438811,
#     'sunset': 1633480563,
#     'temp': {'day': 74.55,
#      'min': 59.86,
#      'max': 81.1,
#      'night': 66.29,
#      'eve': 76.95,
#      'morn': 60.51},
#     'feels_like': {'day': 72.55, 'night': 63.99, 'eve': 75.15, 'morn': 57.67},
#     'pressure': 1017,
#     'humidity': 18,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 14.97,
#     'deg': 154,
#     'gust': 25.57,
#     'clouds': 35,
#     'pop': 0},
#    {'dt': 1633543200,
#     'sunrise': 1633525270,
#     'sunset': 1633566867,
#     'temp': {'day': 72.05,
#      'min': 59.4,
#      'max': 78.19,
#      'night': 67.5,
#      'eve': 68.45,
#      'morn': 59.4},
#     'feels_like': {'day': 70.03, 'night': 65.73, 'eve': 66.74, 'morn': 56.73},
#     'pressure': 1010,
#     'humidity': 23,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 12.3,
#     'deg': 319,
#     'gust': 20.27,
#     'clouds': 79,
#     'pop': 0.31,
#     'rain': 0.36},
#    {'dt': 1633629600,
#     'sunrise': 1633611730,
#     'sunset': 1633653172,
#     'temp': {'day': 70.52,
#      'min': 59.41,
#      'max': 74.91,
#      'night': 67.96,
#      'eve': 73.63,
#      'morn': 59.41},
#     'feels_like': {'day': 68.63, 'night': 65.77, 'eve': 71.58, 'morn': 57.16},
#     'pressure': 1011,
#     'humidity': 29,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 8.57,
#     'deg': 320,
#     'gust': 11.65,
#     'clouds': 66,
#     'pop': 0},
#    {'dt': 1633716000,
#     'sunrise': 1633698189,
#     'sunset': 1633739478,
#     'temp': {'day': 68.23,
#      'min': 60.17,
#      'max': 73.99,
#      'night': 63.64,
#      'eve': 68.16,
#      'morn': 60.17},
#     'feels_like': {'day': 65.79, 'night': 61.3, 'eve': 66.24, 'morn': 57.34},
#     'pressure': 1007,
#     'humidity': 22,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 8.9,
#     'deg': 333,
#     'gust': 10.83,
#     'clouds': 100,
#     'pop': 0.31,
#     'rain': 0.17},
#    {'dt': 1633802400,
#     'sunrise': 1633784649,
#     'sunset': 1633825785,
#     'temp': {'day': 65.16,
#      'min': 53.1,
#      'max': 66,
#      'night': 53.1,
#      'eve': 60.08,
#      'morn': 55.69},
#     'feels_like': {'day': 62.64, 'night': 51.06, 'eve': 57.72, 'morn': 53.02},
#     'pressure': 1009,
#     'humidity': 27,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 12.86,
#     'deg': 26,
#     'gust': 12.48,
#     'clouds': 50,
#     'pop': 0.88,
#     'rain': 1.54},
#    {'dt': 1633888800,
#     'sunrise': 1633871110,
#     'sunset': 1633912092,
#     'temp': {'day': 60.94,
#      'min': 49.62,
#      'max': 64.15,
#      'night': 59.22,
#      'eve': 63.46,
#      'morn': 49.62},
#     'feels_like': {'day': 57.69, 'night': 55.96, 'eve': 60.35, 'morn': 47.98},
#     'pressure': 1015,
#     'humidity': 20,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 11.41,
#     'deg': 335,
#     'gust': 13.42,
#     'clouds': 3,
#     'pop': 0.96,
#     'rain': 4.63}]},
#  {'city': {'id': 4835806,
#    'name': 'Hartford',
#    'coord': {'lon': -72.7662, 'lat': 41.7668},
#    'country': 'US',
#    'population': 894014,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 18.3357803,
#   'cnt': 7,
#   'list': [{'dt': 1633363200,
#     'sunrise': 1633344674,
#     'sunset': 1633386476,
#     'temp': {'day': 59.09,
#      'min': 56.52,
#      'max': 62.02,
#      'night': 56.52,
#      'eve': 56.8,
#      'morn': 60.21},
#     'feels_like': {'day': 59.25, 'night': 56.48, 'eve': 56.79, 'morn': 60.58},
#     'pressure': 1017,
#     'humidity': 97,
#     'weather': [{'id': 502,
#       'main': 'Rain',
#       'description': 'heavy intensity rain',
#       'icon': '10d'}],
#     'speed': 7.81,
#     'deg': 53,
#     'gust': 20.8,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 34.16},
#    {'dt': 1633449600,
#     'sunrise': 1633431138,
#     'sunset': 1633472774,
#     'temp': {'day': 58.19,
#      'min': 53.38,
#      'max': 62.58,
#      'night': 53.38,
#      'eve': 58.3,
#      'morn': 54.21},
#     'feels_like': {'day': 57.52, 'night': 52.79, 'eve': 57.63, 'morn': 53.89},
#     'pressure': 1024,
#     'humidity': 81,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 8.59,
#     'deg': 22,
#     'gust': 20.54,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 1.64},
#    {'dt': 1633536000,
#     'sunrise': 1633517603,
#     'sunset': 1633559073,
#     'temp': {'day': 68.45,
#      'min': 52.3,
#      'max': 72.18,
#      'night': 62.01,
#      'eve': 70.7,
#      'morn': 52.59},
#     'feels_like': {'day': 68, 'night': 61.99, 'eve': 70.57, 'morn': 51.96},
#     'pressure': 1028,
#     'humidity': 64,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 3.4,
#     'deg': 202,
#     'gust': 5.41,
#     'clouds': 35,
#     'pop': 0},
#    {'dt': 1633622400,
#     'sunrise': 1633604068,
#     'sunset': 1633645372,
#     'temp': {'day': 71.06,
#      'min': 57.4,
#      'max': 77.38,
#      'night': 62.58,
#      'eve': 74.59,
#      'morn': 57.4},
#     'feels_like': {'day': 70.83, 'night': 62.53, 'eve': 74.48, 'morn': 57.16},
#     'pressure': 1025,
#     'humidity': 63,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 4.23,
#     'deg': 269,
#     'gust': 9.13,
#     'clouds': 0,
#     'pop': 0},
#    {'dt': 1633708800,
#     'sunrise': 1633690533,
#     'sunset': 1633731672,
#     'temp': {'day': 69.89,
#      'min': 58.73,
#      'max': 74.52,
#      'night': 59.56,
#      'eve': 71.98,
#      'morn': 58.73},
#     'feels_like': {'day': 69.55, 'night': 58.69, 'eve': 71.55, 'morn': 58.62},
#     'pressure': 1021,
#     'humidity': 63,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 4,
#     'deg': 78,
#     'gust': 14.09,
#     'clouds': 94,
#     'pop': 0},
#    {'dt': 1633795200,
#     'sunrise': 1633776999,
#     'sunset': 1633817973,
#     'temp': {'day': 62.28,
#      'min': 51.69,
#      'max': 65.95,
#      'night': 51.69,
#      'eve': 63.73,
#      'morn': 53.85},
#     'feels_like': {'day': 61.25, 'night': 50.09, 'eve': 62.26, 'morn': 53.11},
#     'pressure': 1029,
#     'humidity': 65,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 9.42,
#     'deg': 91,
#     'gust': 20.89,
#     'clouds': 94,
#     'pop': 0},
#    {'dt': 1633881600,
#     'sunrise': 1633863465,
#     'sunset': 1633904274,
#     'temp': {'day': 60.75,
#      'min': 47.5,
#      'max': 66.7,
#      'night': 54.18,
#      'eve': 65.28,
#      'morn': 47.5},
#     'feels_like': {'day': 59.43, 'night': 53.44, 'eve': 64.33, 'morn': 45.19},
#     'pressure': 1031,
#     'humidity': 62,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 5.86,
#     'deg': 20,
#     'gust': 14.47,
#     'clouds': 83,
#     'pop': 0}]},
#  {'city': {'id': 4142290,
#    'name': 'Dover',
#    'coord': {'lon': -75.5244, 'lat': 39.1582},
#    'country': 'US',
#    'population': 36047,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 34.7371321,
#   'cnt': 7,
#   'list': [{'dt': 1633363200,
#     'sunrise': 1633345261,
#     'sunset': 1633387212,
#     'temp': {'day': 79.38,
#      'min': 66.22,
#      'max': 81.19,
#      'night': 70.48,
#      'eve': 75.33,
#      'morn': 67.3},
#     'feels_like': {'day': 79.38, 'night': 71.33, 'eve': 75.94, 'morn': 67.77},
#     'pressure': 1014,
#     'humidity': 60,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 11.72,
#     'deg': 233,
#     'gust': 27.67,
#     'clouds': 100,
#     'pop': 0.98,
#     'rain': 7.78},
#    {'dt': 1633449600,
#     'sunrise': 1633431718,
#     'sunset': 1633473518,
#     'temp': {'day': 70.99,
#      'min': 66.11,
#      'max': 70.99,
#      'night': 66.34,
#      'eve': 68.74,
#      'morn': 66.38},
#     'feels_like': {'day': 71.73, 'night': 66.87, 'eve': 69.35, 'morn': 67.19},
#     'pressure': 1022,
#     'humidity': 84,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 10.83,
#     'deg': 88,
#     'gust': 16.31,
#     'clouds': 99,
#     'pop': 1,
#     'rain': 5.41},
#    {'dt': 1633536000,
#     'sunrise': 1633518176,
#     'sunset': 1633559824,
#     'temp': {'day': 67.8,
#      'min': 65.64,
#      'max': 68.85,
#      'night': 66.22,
#      'eve': 68.47,
#      'morn': 65.71},
#     'feels_like': {'day': 68.23, 'night': 66.49, 'eve': 68.72, 'morn': 66.25},
#     'pressure': 1028,
#     'humidity': 84,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 9.78,
#     'deg': 77,
#     'gust': 15.57,
#     'clouds': 100,
#     'pop': 0.34,
#     'rain': 0.39},
#    {'dt': 1633622400,
#     'sunrise': 1633604633,
#     'sunset': 1633646131,
#     'temp': {'day': 70.39,
#      'min': 65.7,
#      'max': 72.34,
#      'night': 66,
#      'eve': 70.61,
#      'morn': 65.7},
#     'feels_like': {'day': 70.47, 'night': 65.93, 'eve': 70.57, 'morn': 65.97},
#     'pressure': 1026,
#     'humidity': 71,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 6.31,
#     'deg': 104,
#     'gust': 8.5,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633708800,
#     'sunrise': 1633691091,
#     'sunset': 1633732438,
#     'temp': {'day': 73.36,
#      'min': 64.69,
#      'max': 74.08,
#      'night': 65.97,
#      'eve': 73.4,
#      'morn': 64.69},
#     'feels_like': {'day': 73.54, 'night': 65.88, 'eve': 73.63, 'morn': 64.47},
#     'pressure': 1021,
#     'humidity': 67,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 6.46,
#     'deg': 147,
#     'gust': 9.64,
#     'clouds': 66,
#     'pop': 0.11},
#    {'dt': 1633795200,
#     'sunrise': 1633777550,
#     'sunset': 1633818746,
#     'temp': {'day': 67.66,
#      'min': 65.23,
#      'max': 72.05,
#      'night': 65.23,
#      'eve': 69.35,
#      'morn': 65.75},
#     'feels_like': {'day': 67.93, 'night': 65.39, 'eve': 69.37, 'morn': 66.2},
#     'pressure': 1024,
#     'humidity': 81,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 16.06,
#     'deg': 95,
#     'gust': 24.87,
#     'clouds': 100,
#     'pop': 0.33,
#     'rain': 0.48},
#    {'dt': 1633881600,
#     'sunrise': 1633864008,
#     'sunset': 1633905055,
#     'temp': {'day': 70.34,
#      'min': 62.76,
#      'max': 70.45,
#      'night': 67.51,
#      'eve': 69.58,
#      'morn': 62.76},
#     'feels_like': {'day': 70.59, 'night': 67.91, 'eve': 69.85, 'morn': 63.16},
#     'pressure': 1025,
#     'humidity': 75,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 17.63,
#     'deg': 88,
#     'gust': 26.11,
#     'clouds': 72,
#     'pop': 0.48,
#     'rain': 0.67}]},
#  {'city': {'id': 4174715,
#    'name': 'Tallahassee',
#    'coord': {'lon': -84.2807, 'lat': 30.4383},
#    'country': 'US',
#    'population': 181376,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 16.581856,
#   'cnt': 7,
#   'list': [{'dt': 1633366800,
#     'sunrise': 1633347144,
#     'sunset': 1633389532,
#     'temp': {'day': 84.81,
#      'min': 67.86,
#      'max': 86.13,
#      'night': 73.92,
#      'eve': 75.56,
#      'morn': 67.86},
#     'feels_like': {'day': 86.2, 'night': 75.2, 'eve': 76.82, 'morn': 68.61},
#     'pressure': 1016,
#     'humidity': 50,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 6.87,
#     'deg': 181,
#     'gust': 12.06,
#     'clouds': 100,
#     'pop': 0.25},
#    {'dt': 1633453200,
#     'sunrise': 1633433580,
#     'sunset': 1633475859,
#     'temp': {'day': 76.71,
#      'min': 70.2,
#      'max': 78.46,
#      'night': 70.43,
#      'eve': 70.63,
#      'morn': 70.93},
#     'feels_like': {'day': 77.88, 'night': 71.6, 'eve': 71.82, 'morn': 71.44},
#     'pressure': 1016,
#     'humidity': 81,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 4.88,
#     'deg': 221,
#     'gust': 9.42,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 7.22},
#    {'dt': 1633539600,
#     'sunrise': 1633520016,
#     'sunset': 1633562186,
#     'temp': {'day': 77.63,
#      'min': 67.98,
#      'max': 77.63,
#      'night': 70.11,
#      'eve': 71.6,
#      'morn': 68.47},
#     'feels_like': {'day': 78.85, 'night': 71.38, 'eve': 72.82, 'morn': 69.53},
#     'pressure': 1018,
#     'humidity': 80,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 7.74,
#     'deg': 163,
#     'gust': 16.4,
#     'clouds': 93,
#     'pop': 1,
#     'rain': 6.47},
#    {'dt': 1633626000,
#     'sunrise': 1633606452,
#     'sunset': 1633648514,
#     'temp': {'day': 84.81,
#      'min': 69.37,
#      'max': 84.81,
#      'night': 73.18,
#      'eve': 75.25,
#      'morn': 69.71},
#     'feels_like': {'day': 89.85, 'night': 74.34, 'eve': 76.42, 'morn': 70.99},
#     'pressure': 1018,
#     'humidity': 63,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 6.62,
#     'deg': 129,
#     'gust': 14.74,
#     'clouds': 30,
#     'pop': 0.78,
#     'rain': 6.71},
#    {'dt': 1633712400,
#     'sunrise': 1633692889,
#     'sunset': 1633734842,
#     'temp': {'day': 87.01,
#      'min': 70.3,
#      'max': 87.01,
#      'night': 73.58,
#      'eve': 77.04,
#      'morn': 70.3},
#     'feels_like': {'day': 92.28, 'night': 74.77, 'eve': 78.15, 'morn': 71.49},
#     'pressure': 1016,
#     'humidity': 58,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 3.49,
#     'deg': 359,
#     'gust': 4.29,
#     'clouds': 90,
#     'pop': 0.95,
#     'rain': 5.86},
#    {'dt': 1633798800,
#     'sunrise': 1633779327,
#     'sunset': 1633821171,
#     'temp': {'day': 86.54,
#      'min': 69.55,
#      'max': 86.54,
#      'night': 74.5,
#      'eve': 76.75,
#      'morn': 69.55},
#     'feels_like': {'day': 89.33, 'night': 75.45, 'eve': 77.7, 'morn': 70.66},
#     'pressure': 1015,
#     'humidity': 52,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 5.12,
#     'deg': 14,
#     'gust': 17.29,
#     'clouds': 59,
#     'pop': 0.74,
#     'rain': 1.64},
#    {'dt': 1633885200,
#     'sunrise': 1633865764,
#     'sunset': 1633907501,
#     'temp': {'day': 87.17,
#      'min': 69.71,
#      'max': 87.17,
#      'night': 75.45,
#      'eve': 78.6,
#      'morn': 69.71},
#     'feels_like': {'day': 89.37, 'night': 76.17, 'eve': 79.21, 'morn': 70.84},
#     'pressure': 1016,
#     'humidity': 49,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 7.05,
#     'deg': 82,
#     'gust': 17.85,
#     'clouds': 3,
#     'pop': 0.21}]},
#  {'city': {'id': 4180439,
#    'name': 'Atlanta',
#    'coord': {'lon': -84.388, 'lat': 33.749},
#    'country': 'US',
#    'population': 420003,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 16.6691563,
#   'cnt': 7,
#   'list': [{'dt': 1633366800,
#     'sunrise': 1633347248,
#     'sunset': 1633389478,
#     'temp': {'day': 69.91,
#      'min': 64.35,
#      'max': 72.52,
#      'night': 68.36,
#      'eve': 69.66,
#      'morn': 64.87},
#     'feels_like': {'day': 70.68, 'night': 69.17, 'eve': 70.47, 'morn': 65.66},
#     'pressure': 1016,
#     'humidity': 87,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 5.41,
#     'deg': 229,
#     'gust': 14.63,
#     'clouds': 96,
#     'pop': 1,
#     'rain': 9},
#    {'dt': 1633453200,
#     'sunrise': 1633433692,
#     'sunset': 1633475798,
#     'temp': {'day': 67.08,
#      'min': 65.26,
#      'max': 68.97,
#      'night': 65.84,
#      'eve': 66.27,
#      'morn': 65.71},
#     'feels_like': {'day': 67.96, 'night': 66.69, 'eve': 67.12, 'morn': 66.6},
#     'pressure': 1018,
#     'humidity': 95,
#     'weather': [{'id': 502,
#       'main': 'Rain',
#       'description': 'heavy intensity rain',
#       'icon': '10d'}],
#     'speed': 6.93,
#     'deg': 124,
#     'gust': 17.67,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 54.09},
#    {'dt': 1633539600,
#     'sunrise': 1633520136,
#     'sunset': 1633562118,
#     'temp': {'day': 69.28,
#      'min': 63.95,
#      'max': 70.7,
#      'night': 66.34,
#      'eve': 66.78,
#      'morn': 64.17},
#     'feels_like': {'day': 70.18, 'night': 67.28, 'eve': 67.71, 'morn': 64.85},
#     'pressure': 1020,
#     'humidity': 91,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 9.53,
#     'deg': 90,
#     'gust': 22.77,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 9.32},
#    {'dt': 1633626000,
#     'sunrise': 1633606580,
#     'sunset': 1633648438,
#     'temp': {'day': 67.55,
#      'min': 64.65,
#      'max': 72.75,
#      'night': 66.67,
#      'eve': 69.1,
#      'morn': 64.65},
#     'feels_like': {'day': 68.32, 'night': 67.55, 'eve': 69.94, 'morn': 65.37},
#     'pressure': 1021,
#     'humidity': 92,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 7.31,
#     'deg': 111,
#     'gust': 21.7,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 13.51},
#    {'dt': 1633712400,
#     'sunrise': 1633693024,
#     'sunset': 1633734759,
#     'temp': {'day': 69.93,
#      'min': 65.16,
#      'max': 74.64,
#      'night': 68.13,
#      'eve': 69.89,
#      'morn': 65.46},
#     'feels_like': {'day': 70.61, 'night': 68.72, 'eve': 70.43, 'morn': 66.31},
#     'pressure': 1018,
#     'humidity': 85,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 3.53,
#     'deg': 52,
#     'gust': 8.84,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 15.81},
#    {'dt': 1633798800,
#     'sunrise': 1633779469,
#     'sunset': 1633821080,
#     'temp': {'day': 77.59,
#      'min': 64.29,
#      'max': 77.59,
#      'night': 69.53,
#      'eve': 71.78,
#      'morn': 65.25},
#     'feels_like': {'day': 77.68, 'night': 70.03, 'eve': 72.18, 'morn': 65.7},
#     'pressure': 1018,
#     'humidity': 56,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 7.29,
#     'deg': 89,
#     'gust': 15.66,
#     'clouds': 96,
#     'pop': 0.2,
#     'rain': 0.25},
#    {'dt': 1633885200,
#     'sunrise': 1633865914,
#     'sunset': 1633907403,
#     'temp': {'day': 75.74,
#      'min': 66.63,
#      'max': 76.3,
#      'night': 67.66,
#      'eve': 70.88,
#      'morn': 66.63},
#     'feels_like': {'day': 76.03, 'night': 67.93, 'eve': 71.33, 'morn': 67.41},
#     'pressure': 1019,
#     'humidity': 64,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 9.48,
#     'deg': 104,
#     'gust': 19.24,
#     'clouds': 84,
#     'pop': 0.41,
#     'rain': 0.88}]},
#  {'city': {'id': 5856195,
#    'name': 'Honolulu',
#    'coord': {'lon': -157.8583, 'lat': 21.3069},
#    'country': 'US',
#    'population': 371657,
#    'timezone': -36000},
#   'cod': '200',
#   'message': 0.0607068,
#   'cnt': 7,
#   'list': [{'dt': 1633384800,
#     'sunrise': 1633364609,
#     'sunset': 1633407376,
#     'temp': {'day': 80.64,
#      'min': 75.9,
#      'max': 82.98,
#      'night': 76.55,
#      'eve': 79.36,
#      'morn': 75.9},
#     'feels_like': {'day': 83.41, 'night': 77.58, 'eve': 79.36, 'morn': 76.86},
#     'pressure': 1012,
#     'humidity': 66,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 21.21,
#     'deg': 67,
#     'gust': 25.72,
#     'clouds': 18,
#     'pop': 0.38,
#     'rain': 0.35},
#    {'dt': 1633471200,
#     'sunrise': 1633451026,
#     'sunset': 1633493722,
#     'temp': {'day': 79.16,
#      'min': 75.65,
#      'max': 79.16,
#      'night': 76.6,
#      'eve': 77.09,
#      'morn': 75.65},
#     'feels_like': {'day': 79.16, 'night': 77.68, 'eve': 78.08, 'morn': 76.59},
#     'pressure': 1014,
#     'humidity': 70,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 20.54,
#     'deg': 65,
#     'gust': 25.39,
#     'clouds': 8,
#     'pop': 0.04},
#    {'dt': 1633557600,
#     'sunrise': 1633537444,
#     'sunset': 1633580067,
#     'temp': {'day': 78.17,
#      'min': 75.99,
#      'max': 78.31,
#      'night': 75.99,
#      'eve': 77.31,
#      'morn': 76.24},
#     'feels_like': {'day': 79.02, 'night': 76.73, 'eve': 77.97, 'morn': 77.14},
#     'pressure': 1018,
#     'humidity': 71,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 23.58,
#     'deg': 70,
#     'gust': 30.18,
#     'clouds': 9,
#     'pop': 0.04},
#    {'dt': 1633644000,
#     'sunrise': 1633623863,
#     'sunset': 1633666414,
#     'temp': {'day': 78.17,
#      'min': 75.52,
#      'max': 78.17,
#      'night': 75.88,
#      'eve': 76.82,
#      'morn': 75.52},
#     'feels_like': {'day': 78.84, 'night': 76.78, 'eve': 77.63, 'morn': 76.26},
#     'pressure': 1019,
#     'humidity': 67,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 25.9,
#     'deg': 66,
#     'gust': 32.17,
#     'clouds': 0,
#     'pop': 0.21,
#     'rain': 0.28},
#    {'dt': 1633730400,
#     'sunrise': 1633710281,
#     'sunset': 1633752761,
#     'temp': {'day': 77.94,
#      'min': 75.45,
#      'max': 78.28,
#      'night': 75.72,
#      'eve': 76.69,
#      'morn': 75.45},
#     'feels_like': {'day': 78.96, 'night': 76.75, 'eve': 77.68, 'morn': 76.37},
#     'pressure': 1017,
#     'humidity': 75,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 27.07,
#     'deg': 66,
#     'gust': 32.32,
#     'clouds': 32,
#     'pop': 0.4,
#     'rain': 0.98},
#    {'dt': 1633816800,
#     'sunrise': 1633796700,
#     'sunset': 1633839108,
#     'temp': {'day': 77.49,
#      'min': 75.45,
#      'max': 77.49,
#      'night': 75.79,
#      'eve': 76.75,
#      'morn': 75.72},
#     'feels_like': {'day': 78.51, 'night': 76.78, 'eve': 77.79, 'morn': 76.71},
#     'pressure': 1016,
#     'humidity': 76,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 28.3,
#     'deg': 68,
#     'gust': 34.45,
#     'clouds': 96,
#     'pop': 0.51,
#     'rain': 1.77},
#    {'dt': 1633903200,
#     'sunrise': 1633883120,
#     'sunset': 1633925456,
#     'temp': {'day': 78.15,
#      'min': 75.43,
#      'max': 78.37,
#      'night': 76.26,
#      'eve': 77.02,
#      'morn': 75.6},
#     'feels_like': {'day': 79.14, 'night': 77.34, 'eve': 78.13, 'morn': 76.48},
#     'pressure': 1016,
#     'humidity': 74,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 27.92,
#     'deg': 70,
#     'gust': 32.75,
#     'clouds': 13,
#     'pop': 0.25,
#     'rain': 0.43}]},
#  {'city': {'id': 5586437,
#    'name': 'Boise',
#    'coord': {'lon': -116.2035, 'lat': 43.6135},
#    'country': 'US',
#    'population': 145987,
#    'timezone': -21600},
#   'cod': '200',
#   'message': 34.543673,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633355164,
#     'sunset': 1633396831,
#     'temp': {'day': 81.3,
#      'min': 58.01,
#      'max': 83.08,
#      'night': 71.31,
#      'eve': 76.48,
#      'morn': 59.09},
#     'feels_like': {'day': 79.09, 'night': 68.94, 'eve': 75, 'morn': 55.98},
#     'pressure': 1012,
#     'humidity': 11,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 15.3,
#     'deg': 168,
#     'gust': 16.24,
#     'clouds': 0,
#     'pop': 0},
#    {'dt': 1633460400,
#     'sunrise': 1633441634,
#     'sunset': 1633483124,
#     'temp': {'day': 80.82,
#      'min': 61.75,
#      'max': 84.58,
#      'night': 69.15,
#      'eve': 73.63,
#      'morn': 63.05},
#     'feels_like': {'day': 78.75, 'night': 66.52, 'eve': 71.35, 'morn': 59.95},
#     'pressure': 1010,
#     'humidity': 11,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 9.69,
#     'deg': 177,
#     'gust': 12.06,
#     'clouds': 91,
#     'pop': 0},
#    {'dt': 1633546800,
#     'sunrise': 1633528104,
#     'sunset': 1633569417,
#     'temp': {'day': 72.23,
#      'min': 60.46,
#      'max': 72.23,
#      'night': 60.46,
#      'eve': 66.45,
#      'morn': 65.68},
#     'feels_like': {'day': 70.52, 'night': 57.76, 'eve': 64.2, 'morn': 63.27},
#     'pressure': 1011,
#     'humidity': 29,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 15.3,
#     'deg': 298,
#     'gust': 17.81,
#     'clouds': 79,
#     'pop': 0.23},
#    {'dt': 1633633200,
#     'sunrise': 1633614575,
#     'sunset': 1633655711,
#     'temp': {'day': 61.48,
#      'min': 49.48,
#      'max': 65.59,
#      'night': 56.8,
#      'eve': 65.32,
#      'morn': 49.48},
#     'feels_like': {'day': 59.16, 'night': 55.15, 'eve': 63.25, 'morn': 49.48},
#     'pressure': 1013,
#     'humidity': 39,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.87,
#     'deg': 194,
#     'gust': 10.74,
#     'clouds': 99,
#     'pop': 0.2,
#     'rain': 0.11},
#    {'dt': 1633719600,
#     'sunrise': 1633701046,
#     'sunset': 1633742006,
#     'temp': {'day': 59.07,
#      'min': 51.06,
#      'max': 64.54,
#      'night': 55.35,
#      'eve': 63.68,
#      'morn': 51.06},
#     'feels_like': {'day': 57.36, 'night': 52.79, 'eve': 61.34, 'morn': 49.35},
#     'pressure': 1011,
#     'humidity': 57,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 8.48,
#     'deg': 279,
#     'gust': 8.7,
#     'clouds': 100,
#     'pop': 0.47,
#     'rain': 2.26},
#    {'dt': 1633806000,
#     'sunrise': 1633787517,
#     'sunset': 1633828301,
#     'temp': {'day': 58.96,
#      'min': 46.4,
#      'max': 63.72,
#      'night': 54.46,
#      'eve': 63.23,
#      'morn': 46.4},
#     'feels_like': {'day': 56.01, 'night': 51.17, 'eve': 60.39, 'morn': 46.4},
#     'pressure': 1019,
#     'humidity': 31,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 11.56,
#     'deg': 301,
#     'gust': 13.69,
#     'clouds': 6,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633873989,
#     'sunset': 1633914597,
#     'temp': {'day': 62.69,
#      'min': 48.61,
#      'max': 69.13,
#      'night': 62.71,
#      'eve': 69.13,
#      'morn': 48.61},
#     'feels_like': {'day': 60.03, 'night': 60.57, 'eve': 67.12, 'morn': 48.02},
#     'pressure': 1018,
#     'humidity': 29,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 5.19,
#     'deg': 98,
#     'gust': 9.48,
#     'clouds': 28,
#     'pop': 0.02}]},
#  {'city': {'id': 4409896,
#    'name': 'Springfield',
#    'coord': {'lon': -93.2982, 'lat': 37.2153},
#    'country': 'US',
#    'population': 159498,
#    'timezone': -18000},
#   'cod': '200',
#   'message': 0.0632606,
#   'cnt': 7,
#   'list': [{'dt': 1633370400,
#     'sunrise': 1633349477,
#     'sunset': 1633391526,
#     'temp': {'day': 74.91,
#      'min': 58.42,
#      'max': 76.21,
#      'night': 61.11,
#      'eve': 63.54,
#      'morn': 58.42},
#     'feels_like': {'day': 73.8, 'night': 59.74, 'eve': 62.46, 'morn': 58.48},
#     'pressure': 1017,
#     'humidity': 36,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 10.67,
#     'deg': 355,
#     'gust': 13.15,
#     'clouds': 1,
#     'pop': 0},
#    {'dt': 1633456800,
# ...
#     'pressure': 1014,
#     'humidity': 15,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 7.67,
#     'deg': 53,
#     'gust': 11.95,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 5317058,
#    'name': 'Tempe',
#    'coord': {'lon': -111.9093, 'lat': 33.4148},
#    'country': 'US',
#    'population': 161719,
#    'timezone': -25200},
#   'cod': '200',
#   'message': 17.6564939,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633353849,
#     'sunset': 1633396086,
#     'temp': {'day': 91.2,
#      'min': 79.21,
#      'max': 93.56,
#      'night': 82.18,
#      'eve': 90.59,
#      'morn': 79.21},
#     'feels_like': {'day': 87.93, 'night': 81.86, 'eve': 87.28, 'morn': 79.21},
#     'pressure': 1012,
#     'humidity': 23,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 14.29,
#     'deg': 200,
#     'gust': 17.07,
#     'clouds': 100,
#     'pop': 0.72,
#     'rain': 0.96},
#    {'dt': 1633460400,
#     'sunrise': 1633440291,
#     'sunset': 1633482406,
#     'temp': {'day': 84.61,
#      'min': 72.72,
#      'max': 88.66,
#      'night': 78.24,
#      'eve': 87.24,
#      'morn': 72.72},
#     'feels_like': {'day': 84.27, 'night': 78.12, 'eve': 85.84, 'morn': 72.88},
#     'pressure': 1012,
#     'humidity': 42,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 7.58,
#     'deg': 69,
#     'gust': 9.73,
#     'clouds': 1,
#     'pop': 1,
#     'rain': 9.23},
#    {'dt': 1633546800,
#     'sunrise': 1633526734,
#     'sunset': 1633568726,
#     'temp': {'day': 83.17,
#      'min': 74.97,
#      'max': 88.86,
#      'night': 83.23,
#      'eve': 88.86,
#      'morn': 74.97},
#     'feels_like': {'day': 82.36, 'night': 81.21, 'eve': 85.28, 'morn': 74.75},
#     'pressure': 1013,
#     'humidity': 39,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 6.78,
#     'deg': 98,
#     'gust': 8.66,
#     'clouds': 2,
#     'pop': 0.29},
#    {'dt': 1633633200,
#     'sunrise': 1633613178,
#     'sunset': 1633655048,
#     'temp': {'day': 84.67,
#      'min': 79.75,
#      'max': 88.52,
#      'night': 81.21,
#      'eve': 88.07,
#      'morn': 79.75},
#     'feels_like': {'day': 82.09, 'night': 79.34, 'eve': 84.33, 'morn': 79.75},
#     'pressure': 1012,
#     'humidity': 25,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 7.63,
#     'deg': 186,
#     'gust': 9.78,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633719600,
#     'sunrise': 1633699621,
#     'sunset': 1633741369,
#     'temp': {'day': 79.65,
#      'min': 72.37,
#      'max': 81.72,
#      'night': 72.37,
#      'eve': 79.97,
#      'morn': 73.99},
#     'feels_like': {'day': 79.65, 'night': 70.48, 'eve': 79.97, 'morn': 72.55},
#     'pressure': 1013,
#     'humidity': 32,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 16.13,
#     'deg': 251,
#     'gust': 17.47,
#     'clouds': 78,
#     'pop': 0},
#    {'dt': 1633806000,
#     'sunrise': 1633786065,
#     'sunset': 1633827692,
#     'temp': {'day': 76.3,
#      'min': 68.74,
#      'max': 82.56,
#      'night': 76.28,
#      'eve': 82.56,
#      'morn': 68.74},
#     'feels_like': {'day': 74.66, 'night': 74.7, 'eve': 80.11, 'morn': 66.78},
#     'pressure': 1015,
#     'humidity': 22,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 7.31,
#     'deg': 270,
#     'gust': 9.13,
#     'clouds': 40,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633872510,
#     'sunset': 1633914015,
#     'temp': {'day': 81.77,
#      'min': 71.53,
#      'max': 87.67,
#      'night': 80.26,
#      'eve': 87.67,
#      'morn': 71.53},
#     'feels_like': {'day': 79.56, 'night': 78.55, 'eve': 83.98, 'morn': 69.66},
#     'pressure': 1014,
#     'humidity': 16,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 5.75,
#     'deg': 46,
#     'gust': 7.81,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 5295903,
#    'name': 'Gilbert',
#    'coord': {'lon': -111.789, 'lat': 33.3528},
#    'country': 'US',
#    'population': 208453,
#    'timezone': -25200},
#   'cod': '200',
#   'message': 0.2155779,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633353818,
#     'sunset': 1633396058,
#     'temp': {'day': 91.33,
#      'min': 78.15,
#      'max': 94.14,
#      'night': 80.28,
#      'eve': 91.38,
#      'morn': 78.15},
#     'feels_like': {'day': 88.21, 'night': 80.65, 'eve': 87.94, 'morn': 77.13},
#     'pressure': 1012,
#     'humidity': 24,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 15.17,
#     'deg': 210,
#     'gust': 18.81,
#     'clouds': 100,
#     'pop': 0.76,
#     'rain': 0.58},
#    {'dt': 1633460400,
#     'sunrise': 1633440261,
#     'sunset': 1633482379,
#     'temp': {'day': 85.33,
#      'min': 71.13,
#      'max': 88.61,
#      'night': 76.08,
#      'eve': 86.13,
#      'morn': 71.13},
#     'feels_like': {'day': 84.88, 'night': 76.03, 'eve': 85.19, 'morn': 71.33},
#     'pressure': 1012,
#     'humidity': 41,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 8.43,
#     'deg': 141,
#     'gust': 10.49,
#     'clouds': 0,
#     'pop': 1,
#     'rain': 9.46},
#    {'dt': 1633546800,
#     'sunrise': 1633526704,
#     'sunset': 1633568699,
#     'temp': {'day': 82.69,
#      'min': 73.54,
#      'max': 88.27,
#      'night': 81.28,
#      'eve': 88.27,
#      'morn': 73.54},
#     'feels_like': {'day': 82.06, 'night': 80.15, 'eve': 84.83, 'morn': 73.36},
#     'pressure': 1013,
#     'humidity': 40,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 6.38,
#     'deg': 90,
#     'gust': 8.43,
#     'clouds': 2,
#     'pop': 0.32},
#    {'dt': 1633633200,
#     'sunrise': 1633613147,
#     'sunset': 1633655021,
#     'temp': {'day': 84.38,
#      'min': 77.97,
#      'max': 88.18,
#      'night': 78.78,
#      'eve': 87.24,
#      'morn': 77.97},
#     'feels_like': {'day': 81.95, 'night': 78.78, 'eve': 83.75, 'morn': 77.16},
#     'pressure': 1012,
#     'humidity': 26,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 8.37,
#     'deg': 190,
#     'gust': 10.42,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633719600,
#     'sunrise': 1633699590,
#     'sunset': 1633741343,
#     'temp': {'day': 79.21,
#      'min': 70.63,
#      'max': 81.46,
#      'night': 70.63,
#      'eve': 79.41,
#      'morn': 71.47},
#     'feels_like': {'day': 79.21, 'night': 68.67, 'eve': 79.41, 'morn': 69.87},
#     'pressure': 1013,
#     'humidity': 33,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 16.35,
#     'deg': 252,
#     'gust': 16.62,
#     'clouds': 88,
#     'pop': 0},
#    {'dt': 1633806000,
#     'sunrise': 1633786034,
#     'sunset': 1633827665,
#     'temp': {'day': 75.87,
#      'min': 65.97,
#      'max': 81.88,
#      'night': 74.08,
#      'eve': 81.88,
#      'morn': 65.97},
#     'feels_like': {'day': 74.23, 'night': 72.37, 'eve': 79.66, 'morn': 63.91},
#     'pressure': 1015,
#     'humidity': 23,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 6.49,
#     'deg': 318,
#     'gust': 7.74,
#     'clouds': 36,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633872478,
#     'sunset': 1633913988,
#     'temp': {'day': 81.3,
#      'min': 69.21,
#      'max': 87.15,
#      'night': 77.99,
#      'eve': 87.15,
#      'morn': 69.21},
#     'feels_like': {'day': 79.27, 'night': 76.42, 'eve': 83.61, 'morn': 67.24},
#     'pressure': 1014,
#     'humidity': 17,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 5.26,
#     'deg': 41,
#     'gust': 7.14,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 4156404,
#    'name': 'Gainesville',
#    'coord': {'lon': -82.3248, 'lat': 29.6516},
#    'country': 'US',
#    'population': 124354,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 0.0708033,
#   'cnt': 7,
#   'list': [{'dt': 1633366800,
#     'sunrise': 1633346656,
#     'sunset': 1633389081,
#     'temp': {'day': 87.39,
#      'min': 69.84,
#      'max': 88.9,
#      'night': 74.5,
#      'eve': 77.14,
#      'morn': 69.84},
#     'feels_like': {'day': 87.12, 'night': 75.6, 'eve': 78.04, 'morn': 70.47},
#     'pressure': 1015,
#     'humidity': 40,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 6.58,
#     'deg': 105,
#     'gust': 19.26,
#     'clouds': 99,
#     'pop': 0.14},
#    {'dt': 1633453200,
#     'sunrise': 1633433090,
#     'sunset': 1633475409,
#     'temp': {'day': 85.51,
#      'min': 71.08,
#      'max': 86.11,
#      'night': 75.13,
#      'eve': 78.82,
#      'morn': 71.08},
#     'feels_like': {'day': 86.92, 'night': 76.05, 'eve': 78.82, 'morn': 71.98},
#     'pressure': 1016,
#     'humidity': 49,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.49,
#     'deg': 150,
#     'gust': 18.92,
#     'clouds': 99,
#     'pop': 0.36,
#     'rain': 0.24},
#    {'dt': 1633539600,
#     'sunrise': 1633519525,
#     'sunset': 1633561738,
#     'temp': {'day': 85.15,
#      'min': 73.26,
#      'max': 85.15,
#      'night': 75.81,
#      'eve': 77.18,
#      'morn': 73.6},
#     'feels_like': {'day': 88.9, 'night': 76.89, 'eve': 78.17, 'morn': 74.93},
#     'pressure': 1018,
#     'humidity': 58,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 7.45,
#     'deg': 142,
#     'gust': 19.98,
#     'clouds': 100,
#     'pop': 0.96,
#     'rain': 2.55},
#    {'dt': 1633626000,
#     'sunrise': 1633605960,
#     'sunset': 1633648068,
#     'temp': {'day': 89.69,
#      'min': 71.33,
#      'max': 89.69,
#      'night': 76.33,
#      'eve': 79.45,
#      'morn': 72.1},
#     'feels_like': {'day': 91.98, 'night': 77.2, 'eve': 79.45, 'morn': 73.29},
#     'pressure': 1017,
#     'humidity': 45,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 5.59,
#     'deg': 93,
#     'gust': 17.65,
#     'clouds': 31,
#     'pop': 0.35,
#     'rain': 0.1},
#    {'dt': 1633712400,
#     'sunrise': 1633692395,
#     'sunset': 1633734398,
#     'temp': {'day': 90.61,
#      'min': 72.3,
#      'max': 90.61,
#      'night': 73.89,
#      'eve': 77.95,
#      'morn': 72.73},
#     'feels_like': {'day': 93.52, 'night': 74.73, 'eve': 78.84, 'morn': 73.89},
#     'pressure': 1015,
#     'humidity': 45,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 4.54,
#     'deg': 88,
#     'gust': 14.14,
#     'clouds': 67,
#     'pop': 0.71,
#     'rain': 2.44},
#    {'dt': 1633798800,
#     'sunrise': 1633778831,
#     'sunset': 1633820729,
#     'temp': {'day': 90.18,
#      'min': 70.83,
#      'max': 90.18,
#      'night': 76.26,
#      'eve': 79.56,
#      'morn': 71.11},
#     'feels_like': {'day': 92.01, 'night': 77.07, 'eve': 79.56, 'morn': 72.19},
#     'pressure': 1014,
#     'humidity': 43,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.33,
#     'deg': 74,
#     'gust': 15.99,
#     'clouds': 8,
#     'pop': 0.69,
#     'rain': 1.43},
#    {'dt': 1633885200,
#     'sunrise': 1633865267,
#     'sunset': 1633907060,
#     'temp': {'day': 88.66,
#      'min': 70.34,
#      'max': 88.66,
#      'night': 72.77,
#      'eve': 77.4,
#      'morn': 70.34},
#     'feels_like': {'day': 90.01, 'night': 73.65, 'eve': 78.08, 'morn': 71.49},
#     'pressure': 1015,
#     'humidity': 44,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 7.61,
#     'deg': 68,
#     'gust': 18.01,
#     'clouds': 21,
#     'pop': 0.27,
#     'rain': 0.11}]},
#  {'city': {'id': 4168782,
#    'name': 'Plantation',
#    'coord': {'lon': -80.2318, 'lat': 26.1342},
#    'country': 'US',
#    'population': 84955,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 16.8644383,
#   'cnt': 7,
#   'list': [{'dt': 1633366800,
#     'sunrise': 1633346076,
#     'sunset': 1633388657,
#     'temp': {'day': 87.15,
#      'min': 79.59,
#      'max': 87.31,
#      'night': 80.96,
#      'eve': 81.75,
#      'morn': 79.59},
#     'feels_like': {'day': 88.72, 'night': 85.06, 'eve': 85.77, 'morn': 79.59},
#     'pressure': 1014,
#     'humidity': 47,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 10.89,
#     'deg': 97,
#     'gust': 12.53,
#     'clouds': 17,
#     'pop': 0.18},
#    {'dt': 1633453200,
#     'sunrise': 1633432503,
#     'sunset': 1633474993,
#     'temp': {'day': 88.21,
#      'min': 80.17,
#      'max': 89.1,
#      'night': 82.44,
#      'eve': 84.25,
#      'morn': 80.17},
#     'feels_like': {'day': 91.4, 'night': 87.03, 'eve': 88.23, 'morn': 83.1},
#     'pressure': 1015,
#     'humidity': 50,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 12.88,
#     'deg': 102,
#     'gust': 15.7,
#     'clouds': 52,
#     'pop': 0.08},
#    {'dt': 1633539600,
#     'sunrise': 1633518930,
#     'sunset': 1633561329,
#     'temp': {'day': 87.66,
#      'min': 81.21,
#      'max': 88,
#      'night': 83.01,
#      'eve': 83.71,
#      'morn': 81.21},
#     'feels_like': {'day': 92.34, 'night': 88.14, 'eve': 88.39, 'morn': 85.35},
#     'pressure': 1017,
#     'humidity': 55,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 11.72,
#     'deg': 109,
#     'gust': 14.88,
#     'clouds': 84,
#     'pop': 0.56},
#    {'dt': 1633626000,
#     'sunrise': 1633605357,
#     'sunset': 1633647666,
#     'temp': {'day': 89.35,
#      'min': 81.57,
#      'max': 89.35,
#      'night': 83.14,
#      'eve': 84.36,
#      'morn': 81.86},
#     'feels_like': {'day': 94.26, 'night': 88.66, 'eve': 89.94, 'morn': 86.83},
#     'pressure': 1016,
#     'humidity': 52,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 11.7,
#     'deg': 97,
#     'gust': 13.04,
#     'clouds': 40,
#     'pop': 0.41,
#     'rain': 0.37},
#    {'dt': 1633712400,
#     'sunrise': 1633691785,
#     'sunset': 1633734003,
#     'temp': {'day': 88.84,
#      'min': 81.45,
#      'max': 88.84,
#      'night': 83.17,
#      'eve': 84.04,
#      'morn': 81.61},
#     'feels_like': {'day': 93.74, 'night': 87.4, 'eve': 88.7, 'morn': 86.74},
#     'pressure': 1014,
#     'humidity': 53,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 11.03,
#     'deg': 98,
#     'gust': 10.96,
#     'clouds': 97,
#     'pop': 0.6,
#     'rain': 0.88},
#    {'dt': 1633798800,
#     'sunrise': 1633778214,
#     'sunset': 1633820341,
#     'temp': {'day': 89.17,
#      'min': 81.5,
#      'max': 89.17,
#      'night': 81.77,
#      'eve': 83.28,
#      'morn': 81.73},
#     'feels_like': {'day': 92.66, 'night': 84.83, 'eve': 86.13, 'morn': 85.95},
#     'pressure': 1013,
#     'humidity': 49,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 9.48,
#     'deg': 89,
#     'gust': 9.89,
#     'clouds': 29,
#     'pop': 0.98,
#     'rain': 4.71},
#    {'dt': 1633885200,
#     'sunrise': 1633864642,
#     'sunset': 1633906680,
#     'temp': {'day': 85.82,
#      'min': 77.83,
#      'max': 85.82,
#      'night': 81.23,
#      'eve': 82.27,
#      'morn': 78.55},
#     'feels_like': {'day': 88.48, 'night': 83.84, 'eve': 84.83, 'morn': 79.54},
#     'pressure': 1014,
#     'humidity': 53,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 10.29,
#     'deg': 89,
#     'gust': 8.19,
#     'clouds': 26,
#     'pop': 0.88,
#     'rain': 2.12}]}]

# %%
#Check legth ofw weather data
len(weather_json)
# Out:
# 211

# %%
#Write out json to text file 
with open ('7_day_weather_data.txt', 'w') as convert_file:
    convert_file.write(json.dumps(weather_json))

# %%
print(api_url)
