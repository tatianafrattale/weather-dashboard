# %%
#Import dependencies 
import pandas as pd
import numpy as np
import requests
import json

# %%
# List of cities for API calls 
cities_list = ["Montgomery", "Juneau", "Phoenix", "Odessa", "Sacramento", "Denver", "Hartford", "Dover", "Tallahassee", "Atlanta", "Honolulu", "Boise",
          "Springfield", "Indianapolis", "Allen", "Topeka", "Frankfort", "Chesapeake", "Augusta", "Annapolis", "Boston", "Lansing", "Passaic",
          "Jackson", "Roanoke", "Helena", "Lincoln", "Lynchburg", "Concord", "Trenton", "Albuquerque", "Albany", "Raleigh", "Bismarck, Columbus",
          "Auburn", "Salem", "Harrisburg", "Providence", "Columbia", "Pierre", "Nashville", "Austin", "Provo", "Montpelier", "Richmond", "Olympia",
          "Charleston", "Madison, Cheyenne", "Mobile", "Huntsville", "Tucson", "Mesa", "Scottsdale", "Fayetteville", "Jonesboro", "Norfolk",
          "Bakersfield", "Stockton", "Greeley, Westminster", "Aurora", "Loveland", "Stamford", "Norwalk", "Wilmington", "Jacksonville",
          "Miami", "Tampa", "Orlando", "Hollywood", "Lawrence", "Flint", "Troy", "Wyoming", "Duluth", "Plymouth", "Omaha", "Henderson", "Nashua",
          "Clifton", "Elizabeth", "Buffalo", "Rochester", "Yonkers", "Schenectady", "Durham", "Charlotte", "Greensboro", "Asheville", "Gastonia",
          "Akron", "Parma", "Tulsa", "Edmond", "Salem", "Beaverton", "Scranton", "Chattanooga", "Houston", "Dallas", "Arlington", "Plano", "Mesquite",
          "Brownsville", "Pasadena", "Waco", "Carrollton", "Milwaukee", "Tyler", "Murfreesboro", "Pawtucket", "Erie", "Beaverton", "Canton", 
          "Lawton", "Cleveland", "Cincinnati", "Danbury", "Camden", "Newark", "Manchester", "Sparks", "Missoula", "Billings", "Independence", 
          "Gulfport", "Minneapolis", "Southfield", "Kalamazoo", "Westland", "Dearborn", "Somerville", "Newton", "Worcester", "Cambridge", "Lafayette",
          "Kenner", "Shreveport", "Brockton", "Quincy", "Olathe", "Wichita", "Waterloo", "Davenport", "Muncie", "Fishers", "Gary", "Hammond","Bloomington",
          "Palatine", "Joliet", "Rockford", "Chicago", "Peoria", "Elgin", "Roswell", "Macon", "Savannah", "Lauderhill", "Melbourne", "Largo", "Clearwater",
          "Miramar", "Hialeah", "Waterbury", "Longmont", "Boulder", "Centennial", "Arvada", "Pueblo", "Thornton", "Lakewood", "Napa", "Tracy", "Alhambra",
          "Temecula", "Antioch", "Burbank", "Murrieta", "Fairfield", "Carlsbad", "Inglewood", "Downey", "Victorville", "Vallejo", "Roseville", "Visalia",
          "Sunnyvale", "Escondido", "Hayward", "Torrance", "Pomona", "Salinas", "Corona", "Glendale", "Irvine", "Oceanside", "Fontana", "Oxnard", "Modesto",
          "Fremont", "Anaheim", "Oakland", "Fresno", "Springdale", "Avondale", "Yuma", "Surprise", "Tempe", "Gilbert", "Gainesville", "Plantation"]

# %%
# API url template
#api.openweathermap.org/data/2.5/weather?q=atlanta&appid=a6501ad09aae11365e9abba37620e112
url = "https://api.openweathermap.org/data/2.5/forecast/daily?q="
api_key = "&cnt=7&units=imperial&appid=a6501ad09aae11365e9abba37620e112"

# %%
#Iterate through cities list for API Calls
weather_json= []

for city in cities_list: 
    
    api_url = url +city+ api_key
    weather_data = requests.get(api_url).json()
    
    if "name"  not in weather_data: 
        weather_json.append(weather_data)


# Check weather data
weather_json
# Out:
# [{'city': {'id': 4362716,
#    'name': 'Montgomery',
#    'coord': {'lon': -77.1997, 'lat': 39.1501},
#    'country': 'US',
#    'population': 971777,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 18.5513047,
#   'cnt': 7,
#   'list': [{'dt': 1633363200,
#     'sunrise': 1633345663,
#     'sunset': 1633387614,
#     'temp': {'day': 76.6,
#      'min': 64.36,
#      'max': 78.51,
#      'night': 67.17,
#      'eve': 73.22,
#      'morn': 64.45},
#     'feels_like': {'day': 77.11, 'night': 67.87, 'eve': 74.19, 'morn': 64.87},
#     'pressure': 1014,
#     'humidity': 67,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 6.78,
#     'deg': 203,
#     'gust': 19.64,
#     'clouds': 100,
#     'pop': 0.88,
#     'rain': 9.32},
#    {'dt': 1633449600,
#     'sunrise': 1633432120,
#     'sunset': 1633473920,
#     'temp': {'day': 68.34,
#      'min': 62.35,
#      'max': 69.76,
#      'night': 65.77,
#      'eve': 68.25,
#      'morn': 62.73},
#     'feels_like': {'day': 68.97, 'night': 66.6, 'eve': 68.92, 'morn': 63.27},
#     'pressure': 1022,
#     'humidity': 87,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.76,
#     'deg': 61,
#     'gust': 15.77,
#     'clouds': 100,
#     'pop': 0.69,
#     'rain': 1.45},
#    {'dt': 1633536000,
#     'sunrise': 1633518578,
#     'sunset': 1633560226,
#     'temp': {'day': 65.26,
#      'min': 64.29,
#      'max': 65.77,
#      'night': 64.49,
#      'eve': 65.77,
#      'morn': 64.56},
#     'feels_like': {'day': 66, 'night': 65.19, 'eve': 66.47, 'morn': 65.32},
#     'pressure': 1027,
#     'humidity': 96,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.96,
#     'deg': 81,
#     'gust': 15.61,
#     'clouds': 100,
#     'pop': 0.68,
#     'rain': 1.01},
#    {'dt': 1633622400,
#     'sunrise': 1633605035,
#     'sunset': 1633646533,
#     'temp': {'day': 67.64,
#      'min': 64.04,
#      'max': 72.91,
#      'night': 65.16,
#      'eve': 72.91,
#      'morn': 64.04},
#     'feels_like': {'day': 68.29, 'night': 65.79, 'eve': 73.38, 'morn': 64.74},
#     'pressure': 1026,
#     'humidity': 89,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 5.32,
#     'deg': 144,
#     'gust': 8.28,
#     'clouds': 100,
#     'pop': 0.2,
#     'rain': 0.37},
#    {'dt': 1633708800,
#     'sunrise': 1633691493,
#     'sunset': 1633732840,
#     'temp': {'day': 71.58,
#      'min': 64.58,
#      'max': 74.43,
#      'night': 65.46,
#      'eve': 72.01,
#      'morn': 64.58},
#     'feels_like': {'day': 72.19, 'night': 66.04, 'eve': 72.77, 'morn': 65.25},
#     'pressure': 1020,
#     'humidity': 80,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 4.43,
#     'deg': 182,
#     'gust': 8.21,
#     'clouds': 63,
#     'pop': 0.91,
#     'rain': 4.55},
#    {'dt': 1633795200,
#     'sunrise': 1633777952,
#     'sunset': 1633819148,
#     'temp': {'day': 65.7,
#      'min': 62.92,
#      'max': 65.7,
#      'night': 62.98,
#      'eve': 64.85,
#      'morn': 64.26},
#     'feels_like': {'day': 66.34, 'night': 63.48, 'eve': 65.55, 'morn': 65.03},
#     'pressure': 1021,
#     'humidity': 93,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 7.94,
#     'deg': 118,
#     'gust': 21.05,
#     'clouds': 100,
#     'pop': 0.97,
#     'rain': 16.93},
#    {'dt': 1633881600,
#     'sunrise': 1633864410,
#     'sunset': 1633905457,
#     'temp': {'day': 65.25,
#      'min': 60.94,
#      'max': 69.89,
#      'night': 63.93,
#      'eve': 69.85,
#      'morn': 60.94},
#     'feels_like': {'day': 65.79, 'night': 64.2, 'eve': 70.3, 'morn': 61.25},
#     'pressure': 1024,
#     'humidity': 92,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 10.49,
#     'deg': 102,
#     'gust': 23,
#     'clouds': 99,
#     'pop': 0.98,
#     'rain': 1.28}]},
#  {'city': {'id': 5554072,
#    'name': 'Juneau',
#    'coord': {'lon': -134.4197, 'lat': 58.3019},
#    'country': 'US',
#    'population': 31275,
#    'timezone': -28800},
#   'cod': '200',
#   'message': 15.7726022,
#   'cnt': 7,
#   'list': [{'dt': 1633377600,
#     'sunrise': 1633360169,
#     'sunset': 1633400568,
#     'temp': {'day': 44.6,
#      'min': 34.9,
#      'max': 45.5,
#      'night': 34.95,
#      'eve': 41.43,
#      'morn': 36.28},
#     'feels_like': {'day': 44.6, 'night': 31.05, 'eve': 39.06, 'morn': 36.28},
#     'pressure': 1019,
#     'humidity': 78,
#     'weather': [{'id': 600,
#       'main': 'Snow',
#       'description': 'light snow',
#       'icon': '13d'}],
#     'speed': 4.45,
#     'deg': 13,
#     'gust': 4.52,
#     'clouds': 44,
#     'pop': 0.36,
#     'snow': 0.11},
#    {'dt': 1633464000,
#     'sunrise': 1633446702,
#     'sunset': 1633486798,
#     'temp': {'day': 45.37,
#      'min': 34.2,
#      'max': 46.74,
#      'night': 35.53,
#      'eve': 38.93,
#      'morn': 34.34},
#     'feels_like': {'day': 44.33, 'night': 32.27, 'eve': 35.73, 'morn': 30.09},
#     'pressure': 1015,
#     'humidity': 66,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 4.72,
#     'deg': 23,
#     'gust': 5.06,
#     'clouds': 1,
#     'pop': 0},
#    {'dt': 1633550400,
#     'sunrise': 1633533235,
#     'sunset': 1633573029,
#     'temp': {'day': 46.24,
#      'min': 34.03,
#      'max': 46.24,
#      'night': 36.63,
#      'eve': 37.26,
#      'morn': 34.03},
#     'feels_like': {'day': 46.24, 'night': 34.41, 'eve': 35.26, 'morn': 30.6},
#     'pressure': 1017,
#     'humidity': 63,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 3.94,
#     'deg': 358,
#     'gust': 4.18,
#     'clouds': 4,
#     'pop': 0},
#    {'dt': 1633636800,
#     'sunrise': 1633619768,
#     'sunset': 1633659260,
#     'temp': {'day': 40.3,
#      'min': 36.73,
#      'max': 40.3,
#      'night': 40.01,
#      'eve': 39.7,
#      'morn': 38.46},
#     'feels_like': {'day': 37.71, 'night': 37.29, 'eve': 36.81, 'morn': 36.57},
#     'pressure': 1013,
#     'humidity': 99,
#     'weather': [{'id': 616,
#       'main': 'Snow',
#       'description': 'rain and snow',
#       'icon': '13d'}],
#     'speed': 4.32,
#     'deg': 101,
#     'gust': 8.61,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 1.71,
#     'snow': 9.81},
#    {'dt': 1633723200,
#     'sunrise': 1633706302,
#     'sunset': 1633745492,
#     'temp': {'day': 42.12,
#      'min': 40.23,
#      'max': 42.98,
#      'night': 42.55,
#      'eve': 42.89,
#      'morn': 40.6},
#     'feels_like': {'day': 37.74, 'night': 38.1, 'eve': 39.69, 'morn': 37.04},
#     'pressure': 1005,
#     'humidity': 98,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 7.18,
#     'deg': 122,
#     'gust': 15.35,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 23.19},
#    {'dt': 1633809600,
#     'sunrise': 1633792836,
#     'sunset': 1633831724,
#     'temp': {'day': 42.87,
#      'min': 41.58,
#      'max': 43.57,
#      'night': 42.93,
#      'eve': 43.57,
#      'morn': 42.42},
#     'feels_like': {'day': 38.12, 'night': 38.93, 'eve': 39.34, 'morn': 37.67},
#     'pressure': 1000,
#     'humidity': 99,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 8.28,
#     'deg': 142,
#     'gust': 14.27,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 30.09},
#    {'dt': 1633896000,
#     'sunrise': 1633879371,
#     'sunset': 1633917957,
#     'temp': {'day': 44.24,
#      'min': 37.44,
#      'max': 44.24,
#      'night': 37.44,
#      'eve': 38.73,
#      'morn': 40.96},
#     'feels_like': {'day': 44.24, 'night': 35.15, 'eve': 38.73, 'morn': 38.86},
#     'pressure': 1015,
#     'humidity': 84,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 5.64,
#     'deg': 152,
#     'gust': 10.65,
#     'clouds': 96,
#     'pop': 0.91,
#     'rain': 3.38}]},
#  {'city': {'id': 5308655,
#    'name': 'Phoenix',
#    'coord': {'lon': -112.074, 'lat': 33.4484},
#    'country': 'US',
#    'population': 1445632,
#    'timezone': -25200},
#   'cod': '200',
#   'message': 0.0649164,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633353889,
#     'sunset': 1633396124,
#     'temp': {'day': 92.53,
#      'min': 80.8,
#      'max': 95.45,
#      'night': 82,
#      'eve': 94.93,
#      'morn': 80.8},
#     'feels_like': {'day': 89.17, 'night': 81.95, 'eve': 91.85, 'morn': 79.48},
#     'pressure': 1011,
#     'humidity': 22,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 20.89,
#     'deg': 122,
#     'gust': 28.54,
#     'clouds': 95,
#     'pop': 0.6,
#     'rain': 0.91},
#    {'dt': 1633460400,
#     'sunrise': 1633440332,
#     'sunset': 1633482444,
#     'temp': {'day': 86.2,
#      'min': 75.72,
#      'max': 89.71,
#      'night': 82.22,
#      'eve': 86.07,
#      'morn': 75.78},
#     'feels_like': {'day': 85.46, 'night': 81.41, 'eve': 84.58, 'morn': 75.87},
#     'pressure': 1012,
#     'humidity': 39,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 9.48,
#     'deg': 72,
#     'gust': 11.68,
#     'clouds': 88,
#     'pop': 0.95,
#     'rain': 4.09},
#    {'dt': 1633546800,
#     'sunrise': 1633526775,
#     'sunset': 1633568765,
#     'temp': {'day': 84.31,
#      'min': 76.89,
#      'max': 89.94,
#      'night': 85.12,
#      'eve': 89.94,
#      'morn': 76.89},
#     'feels_like': {'day': 82.99, 'night': 82.31, 'eve': 86.18, 'morn': 76.68},
#     'pressure': 1013,
#     'humidity': 36,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 7.65,
#     'deg': 76,
#     'gust': 9.53,
#     'clouds': 2,
#     'pop': 0.03},
#    {'dt': 1633633200,
#     'sunrise': 1633613218,
#     'sunset': 1633655086,
#     'temp': {'day': 84.7,
#      'min': 80.91,
#      'max': 88.56,
#      'night': 83.82,
#      'eve': 88.56,
#      'morn': 80.91},
#     'feels_like': {'day': 81.99, 'night': 81.07, 'eve': 84.7, 'morn': 79.61},
#     'pressure': 1012,
#     'humidity': 23,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 5.79,
#     'deg': 208,
#     'gust': 8.84,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633719600,
#     'sunrise': 1633699662,
#     'sunset': 1633741408,
#     'temp': {'day': 82.78,
#      'min': 76.91,
#      'max': 86.61,
#      'night': 76.91,
#      'eve': 85.73,
#      'morn': 77.76},
#     'feels_like': {'day': 80.55, 'night': 75.29, 'eve': 82.49, 'morn': 76.41},
#     'pressure': 1012,
#     'humidity': 23,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 13.91,
#     'deg': 240,
#     'gust': 14.47,
#     'clouds': 70,
#     'pop': 0},
#    {'dt': 1633806000,
#     'sunrise': 1633786106,
#     'sunset': 1633827730,
#     'temp': {'day': 79.21,
#      'min': 73.87,
#      'max': 83.34,
#      'night': 78.01,
#      'eve': 83.34,
#      'morn': 73.87},
#     'feels_like': {'day': 79.21, 'night': 76.44, 'eve': 80.65, 'morn': 72.12},
#     'pressure': 1012,
#     'humidity': 20,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 7.99,
#     'deg': 279,
#     'gust': 10.56,
#     'clouds': 66,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633872551,
#     'sunset': 1633914053,
#     'temp': {'day': 81.41,
#      'min': 73.08,
#      'max': 86.77,
#      'night': 80.56,
#      'eve': 86.77,
#      'morn': 73.08},
#     'feels_like': {'day': 79.39, 'night': 78.75, 'eve': 83.25, 'morn': 71.26},
#     'pressure': 1014,
#     'humidity': 18,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 6.29,
#     'deg': 247,
#     'gust': 7.45,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 698740,
#    'name': 'Odesa',
#    'coord': {'lon': 30.7326, 'lat': 46.4775},
#    'country': 'UA',
#    'population': 1001558,
#    'timezone': 10800},
#   'cod': '200',
#   'message': 0.0830899,
#   'cnt': 7,
#   'list': [{'dt': 1633424400,
#     'sunrise': 1633406442,
#     'sunset': 1633447802,
#     'temp': {'day': 58.44,
#      'min': 48.13,
#      'max': 61.77,
#      'night': 56.91,
#      'eve': 61.45,
#      'morn': 52.41},
#     'feels_like': {'day': 56.1, 'night': 54.93, 'eve': 59.45, 'morn': 50.13},
#     'pressure': 1029,
#     'humidity': 45,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 18.63,
#     'deg': 92,
#     'gust': 22.46,
#     'clouds': 0,
#     'pop': 0},
#    {'dt': 1633510800,
#     'sunrise': 1633492921,
#     'sunset': 1633534086,
#     'temp': {'day': 56.75,
#      'min': 54.25,
#      'max': 60.06,
#      'night': 57.79,
#      'eve': 60.06,
#      'morn': 54.25},
#     'feels_like': {'day': 55.04, 'night': 56.14, 'eve': 58.55, 'morn': 52.29},
#     'pressure': 1028,
#     'humidity': 62,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 21.07,
#     'deg': 97,
#     'gust': 24.18,
#     'clouds': 100,
#     'pop': 0.01},
#    {'dt': 1633597200,
#     'sunrise': 1633579401,
#     'sunset': 1633620370,
#     'temp': {'day': 55.17,
#      'min': 52.52,
#      'max': 56.82,
#      'night': 55.8,
#      'eve': 56.61,
#      'morn': 53.64},
#     'feels_like': {'day': 53.15, 'night': 53.94, 'eve': 54.73, 'morn': 51.62},
#     'pressure': 1027,
#     'humidity': 59,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 21.18,
#     'deg': 81,
#     'gust': 25.66,
#     'clouds': 10,
#     'pop': 0.01},
#    {'dt': 1633683600,
#     'sunrise': 1633665881,
#     'sunset': 1633706655,
#     'temp': {'day': 56.7,
#      'min': 54.77,
#      'max': 59.74,
#      'night': 57.31,
#      'eve': 59.74,
#      'morn': 55.54},
#     'feels_like': {'day': 54.75, 'night': 55.42, 'eve': 57.76, 'morn': 54.18},
#     'pressure': 1027,
#     'humidity': 57,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 19.82,
#     'deg': 76,
#     'gust': 23.38,
#     'clouds': 100,
#     'pop': 0.18},
#    {'dt': 1633770000,
#     'sunrise': 1633752362,
#     'sunset': 1633792940,
#     'temp': {'day': 55.98,
#      'min': 51.94,
#      'max': 59.04,
#      'night': 54.14,
#      'eve': 58.46,
#      'morn': 52.83},
#     'feels_like': {'day': 53.44, 'night': 51.08, 'eve': 55.56, 'morn': 50.4},
#     'pressure': 1026,
#     'humidity': 46,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 17.92,
#     'deg': 46,
#     'gust': 25.14,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633856400,
#     'sunrise': 1633838843,
#     'sunset': 1633879227,
#     'temp': {'day': 51.69,
#      'min': 48.02,
#      'max': 52.72,
#      'night': 52.72,
#      'eve': 52.39,
#      'morn': 48.02},
#     'feels_like': {'day': 48.54, 'night': 50.04, 'eve': 49.87, 'morn': 42.24},
#     'pressure': 1026,
#     'humidity': 42,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 15.68,
#     'deg': 20,
#     'gust': 21.88,
#     'clouds': 100,
#     'pop': 0.5,
#     'rain': 1.68},
#    {'dt': 1633942800,
#     'sunrise': 1633925324,
#     'sunset': 1633965513,
#     'temp': {'day': 52.52,
#      'min': 47.82,
#      'max': 52.52,
#      'night': 48.38,
#      'eve': 49.71,
#      'morn': 47.82},
#     'feels_like': {'day': 50.34, 'night': 44.64, 'eve': 45.84, 'morn': 42.26},
#     'pressure': 1020,
#     'humidity': 61,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 13.47,
#     'deg': 7,
#     'gust': 16.53,
#     'clouds': 100,
#     'pop': 0.18}]},
#  {'city': {'id': 5389519,
#    'name': 'Sacramento',
#    'coord': {'lon': -121.3177, 'lat': 38.4666},
#    'country': 'US',
#    'population': 1418788,
#    'timezone': -25200},
#   'cod': '200',
#   'message': 0.0658298,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633356240,
#     'sunset': 1633398210,
#     'temp': {'day': 87.3,
#      'min': 63.46,
#      'max': 91.38,
#      'night': 68.95,
#      'eve': 89.73,
#      'morn': 64.11},
#     'feels_like': {'day': 83.71, 'night': 66.87, 'eve': 85.98, 'morn': 61.39},
#     'pressure': 1012,
#     'humidity': 16,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 5.03,
#     'deg': 229,
#     'gust': 9.44,
#     'clouds': 11,
#     'pop': 0},
#    {'dt': 1633460400,
#     'sunrise': 1633442695,
#     'sunset': 1633484517,
#     'temp': {'day': 82.65,
#      'min': 60.87,
#      'max': 85.82,
#      'night': 61.48,
#      'eve': 76.06,
#      'morn': 61.54},
#     'feels_like': {'day': 80.15, 'night': 59.83, 'eve': 74.59, 'morn': 59.22},
#     'pressure': 1012,
#     'humidity': 15,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 12.15,
#     'deg': 241,
#     'gust': 18.01,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633546800,
#     'sunrise': 1633529150,
#     'sunset': 1633570825,
#     'temp': {'day': 70.45,
#      'min': 57.43,
#      'max': 76.73,
#      'night': 60.71,
#      'eve': 75.92,
#      'morn': 57.43},
#     'feels_like': {'day': 69.44, 'night': 58.93, 'eve': 74.95, 'morn': 56.07},
#     'pressure': 1015,
#     'humidity': 48,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 7.4,
#     'deg': 244,
#     'gust': 14.85,
#     'clouds': 89,
#     'pop': 0},
#    {'dt': 1633633200,
#     'sunrise': 1633615606,
#     'sunset': 1633657134,
#     'temp': {'day': 64.9,
#      'min': 52.61,
#      'max': 71.29,
#      'night': 52.61,
#      'eve': 70.03,
#      'morn': 57.45},
#     'feels_like': {'day': 62.89, 'night': 50.95, 'eve': 68, 'morn': 55.62},
#     'pressure': 1015,
#     'humidity': 38,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 9.46,
#     'deg': 224,
#     'gust': 17.92,
#     'clouds': 100,
#     'pop': 0.03},
#    {'dt': 1633719600,
#     'sunrise': 1633702062,
#     'sunset': 1633743443,
#     'temp': {'day': 61.63,
#      'min': 48.16,
#      'max': 69.76,
#      'night': 54.14,
#      'eve': 69.76,
#      'morn': 48.16},
#     'feels_like': {'day': 59.61, 'night': 52.59, 'eve': 67.66, 'morn': 45.91},
#     'pressure': 1019,
#     'humidity': 45,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 9.15,
#     'deg': 231,
#     'gust': 19.15,
#     'clouds': 21,
#     'pop': 0},
#    {'dt': 1633806000,
#     'sunrise': 1633788519,
#     'sunset': 1633829753,
#     'temp': {'day': 65.37,
#      'min': 50.63,
#      'max': 75.72,
#      'night': 59.18,
#      'eve': 75.72,
#      'morn': 50.63},
#     'feels_like': {'day': 63.39, 'night': 57.2, 'eve': 74.08, 'morn': 49.3},
#     'pressure': 1020,
#     'humidity': 38,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 8.48,
#     'deg': 322,
#     'gust': 10.56,
#     'clouds': 15,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633874976,
#     'sunset': 1633916064,
#     'temp': {'day': 71.65,
#      'min': 53.62,
#      'max': 81,
#      'night': 61.72,
#      'eve': 81,
#      'morn': 53.62},
#     'feels_like': {'day': 69.75, 'night': 59.52, 'eve': 79.07, 'morn': 51.22},
#     'pressure': 1019,
#     'humidity': 26,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 4.88,
#     'deg': 297,
#     'gust': 5.32,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 5419384,
#    'name': 'Denver',
#    'coord': {'lon': -104.9847, 'lat': 39.7392},
#    'country': 'US',
#    'population': 600158,
#    'timezone': -21600},
#   'cod': '200',
#   'message': 0.1175297,
#   'cnt': 7,
#   'list': [{'dt': 1633370400,
#     'sunrise': 1633352353,
#     'sunset': 1633394258,
#     'temp': {'day': 74.89,
#      'min': 58.53,
#      'max': 78.78,
#      'night': 66.6,
#      'eve': 78.26,
#      'morn': 59.23},
#     'feels_like': {'day': 72.79, 'night': 63.99, 'eve': 76.53, 'morn': 56.32},
#     'pressure': 1018,
#     'humidity': 15,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 10.47,
#     'deg': 115,
#     'gust': 19.77,
#     'clouds': 2,
#     'pop': 0},
#    {'dt': 1633456800,
#     'sunrise': 1633438811,
#     'sunset': 1633480563,
#     'temp': {'day': 74.55,
#      'min': 59.86,
#      'max': 81.1,
#      'night': 66.29,
#      'eve': 76.95,
#      'morn': 60.51},
#     'feels_like': {'day': 72.55, 'night': 63.99, 'eve': 75.15, 'morn': 57.67},
#     'pressure': 1017,
#     'humidity': 18,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 14.97,
#     'deg': 154,
#     'gust': 25.57,
#     'clouds': 35,
#     'pop': 0},
#    {'dt': 1633543200,
#     'sunrise': 1633525270,
#     'sunset': 1633566867,
#     'temp': {'day': 72.05,
#      'min': 59.4,
#      'max': 78.19,
#      'night': 67.5,
#      'eve': 68.45,
#      'morn': 59.4},
#     'feels_like': {'day': 70.03, 'night': 65.73, 'eve': 66.74, 'morn': 56.73},
#     'pressure': 1010,
#     'humidity': 23,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 12.3,
#     'deg': 319,
#     'gust': 20.27,
#     'clouds': 79,
#     'pop': 0.31,
#     'rain': 0.36},
#    {'dt': 1633629600,
#     'sunrise': 1633611730,
#     'sunset': 1633653172,
#     'temp': {'day': 70.52,
#      'min': 59.41,
#      'max': 74.91,
#      'night': 67.96,
#      'eve': 73.63,
#      'morn': 59.41},
#     'feels_like': {'day': 68.63, 'night': 65.77, 'eve': 71.58, 'morn': 57.16},
#     'pressure': 1011,
#     'humidity': 29,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 8.57,
#     'deg': 320,
#     'gust': 11.65,
#     'clouds': 66,
#     'pop': 0},
#    {'dt': 1633716000,
#     'sunrise': 1633698189,
#     'sunset': 1633739478,
#     'temp': {'day': 68.23,
#      'min': 60.17,
#      'max': 73.99,
#      'night': 63.64,
#      'eve': 68.16,
#      'morn': 60.17},
#     'feels_like': {'day': 65.79, 'night': 61.3, 'eve': 66.24, 'morn': 57.34},
#     'pressure': 1007,
#     'humidity': 22,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 8.9,
#     'deg': 333,
#     'gust': 10.83,
#     'clouds': 100,
#     'pop': 0.31,
#     'rain': 0.17},
#    {'dt': 1633802400,
#     'sunrise': 1633784649,
#     'sunset': 1633825785,
#     'temp': {'day': 65.16,
#      'min': 53.1,
#      'max': 66,
#      'night': 53.1,
#      'eve': 60.08,
#      'morn': 55.69},
#     'feels_like': {'day': 62.64, 'night': 51.06, 'eve': 57.72, 'morn': 53.02},
#     'pressure': 1009,
#     'humidity': 27,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 12.86,
#     'deg': 26,
#     'gust': 12.48,
#     'clouds': 50,
#     'pop': 0.88,
#     'rain': 1.54},
#    {'dt': 1633888800,
#     'sunrise': 1633871110,
#     'sunset': 1633912092,
#     'temp': {'day': 60.94,
#      'min': 49.62,
#      'max': 64.15,
#      'night': 59.22,
#      'eve': 63.46,
#      'morn': 49.62},
#     'feels_like': {'day': 57.69, 'night': 55.96, 'eve': 60.35, 'morn': 47.98},
#     'pressure': 1015,
#     'humidity': 20,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 11.41,
#     'deg': 335,
#     'gust': 13.42,
#     'clouds': 3,
#     'pop': 0.96,
#     'rain': 4.63}]},
#  {'city': {'id': 4835806,
#    'name': 'Hartford',
#    'coord': {'lon': -72.7662, 'lat': 41.7668},
#    'country': 'US',
#    'population': 894014,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 16.1547449,
#   'cnt': 7,
#   'list': [{'dt': 1633363200,
#     'sunrise': 1633344674,
#     'sunset': 1633386476,
#     'temp': {'day': 59.09,
#      'min': 56.12,
#      'max': 62.02,
#      'night': 56.12,
#      'eve': 57.45,
#      'morn': 60.21},
#     'feels_like': {'day': 59.25, 'night': 56.03, 'eve': 57.45, 'morn': 60.58},
#     'pressure': 1017,
#     'humidity': 97,
#     'weather': [{'id': 502,
#       'main': 'Rain',
#       'description': 'heavy intensity rain',
#       'icon': '10d'}],
#     'speed': 7.85,
#     'deg': 50,
#     'gust': 20.98,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 32.47},
#    {'dt': 1633449600,
#     'sunrise': 1633431138,
#     'sunset': 1633472774,
#     'temp': {'day': 56.16,
#      'min': 54.16,
#      'max': 61.88,
#      'night': 56.12,
#      'eve': 59.04,
#      'morn': 54.45},
#     'feels_like': {'day': 55.62, 'night': 55.38, 'eve': 58.44, 'morn': 54.16},
#     'pressure': 1025,
#     'humidity': 88,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 7.56,
#     'deg': 25,
#     'gust': 17.94,
#     'clouds': 100,
#     'pop': 0.84,
#     'rain': 1.05},
#    {'dt': 1633536000,
#     'sunrise': 1633517603,
#     'sunset': 1633559073,
#     'temp': {'day': 61.83,
#      'min': 56.14,
#      'max': 69.46,
#      'night': 59.86,
#      'eve': 69.31,
#      'morn': 56.34},
#     'feels_like': {'day': 61.23, 'night': 59.97, 'eve': 69.28, 'morn': 55.62},
#     'pressure': 1029,
#     'humidity': 75,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 3.11,
#     'deg': 26,
#     'gust': 6.51,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633622400,
#     'sunrise': 1633604068,
#     'sunset': 1633645372,
#     'temp': {'day': 67.5,
#      'min': 60.4,
#      'max': 75.27,
#      'night': 61.75,
#      'eve': 71.2,
#      'morn': 61.05},
#     'feels_like': {'day': 67.48, 'night': 61.63, 'eve': 71.22, 'morn': 61.14},
#     'pressure': 1025,
#     'humidity': 75,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 2.91,
#     'deg': 231,
#     'gust': 6.38,
#     'clouds': 100,
#     'pop': 0.2,
#     'rain': 0.12},
#    {'dt': 1633708800,
#     'sunrise': 1633690533,
#     'sunset': 1633731672,
#     'temp': {'day': 70.81,
#      'min': 58.48,
#      'max': 76.55,
#      'night': 60.13,
#      'eve': 72.79,
#      'morn': 58.48},
#     'feels_like': {'day': 70.56, 'night': 59.79, 'eve': 72.45, 'morn': 58.35},
#     'pressure': 1020,
#     'humidity': 63,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 4.25,
#     'deg': 67,
#     'gust': 8.52,
#     'clouds': 32,
#     'pop': 0},
#    {'dt': 1633795200,
#     'sunrise': 1633776999,
#     'sunset': 1633817973,
#     'temp': {'day': 64.08,
#      'min': 53.35,
#      'max': 65.34,
#      'night': 53.35,
#      'eve': 64.45,
#      'morn': 54.5},
#     'feels_like': {'day': 63.61, 'night': 52.29, 'eve': 63.75, 'morn': 53.78},
#     'pressure': 1026,
#     'humidity': 73,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 7.92,
#     'deg': 97,
#     'gust': 14.63,
#     'clouds': 81,
#     'pop': 0.37,
#     'rain': 0.49},
#    {'dt': 1633881600,
#     'sunrise': 1633863465,
#     'sunset': 1633904274,
#     'temp': {'day': 58.3,
#      'min': 50.7,
#      'max': 65.86,
#      'night': 52.93,
#      'eve': 64.08,
#      'morn': 50.7},
#     'feels_like': {'day': 57.02, 'night': 52.02, 'eve': 63, 'morn': 49.33},
#     'pressure': 1029,
#     'humidity': 68,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 6.22,
#     'deg': 125,
#     'gust': 14.47,
#     'clouds': 100,
#     'pop': 0}]},
#  {'city': {'id': 4142290,
#    'name': 'Dover',
#    'coord': {'lon': -75.5244, 'lat': 39.1582},
#    'country': 'US',
#    'population': 36047,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 20.3306827,
#   'cnt': 7,
#   'list': [{'dt': 1633363200,
#     'sunrise': 1633345261,
#     'sunset': 1633387212,
#     'temp': {'day': 79.38,
#      'min': 66.22,
#      'max': 80.78,
#      'night': 69.87,
#      'eve': 74.88,
#      'morn': 67.3},
#     'feels_like': {'day': 79.38, 'night': 70.7, 'eve': 75.63, 'morn': 67.77},
#     'pressure': 1014,
#     'humidity': 60,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 11.72,
#     'deg': 233,
#     'gust': 27.67,
#     'clouds': 100,
#     'pop': 0.93,
#     'rain': 9.83},
#    {'dt': 1633449600,
#     'sunrise': 1633431718,
#     'sunset': 1633473518,
#     'temp': {'day': 71.58,
#      'min': 65.73,
#      'max': 71.69,
#      'night': 66.38,
#      'eve': 68.18,
#      'morn': 66.16},
#     'feels_like': {'day': 72.34, 'night': 67.05, 'eve': 68.83, 'morn': 66.99},
#     'pressure': 1022,
#     'humidity': 83,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 10.87,
#     'deg': 75,
#     'gust': 16.49,
#     'clouds': 100,
#     'pop': 0.98,
#     'rain': 6.93},
#    {'dt': 1633536000,
#     'sunrise': 1633518176,
#     'sunset': 1633559824,
#     'temp': {'day': 66.38,
#      'min': 65.16,
#      'max': 68.29,
#      'night': 65.48,
#      'eve': 68.29,
#      'morn': 65.23},
#     'feels_like': {'day': 66.9, 'night': 65.86, 'eve': 68.58, 'morn': 65.82},
#     'pressure': 1028,
#     'humidity': 89,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 10.4,
#     'deg': 77,
#     'gust': 16.22,
#     'clouds': 100,
#     'pop': 0.63,
#     'rain': 1.36},
#    {'dt': 1633622400,
#     'sunrise': 1633604633,
#     'sunset': 1633646131,
#     'temp': {'day': 69.12,
#      'min': 65.1,
#      'max': 71.6,
#      'night': 65.1,
#      'eve': 71.22,
#      'morn': 65.64},
#     'feels_like': {'day': 69.44, 'night': 65.59, 'eve': 71.53, 'morn': 66.09},
#     'pressure': 1026,
#     'humidity': 79,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 5.12,
#     'deg': 128,
#     'gust': 6.82,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633708800,
#     'sunrise': 1633691091,
#     'sunset': 1633732438,
#     'temp': {'day': 72.97,
#      'min': 63.5,
#      'max': 75.58,
#      'night': 66.83,
#      'eve': 71.56,
#      'morn': 63.5},
#     'feels_like': {'day': 73.26, 'night': 67.03, 'eve': 71.91, 'morn': 63.88},
#     'pressure': 1021,
#     'humidity': 70,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 7.25,
#     'deg': 150,
#     'gust': 13.47,
#     'clouds': 100,
#     'pop': 0.36,
#     'rain': 0.33},
#    {'dt': 1633795200,
#     'sunrise': 1633777550,
#     'sunset': 1633818746,
#     'temp': {'day': 72.1,
#      'min': 65.48,
#      'max': 72.72,
#      'night': 67.08,
#      'eve': 70.95,
#      'morn': 65.48},
#     'feels_like': {'day': 72.3, 'night': 67.15, 'eve': 71.13, 'morn': 65.91},
#     'pressure': 1022,
#     'humidity': 70,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 13.53,
#     'deg': 113,
#     'gust': 23.04,
#     'clouds': 99,
#     'pop': 0.34,
#     'rain': 0.57},
#    {'dt': 1633881600,
#     'sunrise': 1633864008,
#     'sunset': 1633905055,
#     'temp': {'day': 71.01,
#      'min': 66.18,
#      'max': 73,
#      'night': 66.97,
#      'eve': 69.57,
#      'morn': 66.61},
#     'feels_like': {'day': 71.33, 'night': 67.32, 'eve': 69.84, 'morn': 67.01},
#     'pressure': 1024,
#     'humidity': 75,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 17.74,
#     'deg': 90,
#     'gust': 28.3,
#     'clouds': 91,
#     'pop': 0.46,
#     'rain': 1.08}]},
#  {'city': {'id': 4174715,
#    'name': 'Tallahassee',
#    'coord': {'lon': -84.2807, 'lat': 30.4383},
#    'country': 'US',
#    'population': 181376,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 16.9050369,
#   'cnt': 7,
#   'list': [{'dt': 1633366800,
#     'sunrise': 1633347144,
#     'sunset': 1633389532,
#     'temp': {'day': 84.81,
#      'min': 67.86,
#      'max': 85.57,
#      'night': 73.71,
#      'eve': 76.48,
#      'morn': 67.86},
#     'feels_like': {'day': 86.2, 'night': 74.59, 'eve': 78.19, 'morn': 68.61},
#     'pressure': 1016,
#     'humidity': 50,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 6.8,
#     'deg': 182,
#     'gust': 12.71,
#     'clouds': 100,
#     'pop': 0.25},
#    {'dt': 1633453200,
#     'sunrise': 1633433580,
#     'sunset': 1633475859,
#     'temp': {'day': 78.39,
#      'min': 69.4,
#      'max': 78.39,
#      'night': 69.87,
#      'eve': 70.93,
#      'morn': 70.2},
#     'feels_like': {'day': 79.39, 'night': 70.84, 'eve': 72.05, 'morn': 70.86},
#     'pressure': 1016,
#     'humidity': 74,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 4.21,
#     'deg': 209,
#     'gust': 8.23,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 8.29},
#    {'dt': 1633539600,
#     'sunrise': 1633520016,
#     'sunset': 1633562186,
#     'temp': {'day': 80.13,
#      'min': 67.8,
#      'max': 83.66,
#      'night': 72.88,
#      'eve': 74.75,
#      'morn': 67.8},
#     'feels_like': {'day': 82.92, 'night': 73.96, 'eve': 75.63, 'morn': 68.85},
#     'pressure': 1018,
#     'humidity': 68,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 7.16,
#     'deg': 145,
#     'gust': 17.58,
#     'clouds': 96,
#     'pop': 1,
#     'rain': 4.12},
#    {'dt': 1633626000,
#     'sunrise': 1633606452,
#     'sunset': 1633648514,
#     'temp': {'day': 86.25,
#      'min': 69.85,
#      'max': 86.25,
#      'night': 74.26,
#      'eve': 77.32,
#      'morn': 70.12},
#     'feels_like': {'day': 90.5, 'night': 75.38, 'eve': 78.37, 'morn': 71.4},
#     'pressure': 1017,
#     'humidity': 57,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 4.18,
#     'deg': 85,
#     'gust': 15.66,
#     'clouds': 8,
#     'pop': 0.94,
#     'rain': 2.98},
#    {'dt': 1633712400,
#     'sunrise': 1633692889,
#     'sunset': 1633734842,
#     'temp': {'day': 89.17,
#      'min': 70.03,
#      'max': 89.17,
#      'night': 72.7,
#      'eve': 77.13,
#      'morn': 70.05},
#     'feels_like': {'day': 92.66, 'night': 73.76, 'eve': 78.12, 'morn': 71.22},
#     'pressure': 1015,
#     'humidity': 49,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 4.36,
#     'deg': 26,
#     'gust': 10.42,
#     'clouds': 39,
#     'pop': 0.8,
#     'rain': 3.47},
#    {'dt': 1633798800,
#     'sunrise': 1633779327,
#     'sunset': 1633821171,
#     'temp': {'day': 86.76,
#      'min': 68.97,
#      'max': 86.76,
#      'night': 71.46,
#      'eve': 75.2,
#      'morn': 68.97},
#     'feels_like': {'day': 87.58, 'night': 71.73, 'eve': 75.47, 'morn': 70.03},
#     'pressure': 1015,
#     'humidity': 45,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 5.82,
#     'deg': 40,
#     'gust': 12.17,
#     'clouds': 61,
#     'pop': 0.83,
#     'rain': 0.48},
#    {'dt': 1633885200,
#     'sunrise': 1633865764,
#     'sunset': 1633907501,
#     'temp': {'day': 88.2,
#      'min': 67.44,
#      'max': 88.2,
#      'night': 75.79,
#      'eve': 78.75,
#      'morn': 67.44},
#     'feels_like': {'day': 89.02, 'night': 76.14, 'eve': 78.75, 'morn': 67.69},
#     'pressure': 1016,
#     'humidity': 43,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 4.59,
#     'deg': 59,
#     'gust': 13.49,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 4180439,
#    'name': 'Atlanta',
#    'coord': {'lon': -84.388, 'lat': 33.749},
#    'country': 'US',
#    'population': 420003,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 0.0888543,
#   'cnt': 7,
#   'list': [{'dt': 1633366800,
#     'sunrise': 1633347248,
#     'sunset': 1633389478,
#     'temp': {'day': 69.91,
#      'min': 64.35,
#      'max': 71.28,
#      'night': 67.89,
#      'eve': 70.12,
#      'morn': 64.87},
#     'feels_like': {'day': 70.68, 'night': 68.76, 'eve': 70.97, 'morn': 65.66},
#     'pressure': 1016,
#     'humidity': 87,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 5.41,
#     'deg': 229,
#     'gust': 14.63,
#     'clouds': 96,
#     'pop': 1,
#     'rain': 11.41},
#    {'dt': 1633453200,
#     'sunrise': 1633433692,
#     'sunset': 1633475798,
#     'temp': {'day': 65.41,
#      'min': 64.72,
#      'max': 66.88,
#      'night': 64.72,
#      'eve': 65.26,
#      'morn': 65.41},
#     'feels_like': {'day': 66.2, 'night': 65.5, 'eve': 66.09, 'morn': 66.25},
#     'pressure': 1018,
#     'humidity': 97,
#     'weather': [{'id': 502,
#       'main': 'Rain',
#       'description': 'heavy intensity rain',
#       'icon': '10d'}],
#     'speed': 8.25,
#     'deg': 112,
#     'gust': 18.21,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 49.93},
#    {'dt': 1633539600,
#     'sunrise': 1633520136,
#     'sunset': 1633562118,
#     'temp': {'day': 68.25,
#      'min': 64.36,
#      'max': 69.73,
#      'night': 66.25,
#      'eve': 66.69,
#      'morn': 64.6},
#     'feels_like': {'day': 69.15, 'night': 67.19, 'eve': 67.62, 'morn': 65.41},
#     'pressure': 1020,
#     'humidity': 93,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 9.15,
#     'deg': 74,
#     'gust': 20.92,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 17.98},
#    {'dt': 1633626000,
#     'sunrise': 1633606580,
#     'sunset': 1633648438,
#     'temp': {'day': 70.65,
#      'min': 64.85,
#      'max': 73.54,
#      'night': 66.36,
#      'eve': 67.89,
#      'morn': 64.85},
#     'feels_like': {'day': 71.6, 'night': 67.21, 'eve': 68.85, 'morn': 65.59},
#     'pressure': 1020,
#     'humidity': 89,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 7.25,
#     'deg': 119,
#     'gust': 19.69,
#     'clouds': 100,
#     'pop': 1,
#     'rain': 9.93},
#    {'dt': 1633712400,
#     'sunrise': 1633693024,
#     'sunset': 1633734759,
#     'temp': {'day': 70.3,
#      'min': 63.82,
#      'max': 71.4,
#      'night': 67.01,
#      'eve': 69.33,
#      'morn': 63.82},
#     'feels_like': {'day': 70.75, 'night': 67.12, 'eve': 69.49, 'morn': 64.51},
#     'pressure': 1018,
#     'humidity': 79,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 3.69,
#     'deg': 35,
#     'gust': 9.01,
#     'clouds': 99,
#     'pop': 1,
#     'rain': 2.97},
#    {'dt': 1633798800,
#     'sunrise': 1633779469,
#     'sunset': 1633821080,
#     'temp': {'day': 80.19,
#      'min': 63.63,
#      'max': 80.19,
#      'night': 70.02,
#      'eve': 72.75,
#      'morn': 63.63},
#     'feels_like': {'day': 80.67, 'night': 70.11, 'eve': 72.79, 'morn': 63.73},
#     'pressure': 1016,
#     'humidity': 47,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 4,
#     'deg': 337,
#     'gust': 8.08,
#     'clouds': 96,
#     'pop': 0},
#    {'dt': 1633885200,
#     'sunrise': 1633865914,
#     'sunset': 1633907403,
#     'temp': {'day': 79.92,
#      'min': 64.69,
#      'max': 79.92,
#      'night': 66.99,
#      'eve': 70.66,
#      'morn': 64.69},
#     'feels_like': {'day': 79.92, 'night': 67.3, 'eve': 70.95, 'morn': 65.08},
#     'pressure': 1018,
#     'humidity': 52,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 9.1,
#     'deg': 79,
#     'gust': 20.87,
#     'clouds': 15,
#     'pop': 0}]},
#  {'city': {'id': 5856195,
#    'name': 'Honolulu',
#    'coord': {'lon': -157.8583, 'lat': 21.3069},
#    'country': 'US',
#    'population': 371657,
#    'timezone': -36000},
#   'cod': '200',
#   'message': 0.1152202,
#   'cnt': 7,
#   'list': [{'dt': 1633384800,
#     'sunrise': 1633364609,
#     'sunset': 1633407376,
#     'temp': {'day': 84.96,
#      'min': 75.9,
#      'max': 86.49,
#      'night': 76.46,
#      'eve': 77.02,
#      'morn': 75.9},
#     'feels_like': {'day': 88.57, 'night': 77.43, 'eve': 77.9, 'morn': 76.86},
#     'pressure': 1013,
#     'humidity': 58,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 20.65,
#     'deg': 70,
#     'gust': 25.84,
#     'clouds': 17,
#     'pop': 0.38,
#     'rain': 0.34},
#    {'dt': 1633471200,
#     'sunrise': 1633451026,
#     'sunset': 1633493722,
#     'temp': {'day': 78.98,
#      'min': 75.85,
#      'max': 79.03,
#      'night': 76.53,
#      'eve': 77.13,
#      'morn': 75.96},
#     'feels_like': {'day': 78.98, 'night': 77.59, 'eve': 78.15, 'morn': 76.91},
#     'pressure': 1014,
#     'humidity': 71,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 20.45,
#     'deg': 64,
#     'gust': 24.4,
#     'clouds': 15,
#     'pop': 0},
#    {'dt': 1633557600,
#     'sunrise': 1633537444,
#     'sunset': 1633580067,
#     'temp': {'day': 78.39,
#      'min': 75.99,
#      'max': 78.39,
#      'night': 75.99,
#      'eve': 77.43,
#      'morn': 76.48},
#     'feels_like': {'day': 79.39, 'night': 76.68, 'eve': 78.4, 'morn': 77.54},
#     'pressure': 1017,
#     'humidity': 74,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 24.29,
#     'deg': 75,
#     'gust': 30.71,
#     'clouds': 11,
#     'pop': 0.32,
#     'rain': 0.4},
#    {'dt': 1633644000,
#     'sunrise': 1633623863,
#     'sunset': 1633666414,
#     'temp': {'day': 78.22,
#      'min': 75.61,
#      'max': 78.33,
#      'night': 76.01,
#      'eve': 76.93,
#      'morn': 75.61},
#     'feels_like': {'day': 79.09, 'night': 76.93, 'eve': 77.76, 'morn': 76.26},
#     'pressure': 1018,
#     'humidity': 71,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 25.59,
#     'deg': 66,
#     'gust': 31.65,
#     'clouds': 8,
#     'pop': 0.1},
#    {'dt': 1633730400,
#     'sunrise': 1633710281,
#     'sunset': 1633752761,
#     'temp': {'day': 77.86,
#      'min': 75.43,
#      'max': 78.33,
#      'night': 75.43,
#      'eve': 76.71,
#      'morn': 75.56},
#     'feels_like': {'day': 78.78, 'night': 76.44, 'eve': 77.61, 'morn': 76.48},
#     'pressure': 1017,
#     'humidity': 73,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 27.72,
#     'deg': 69,
#     'gust': 32.99,
#     'clouds': 23,
#     'pop': 0.24,
#     'rain': 0.57},
#    {'dt': 1633816800,
#     'sunrise': 1633796700,
#     'sunset': 1633839108,
#     'temp': {'day': 77.81,
#      'min': 75.22,
#      'max': 78.12,
#      'night': 75.58,
#      'eve': 76.55,
#      'morn': 75.47},
#     'feels_like': {'day': 78.76, 'night': 76.64, 'eve': 77.61, 'morn': 76.42},
#     'pressure': 1016,
#     'humidity': 74,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 27.54,
#     'deg': 69,
#     'gust': 33.87,
#     'clouds': 13,
#     'pop': 0.39,
#     'rain': 2.06},
#    {'dt': 1633903200,
#     'sunrise': 1633883120,
#     'sunset': 1633925456,
#     'temp': {'day': 78.13,
#      'min': 75.63,
#      'max': 78.21,
#      'night': 76.08,
#      'eve': 77.05,
#      'morn': 75.63},
#     'feels_like': {'day': 79.18, 'night': 77.34, 'eve': 78.17, 'morn': 76.66},
#     'pressure': 1016,
#     'humidity': 75,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 27.6,
#     'deg': 69,
#     'gust': 33.35,
#     'clouds': 8,
#     'pop': 0.33,
#     'rain': 0.79}]},
#  {'city': {'id': 5586437,
#    'name': 'Boise',
#    'coord': {'lon': -116.2035, 'lat': 43.6135},
#    'country': 'US',
#    'population': 145987,
#    'timezone': -21600},
#   'cod': '200',
#   'message': 0.0863652,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633355164,
#     'sunset': 1633396831,
#     'temp': {'day': 81.48,
#      'min': 58.01,
#      'max': 83.03,
#      'night': 70.02,
#      'eve': 79.83,
#      'morn': 59.09},
#     'feels_like': {'day': 79.25, 'night': 67.42, 'eve': 79.83, 'morn': 55.98},
#     'pressure': 1012,
#     'humidity': 12,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 15.3,
#     'deg': 168,
#     'gust': 16.24,
#     'clouds': 0,
#     'pop': 0},
#    {'dt': 1633460400,
#     'sunrise': 1633441634,
#     'sunset': 1633483124,
#     'temp': {'day': 80.82,
#      'min': 61.75,
#      'max': 84.58,
#      'night': 69.15,
#      'eve': 73.63,
#      'morn': 63.05},
#     'feels_like': {'day': 78.75, 'night': 66.52, 'eve': 71.35, 'morn': 59.95},
#     'pressure': 1010,
#     'humidity': 11,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 9.69,
#     'deg': 177,
#     'gust': 12.06,
#     'clouds': 91,
#     'pop': 0},
#    {'dt': 1633546800,
#     'sunrise': 1633528104,
#     'sunset': 1633569417,
#     'temp': {'day': 72.23,
#      'min': 60.46,
#      'max': 72.23,
#      'night': 60.46,
#      'eve': 66.45,
#      'morn': 65.68},
#     'feels_like': {'day': 70.52, 'night': 57.76, 'eve': 64.2, 'morn': 63.27},
#     'pressure': 1011,
#     'humidity': 29,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 15.3,
#     'deg': 298,
#     'gust': 17.81,
#     'clouds': 79,
#     'pop': 0.23},
#    {'dt': 1633633200,
#     'sunrise': 1633614575,
#     'sunset': 1633655711,
#     'temp': {'day': 61.48,
#      'min': 49.48,
#      'max': 65.59,
#      'night': 56.8,
#      'eve': 65.32,
#      'morn': 49.48},
#     'feels_like': {'day': 59.16, 'night': 55.15, 'eve': 63.25, 'morn': 49.48},
#     'pressure': 1013,
#     'humidity': 39,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.87,
#     'deg': 194,
#     'gust': 10.74,
#     'clouds': 99,
#     'pop': 0.2,
#     'rain': 0.11},
#    {'dt': 1633719600,
#     'sunrise': 1633701046,
#     'sunset': 1633742006,
#     'temp': {'day': 59.07,
#      'min': 51.06,
#      'max': 64.54,
#      'night': 55.35,
#      'eve': 63.68,
#      'morn': 51.06},
#     'feels_like': {'day': 57.36, 'night': 52.79, 'eve': 61.34, 'morn': 49.35},
#     'pressure': 1011,
#     'humidity': 57,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 8.48,
#     'deg': 279,
#     'gust': 8.7,
#     'clouds': 100,
#     'pop': 0.47,
#     'rain': 2.26},
#    {'dt': 1633806000,
#     'sunrise': 1633787517,
#     'sunset': 1633828301,
#     'temp': {'day': 58.96,
#      'min': 46.4,
#      'max': 63.72,
#      'night': 54.46,
#      'eve': 63.23,
#      'morn': 46.4},
#     'feels_like': {'day': 56.01, 'night': 51.17, 'eve': 60.39, 'morn': 46.4},
#     'pressure': 1019,
#     'humidity': 31,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 11.56,
#     'deg': 301,
#     'gust': 13.69,
#     'clouds': 6,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633873989,
#     'sunset': 1633914597,
#     'temp': {'day': 62.69,
#      'min': 48.61,
#      'max': 69.13,
#      'night': 62.71,
#      'eve': 69.13,
#      'morn': 48.61},
#     'feels_like': {'day': 60.03, 'night': 60.57, 'eve': 67.12, 'morn': 48.02},
#     'pressure': 1018,
#     'humidity': 29,
#     'weather': [{'id': 802,
#       'main': 'Clouds',
#       'description': 'scattered clouds',
#       'icon': '03d'}],
#     'speed': 5.19,
#     'deg': 98,
#     'gust': 9.48,
#     'clouds': 28,
#     'pop': 0.02}]},
#  {'city': {'id': 4409896,
#    'name': 'Springfield',
#    'coord': {'lon': -93.2982, 'lat': 37.2153},
#    'country': 'US',
#    'population': 159498,
#    'timezone': -18000},
#   'cod': '200',
#   'message': 0.1063136,
#   'cnt': 7,
#   'list': [{'dt': 1633370400,
#     'sunrise': 1633349477,
#     'sunset': 1633391526,
#     'temp': {'day': 74.91,
#      'min': 58.42,
#      'max': 74.98,
#      'night': 59.77,
#      'eve': 70.14,
#      'morn': 58.42},
#     'feels_like': {'day': 73.8, 'night': 58.14, 'eve': 69.06, 'morn': 58.48},
#     'pressure': 1017,
#     'humidity': 36,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 10.67,
#     'deg': 355,
#     'gust': 13.15,
#     'clouds': 1,
#     'pop': 0},
# ...
#     'pressure': 1014,
#     'humidity': 18,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 7.72,
#     'deg': 19,
#     'gust': 10.87,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 5317058,
#    'name': 'Tempe',
#    'coord': {'lon': -111.9093, 'lat': 33.4148},
#    'country': 'US',
#    'population': 161719,
#    'timezone': -25200},
#   'cod': '200',
#   'message': 0.0906189,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633353849,
#     'sunset': 1633396086,
#     'temp': {'day': 92.26,
#      'min': 79.21,
#      'max': 95.25,
#      'night': 80.29,
#      'eve': 94.35,
#      'morn': 79.21},
#     'feels_like': {'day': 89.06, 'night': 80.96, 'eve': 91.42, 'morn': 79.21},
#     'pressure': 1012,
#     'humidity': 23,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 22.64,
#     'deg': 109,
#     'gust': 29.66,
#     'clouds': 95,
#     'pop': 0.69,
#     'rain': 1.35},
#    {'dt': 1633460400,
#     'sunrise': 1633440291,
#     'sunset': 1633482406,
#     'temp': {'day': 85.91,
#      'min': 73.67,
#      'max': 89.28,
#      'night': 80.85,
#      'eve': 85.53,
#      'morn': 73.67},
#     'feels_like': {'day': 85.14, 'night': 80.73, 'eve': 84.36, 'morn': 73.8},
#     'pressure': 1012,
#     'humidity': 39,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 8.39,
#     'deg': 66,
#     'gust': 10.98,
#     'clouds': 52,
#     'pop': 0.95,
#     'rain': 3.77},
#    {'dt': 1633546800,
#     'sunrise': 1633526734,
#     'sunset': 1633568726,
#     'temp': {'day': 83.88,
#      'min': 75.38,
#      'max': 89.4,
#      'night': 83.35,
#      'eve': 89.4,
#      'morn': 75.38},
#     'feels_like': {'day': 82.72, 'night': 81.16, 'eve': 85.78, 'morn': 75.16},
#     'pressure': 1013,
#     'humidity': 37,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 7.72,
#     'deg': 73,
#     'gust': 9.84,
#     'clouds': 2,
#     'pop': 0.09},
#    {'dt': 1633633200,
#     'sunrise': 1633613178,
#     'sunset': 1633655048,
#     'temp': {'day': 84.97,
#      'min': 79.63,
#      'max': 88.47,
#      'night': 82.35,
#      'eve': 88.14,
#      'morn': 79.63},
#     'feels_like': {'day': 82.13, 'night': 80.06, 'eve': 84.36, 'morn': 79.63},
#     'pressure': 1012,
#     'humidity': 22,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 7.16,
#     'deg': 199,
#     'gust': 9.82,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633719600,
#     'sunrise': 1633699621,
#     'sunset': 1633741369,
#     'temp': {'day': 82.76,
#      'min': 75.67,
#      'max': 86.27,
#      'night': 76.41,
#      'eve': 85.33,
#      'morn': 75.67},
#     'feels_like': {'day': 80.44, 'night': 74.79, 'eve': 82.22, 'morn': 74.1},
#     'pressure': 1012,
#     'humidity': 21,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 13.44,
#     'deg': 244,
#     'gust': 14.27,
#     'clouds': 69,
#     'pop': 0},
#    {'dt': 1633806000,
#     'sunrise': 1633786065,
#     'sunset': 1633827692,
#     'temp': {'day': 79.09,
#      'min': 72.45,
#      'max': 82.96,
#      'night': 76.95,
#      'eve': 82.87,
#      'morn': 72.45},
#     'feels_like': {'day': 79.09, 'night': 75.38, 'eve': 80.33, 'morn': 70.66},
#     'pressure': 1012,
#     'humidity': 20,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 8.08,
#     'deg': 278,
#     'gust': 9.4,
#     'clouds': 63,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633872510,
#     'sunset': 1633914015,
#     'temp': {'day': 81,
#      'min': 71.1,
#      'max': 86.16,
#      'night': 79.2,
#      'eve': 86.16,
#      'morn': 71.1},
#     'feels_like': {'day': 79.16, 'night': 79.2, 'eve': 82.76, 'morn': 69.17},
#     'pressure': 1014,
#     'humidity': 19,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 5.93,
#     'deg': 42,
#     'gust': 7.05,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 5295903,
#    'name': 'Gilbert',
#    'coord': {'lon': -111.789, 'lat': 33.3528},
#    'country': 'US',
#    'population': 208453,
#    'timezone': -25200},
#   'cod': '200',
#   'message': 17.8593572,
#   'cnt': 7,
#   'list': [{'dt': 1633374000,
#     'sunrise': 1633353818,
#     'sunset': 1633396058,
#     'temp': {'day': 92.21,
#      'min': 78.15,
#      'max': 95.29,
#      'night': 79.41,
#      'eve': 93.67,
#      'morn': 78.15},
#     'feels_like': {'day': 89.19, 'night': 79.41, 'eve': 90.86, 'morn': 77.13},
#     'pressure': 1012,
#     'humidity': 24,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 22.57,
#     'deg': 96,
#     'gust': 29.04,
#     'clouds': 95,
#     'pop': 0.73,
#     'rain': 1.47},
#    {'dt': 1633460400,
#     'sunrise': 1633440261,
#     'sunset': 1633482379,
#     'temp': {'day': 85.77,
#      'min': 72.52,
#      'max': 89.46,
#      'night': 79.21,
#      'eve': 85.8,
#      'morn': 72.52},
#     'feels_like': {'day': 84.97, 'night': 79.21, 'eve': 84.65, 'morn': 72.66},
#     'pressure': 1012,
#     'humidity': 39,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 8.9,
#     'deg': 287,
#     'gust': 10.22,
#     'clouds': 13,
#     'pop': 0.96,
#     'rain': 3.17},
#    {'dt': 1633546800,
#     'sunrise': 1633526704,
#     'sunset': 1633568699,
#     'temp': {'day': 83.62,
#      'min': 74.26,
#      'max': 88.84,
#      'night': 81.41,
#      'eve': 88.84,
#      'morn': 74.26},
#     'feels_like': {'day': 82.63, 'night': 80.08, 'eve': 85.35, 'morn': 74.03},
#     'pressure': 1013,
#     'humidity': 38,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 7.78,
#     'deg': 70,
#     'gust': 10.16,
#     'clouds': 1,
#     'pop': 0.16},
#    {'dt': 1633633200,
#     'sunrise': 1633613147,
#     'sunset': 1633655021,
#     'temp': {'day': 85.06,
#      'min': 77.79,
#      'max': 88.2,
#      'night': 80.53,
#      'eve': 87.42,
#      'morn': 77.79},
#     'feels_like': {'day': 82.09, 'night': 78.91, 'eve': 83.86, 'morn': 76.87},
#     'pressure': 1012,
#     'humidity': 20,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 7.76,
#     'deg': 201,
#     'gust': 10.36,
#     'clouds': 100,
#     'pop': 0},
#    {'dt': 1633719600,
#     'sunrise': 1633699590,
#     'sunset': 1633741343,
#     'temp': {'day': 82.87,
#      'min': 73.36,
#      'max': 85.98,
#      'night': 75.27,
#      'eve': 84.74,
#      'morn': 73.36},
#     'feels_like': {'day': 80.46, 'night': 73.58, 'eve': 81.84, 'morn': 71.67},
#     'pressure': 1012,
#     'humidity': 20,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 12.86,
#     'deg': 251,
#     'gust': 15.03,
#     'clouds': 65,
#     'pop': 0},
#    {'dt': 1633806000,
#     'sunrise': 1633786034,
#     'sunset': 1633827665,
#     'temp': {'day': 78.94,
#      'min': 70.03,
#      'max': 82.71,
#      'night': 75.18,
#      'eve': 82.45,
#      'morn': 70.03},
#     'feels_like': {'day': 78.94, 'night': 73.53, 'eve': 80.02, 'morn': 68.14},
#     'pressure': 1012,
#     'humidity': 21,
#     'weather': [{'id': 803,
#       'main': 'Clouds',
#       'description': 'broken clouds',
#       'icon': '04d'}],
#     'speed': 7.78,
#     'deg': 274,
#     'gust': 8.21,
#     'clouds': 59,
#     'pop': 0},
#    {'dt': 1633892400,
#     'sunrise': 1633872478,
#     'sunset': 1633913988,
#     'temp': {'day': 80.53,
#      'min': 69.03,
#      'max': 85.55,
#      'night': 77.31,
#      'eve': 85.55,
#      'morn': 69.03},
#     'feels_like': {'day': 78.91, 'night': 75.63, 'eve': 82.29, 'morn': 67.05},
#     'pressure': 1014,
#     'humidity': 20,
#     'weather': [{'id': 800,
#       'main': 'Clear',
#       'description': 'sky is clear',
#       'icon': '01d'}],
#     'speed': 5.61,
#     'deg': 33,
#     'gust': 6.87,
#     'clouds': 0,
#     'pop': 0}]},
#  {'city': {'id': 4156404,
#    'name': 'Gainesville',
#    'coord': {'lon': -82.3248, 'lat': 29.6516},
#    'country': 'US',
#    'population': 124354,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 0.1337635,
#   'cnt': 7,
#   'list': [{'dt': 1633366800,
#     'sunrise': 1633346656,
#     'sunset': 1633389081,
#     'temp': {'day': 87.39,
#      'min': 69.84,
#      'max': 88.63,
#      'night': 74.5,
#      'eve': 78.58,
#      'morn': 69.84},
#     'feels_like': {'day': 87.12, 'night': 75.22, 'eve': 78.82, 'morn': 70.47},
#     'pressure': 1015,
#     'humidity': 40,
#     'weather': [{'id': 804,
#       'main': 'Clouds',
#       'description': 'overcast clouds',
#       'icon': '04d'}],
#     'speed': 6.89,
#     'deg': 101,
#     'gust': 17.92,
#     'clouds': 99,
#     'pop': 0.05},
#    {'dt': 1633453200,
#     'sunrise': 1633433090,
#     'sunset': 1633475409,
#     'temp': {'day': 85.77,
#      'min': 70.86,
#      'max': 85.77,
#      'night': 74.84,
#      'eve': 79.12,
#      'morn': 71.08},
#     'feels_like': {'day': 87.01, 'night': 75.83, 'eve': 79.12, 'morn': 72.01},
#     'pressure': 1016,
#     'humidity': 48,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 5.06,
#     'deg': 161,
#     'gust': 15.95,
#     'clouds': 98,
#     'pop': 0.51,
#     'rain': 0.26},
#    {'dt': 1633539600,
#     'sunrise': 1633519525,
#     'sunset': 1633561738,
#     'temp': {'day': 83.75,
#      'min': 72.45,
#      'max': 83.75,
#      'night': 72.45,
#      'eve': 74.79,
#      'morn': 72.86},
#     'feels_like': {'day': 87.64, 'night': 73.67, 'eve': 76.05, 'morn': 74.12},
#     'pressure': 1018,
#     'humidity': 62,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 6.71,
#     'deg': 60,
#     'gust': 20.6,
#     'clouds': 100,
#     'pop': 0.75,
#     'rain': 4.51},
#    {'dt': 1633626000,
#     'sunrise': 1633605960,
#     'sunset': 1633648068,
#     'temp': {'day': 92.59,
#      'min': 72.05,
#      'max': 92.59,
#      'night': 75.96,
#      'eve': 78.73,
#      'morn': 72.27},
#     'feels_like': {'day': 95.63, 'night': 77.34, 'eve': 78.73, 'morn': 73.71},
#     'pressure': 1016,
#     'humidity': 42,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 4.61,
#     'deg': 79,
#     'gust': 13.24,
#     'clouds': 17,
#     'pop': 0.38,
#     'rain': 1.4},
#    {'dt': 1633712400,
#     'sunrise': 1633692395,
#     'sunset': 1633734398,
#     'temp': {'day': 88.99,
#      'min': 71.89,
#      'max': 88.99,
#      'night': 71.89,
#      'eve': 75.38,
#      'morn': 73.78},
#     'feels_like': {'day': 92.75, 'night': 73.2, 'eve': 76.42, 'morn': 75.04},
#     'pressure': 1015,
#     'humidity': 50,
#     'weather': [{'id': 501,
#       'main': 'Rain',
#       'description': 'moderate rain',
#       'icon': '10d'}],
#     'speed': 4.5,
#     'deg': 108,
#     'gust': 12.17,
#     'clouds': 80,
#     'pop': 1,
#     'rain': 6.83},
#    {'dt': 1633798800,
#     'sunrise': 1633778831,
#     'sunset': 1633820729,
#     'temp': {'day': 89.85,
#      'min': 68.94,
#      'max': 89.85,
#      'night': 72.88,
#      'eve': 75.54,
#      'morn': 69.66},
#     'feels_like': {'day': 91.87, 'night': 73.9, 'eve': 76.51, 'morn': 70.47},
#     'pressure': 1014,
#     'humidity': 44,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 4.36,
#     'deg': 74,
#     'gust': 9.82,
#     'clouds': 40,
#     'pop': 1,
#     'rain': 1.28},
#    {'dt': 1633885200,
#     'sunrise': 1633865267,
#     'sunset': 1633907060,
#     'temp': {'day': 89.71,
#      'min': 70.99,
#      'max': 89.71,
#      'night': 75.88,
#      'eve': 79.34,
#      'morn': 70.99},
#     'feels_like': {'day': 89.64, 'night': 76.69, 'eve': 79.34, 'morn': 72.01},
#     'pressure': 1015,
#     'humidity': 38,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 8.61,
#     'deg': 82,
#     'gust': 18.92,
#     'clouds': 21,
#     'pop': 0.08}]},
#  {'city': {'id': 4168782,
#    'name': 'Plantation',
#    'coord': {'lon': -80.2318, 'lat': 26.1342},
#    'country': 'US',
#    'population': 84955,
#    'timezone': -14400},
#   'cod': '200',
#   'message': 16.765605,
#   'cnt': 7,
#   'list': [{'dt': 1633366800,
#     'sunrise': 1633346076,
#     'sunset': 1633388657,
#     'temp': {'day': 87.15,
#      'min': 79.59,
#      'max': 87.78,
#      'night': 81.72,
#      'eve': 81.48,
#      'morn': 79.59},
#     'feels_like': {'day': 88.72, 'night': 85.32, 'eve': 86.9, 'morn': 79.59},
#     'pressure': 1014,
#     'humidity': 47,
#     'weather': [{'id': 801,
#       'main': 'Clouds',
#       'description': 'few clouds',
#       'icon': '02d'}],
#     'speed': 12.12,
#     'deg': 94,
#     'gust': 11.9,
#     'clouds': 17,
#     'pop': 0.06},
#    {'dt': 1633453200,
#     'sunrise': 1633432503,
#     'sunset': 1633474993,
#     'temp': {'day': 87.55,
#      'min': 79.99,
#      'max': 88.16,
#      'night': 82.63,
#      'eve': 83.59,
#      'morn': 79.99},
#     'feels_like': {'day': 91.36, 'night': 86.68, 'eve': 87.1, 'morn': 79.99},
#     'pressure': 1015,
#     'humidity': 53,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 12.19,
#     'deg': 85,
#     'gust': 16.37,
#     'clouds': 52,
#     'pop': 0.45,
#     'rain': 0.57},
#    {'dt': 1633539600,
#     'sunrise': 1633518930,
#     'sunset': 1633561329,
#     'temp': {'day': 88.65,
#      'min': 80.6,
#      'max': 88.65,
#      'night': 82.9,
#      'eve': 83.95,
#      'morn': 80.6},
#     'feels_like': {'day': 93.36, 'night': 87.93, 'eve': 88.54, 'morn': 84.87},
#     'pressure': 1016,
#     'humidity': 53,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 11.9,
#     'deg': 89,
#     'gust': 15.7,
#     'clouds': 46,
#     'pop': 0.45,
#     'rain': 0.58},
#    {'dt': 1633626000,
#     'sunrise': 1633605357,
#     'sunset': 1633647666,
#     'temp': {'day': 89.47,
#      'min': 81.36,
#      'max': 89.47,
#      'night': 82.92,
#      'eve': 84.16,
#      'morn': 81.95},
#     'feels_like': {'day': 94.5, 'night': 88.23, 'eve': 89.87, 'morn': 87.01},
#     'pressure': 1016,
#     'humidity': 52,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 11.5,
#     'deg': 104,
#     'gust': 13.31,
#     'clouds': 16,
#     'pop': 0.43,
#     'rain': 0.53},
#    {'dt': 1633712400,
#     'sunrise': 1633691785,
#     'sunset': 1633734003,
#     'temp': {'day': 89.58,
#      'min': 81.63,
#      'max': 89.58,
#      'night': 83.1,
#      'eve': 84.25,
#      'morn': 81.68},
#     'feels_like': {'day': 93.83, 'night': 87.53, 'eve': 88.52, 'morn': 86.68},
#     'pressure': 1014,
#     'humidity': 50,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 11.16,
#     'deg': 97,
#     'gust': 11.34,
#     'clouds': 92,
#     'pop': 0.5,
#     'rain': 0.37},
#    {'dt': 1633798800,
#     'sunrise': 1633778214,
#     'sunset': 1633820341,
#     'temp': {'day': 90.19,
#      'min': 80.94,
#      'max': 90.19,
#      'night': 81.48,
#      'eve': 83.64,
#      'morn': 80.94},
#     'feels_like': {'day': 93.63, 'night': 85.1, 'eve': 86.94, 'morn': 85.03},
#     'pressure': 1013,
#     'humidity': 47,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 10.96,
#     'deg': 64,
#     'gust': 12.08,
#     'clouds': 10,
#     'pop': 0.96,
#     'rain': 5.58},
#    {'dt': 1633885200,
#     'sunrise': 1633864642,
#     'sunset': 1633906680,
#     'temp': {'day': 87.49,
#      'min': 79.88,
#      'max': 87.49,
#      'night': 81.57,
#      'eve': 82.6,
#      'morn': 80.1},
#     'feels_like': {'day': 90.55, 'night': 85.06, 'eve': 85.95, 'morn': 83.5},
#     'pressure': 1014,
#     'humidity': 51,
#     'weather': [{'id': 500,
#       'main': 'Rain',
#       'description': 'light rain',
#       'icon': '10d'}],
#     'speed': 12.97,
#     'deg': 72,
#     'gust': 12.8,
#     'clouds': 20,
#     'pop': 0.96,
#     'rain': 3.7}]}]

# %%
#Check legth ofw weather data
len(weather_json)
# Out:
# 211

# %%
#Write out json to text file 
with open ('7_day_weather_data.txt', 'w') as convert_file:
    convert_file.write(json.dumps(weather_json))
