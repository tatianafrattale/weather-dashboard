# %%
#Import dependencies 
import pandas as pd
import numpy as np
import requests
import json

# %%
# List of cities for API calls 
cities_list = ["Montgomery", "Juneau", "Phoenix", "Odessa", "Sacramento", "Denver", "Hartford", "Dover", "Tallahassee", "Atlanta", "Honolulu", "Boise",
          "Springfield", "Indianapolis", "Allen", "Topeka", "Frankfort", "Chesapeake", "Augusta", "Annapolis", "Boston", "Lansing", "Passaic",
          "Jackson", "Roanoke", "Helena", "Lincoln", "Lynchburg", "Concord", "Trenton", "Albuquerque", "Albany", "Raleigh", "Bismarck, Columbus",
          "Auburn", "Salem", "Harrisburg", "Providence", "Columbia", "Pierre", "Nashville", "Austin", "Provo", "Montpelier", "Richmond", "Olympia",
          "Charleston", "Madison, Cheyenne", "Mobile", "Huntsville", "Tucson", "Mesa", "Scottsdale", "Fayetteville", "Jonesboro", "Norfolk",
          "Bakersfield", "Stockton", "Greeley, Westminster", "Aurora", "Loveland", "Stamford", "Norwalk", "Wilmington", "Jacksonville",
          "Miami", "Tampa", "Orlando", "Hollywood", "Lawrence", "Flint", "Troy", "Wyoming", "Duluth", "Plymouth", "Omaha", "Henderson", "Nashua",
          "Clifton", "Elizabeth", "Buffalo", "Rochester", "Yonkers", "Schenectady", "Durham", "Charlotte", "Greensboro", "Asheville", "Gastonia",
          "Akron", "Parma", "Tulsa", "Edmond", "Salem", "Beaverton", "Scranton", "Chattanooga", "Houston", "Dallas", "Arlington", "Plano", "Mesquite",
          "Brownsville", "Pasadena", "Waco", "Carrollton", "Milwaukee", "Tyler", "Murfreesboro", "Pawtucket", "Erie", "Beaverton", "Canton", 
          "Lawton", "Cleveland", "Cincinnati", "Danbury", "Camden", "Newark", "Manchester", "Sparks", "Missoula", "Billings", "Independence", 
          "Gulfport", "Minneapolis", "Southfield", "Kalamazoo", "Westland", "Dearborn", "Somerville", "Newton", "Worcester", "Cambridge", "Lafayette",
          "Kenner", "Shreveport", "Brockton", "Quincy", "Olathe", "Wichita", "Waterloo", "Davenport", "Muncie", "Fishers", "Gary", "Hammond","Bloomington",
          "Palatine", "Joliet", "Rockford", "Chicago", "Peoria", "Elgin", "Roswell", "Macon", "Savannah", "Lauderhill", "Melbourne", "Largo", "Clearwater",
          "Miramar", "Hialeah", "Waterbury", "Longmont", "Boulder", "Centennial", "Arvada", "Pueblo", "Thornton", "Lakewood", "Napa", "Tracy", "Alhambra",
          "Temecula", "Antioch", "Burbank", "Murrieta", "Fairfield", "Carlsbad", "Inglewood", "Downey", "Victorville", "Vallejo", "Roseville", "Visalia",
          "Sunnyvale", "Escondido", "Hayward", "Torrance", "Pomona", "Salinas", "Corona", "Glendale", "Irvine", "Oceanside", "Fontana", "Oxnard", "Modesto",
          "Fremont", "Anaheim", "Oakland", "Fresno", "Springdale", "Avondale", "Yuma", "Surprise", "Tempe", "Gilbert", "Gainesville", "Plantation"]

# %%
# API url template
#api.openweathermap.org/data/2.5/weather?q=atlanta&appid=a6501ad09aae11365e9abba37620e112
url = "https://api.openweathermap.org/data/2.5/weather?q="
api_key = "&cnt=7&units=imperial&appid=a6501ad09aae11365e9abba37620e112"

# %%
#Iterate through cities list for API Calls
weather_json= []

for city in cities_list: 
    
    api_url = url +city+ api_key
    weather_data = requests.get(api_url).json()
    
    if "name"  in weather_data: 
        weather_json.append(weather_data)


# Check weather data
weather_json
# Out:
# [{'coord': {'lon': -77.1997, 'lat': 39.1501},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 71.42,
#    'feels_like': 70.75,
#    'temp_min': 67.39,
#    'temp_max': 74.95,
#    'pressure': 1018,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 7, 'deg': 337, 'gust': 11.99},
#   'clouds': {'all': 20},
#   'dt': 1633028977,
#   'sys': {'type': 2,
#    'id': 2001892,
#    'country': 'US',
#    'sunrise': 1632999838,
#    'sunset': 1633042396},
#   'timezone': -14400,
#   'id': 4362716,
#   'name': 'Montgomery',
#   'cod': 200},
#  {'coord': {'lon': -134.4197, 'lat': 58.3019},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 46.45,
#    'feels_like': 46.45,
#    'temp_min': 45.1,
#    'temp_max': 47.84,
#    'pressure': 997,
#    'humidity': 95},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'rain': {'1h': 0.65},
#   'clouds': {'all': 90},
#   'dt': 1633028978,
#   'sys': {'type': 2,
#    'id': 2012911,
#    'country': 'US',
#    'sunrise': 1633014042,
#    'sunset': 1633055651},
#   'timezone': -28800,
#   'id': 5554072,
#   'name': 'Juneau',
#   'cod': 200},
#  {'coord': {'lon': -112.074, 'lat': 33.4484},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 85.01,
#    'feels_like': 83.37,
#    'temp_min': 81.14,
#    'temp_max': 88.38,
#    'pressure': 1012,
#    'humidity': 34},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 146, 'gust': 7},
#   'clouds': {'all': 20},
#   'dt': 1633028685,
#   'sys': {'type': 2,
#    'id': 2008537,
#    'country': 'US',
#    'sunrise': 1633008121,
#    'sunset': 1633050849},
#   'timezone': -25200,
#   'id': 5308655,
#   'name': 'Phoenix',
#   'cod': 200},
#  {'coord': {'lon': 30.7326, 'lat': 46.4775},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 53.53,
#    'feels_like': 51.12,
#    'temp_min': 52.92,
#    'temp_max': 53.53,
#    'pressure': 1029,
#    'humidity': 54},
#   'visibility': 10000,
#   'wind': {'speed': 8.95, 'deg': 60},
#   'clouds': {'all': 0},
#   'dt': 1633028978,
#   'sys': {'type': 1,
#    'id': 8915,
#    'country': 'UA',
#    'sunrise': 1632974049,
#    'sunset': 1633016390},
#   'timezone': 10800,
#   'id': 698740,
#   'name': 'Odesa',
#   'cod': 200},
#  {'coord': {'lon': -121.3177, 'lat': 38.4666},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.46,
#    'feels_like': 77.5,
#    'temp_min': 73.92,
#    'temp_max': 86.18,
#    'pressure': 1016,
#    'humidity': 32},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 223, 'gust': 4},
#   'clouds': {'all': 1},
#   'dt': 1633028910,
#   'sys': {'type': 2,
#    'id': 2002655,
#    'country': 'US',
#    'sunrise': 1633010422,
#    'sunset': 1633052984},
#   'timezone': -25200,
#   'id': 5389519,
#   'name': 'Sacramento',
#   'cod': 200},
#  {'coord': {'lon': -104.9847, 'lat': 39.7392},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 53.26,
#    'feels_like': 51.21,
#    'temp_min': 47.7,
#    'temp_max': 60.33,
#    'pressure': 1024,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 23, 'gust': 4},
#   'clouds': {'all': 93},
#   'dt': 1633028979,
#   'sys': {'type': 2,
#    'id': 2004334,
#    'country': 'US',
#    'sunrise': 1633006521,
#    'sunset': 1633049047},
#   'timezone': -21600,
#   'id': 5419384,
#   'name': 'Denver',
#   'cod': 200},
#  {'coord': {'lon': -72.7662, 'lat': 41.7668},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 60.31,
#    'feels_like': 59,
#    'temp_min': 57.34,
#    'temp_max': 63.41,
#    'pressure': 1017,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 334, 'gust': 5.01},
#   'clouds': {'all': 90},
#   'dt': 1633028736,
#   'sys': {'type': 2,
#    'id': 2007105,
#    'country': 'US',
#    'sunrise': 1632998819,
#    'sunset': 1633041287},
#   'timezone': -14400,
#   'id': 4835806,
#   'name': 'Hartford',
#   'cod': 200},
#  {'coord': {'lon': -75.5244, 'lat': 39.1582},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 70.56,
#    'feels_like': 69.76,
#    'temp_min': 66.42,
#    'temp_max': 73.49,
#    'pressure': 1018,
#    'humidity': 52},
#   'visibility': 10000,
#   'wind': {'speed': 12.66, 'deg': 290},
#   'clouds': {'all': 20},
#   'dt': 1633028980,
#   'sys': {'type': 1,
#    'id': 3847,
#    'country': 'US',
#    'sunrise': 1632999436,
#    'sunset': 1633041994},
#   'timezone': -14400,
#   'id': 4142290,
#   'name': 'Dover',
#   'cod': 200},
#  {'coord': {'lon': -84.2807, 'lat': 30.4383},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 87.26,
#    'feels_like': 92.77,
#    'temp_min': 84.67,
#    'temp_max': 89.01,
#    'pressure': 1017,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 63, 'gust': 1.01},
#   'clouds': {'all': 75},
#   'dt': 1633028721,
#   'sys': {'type': 2,
#    'id': 2006015,
#    'country': 'US',
#    'sunrise': 1633001403,
#    'sunset': 1633044229},
#   'timezone': -14400,
#   'id': 4174715,
#   'name': 'Tallahassee',
#   'cod': 200},
#  {'coord': {'lon': -84.388, 'lat': 33.749},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 81.75,
#    'feels_like': 83.91,
#    'temp_min': 78.42,
#    'temp_max': 84.96,
#    'pressure': 1020,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 218, 'gust': 3},
#   'clouds': {'all': 1},
#   'dt': 1633028728,
#   'sys': {'type': 2,
#    'id': 2041852,
#    'country': 'US',
#    'sunrise': 1633001478,
#    'sunset': 1633044206},
#   'timezone': -14400,
#   'id': 4180439,
#   'name': 'Atlanta',
#   'cod': 200},
#  {'coord': {'lon': -157.8583, 'lat': 21.3069},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 80.33,
#    'feels_like': 83.23,
#    'temp_min': 76.89,
#    'temp_max': 82.22,
#    'pressure': 1016,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 6.91, 'deg': 60},
#   'rain': {'1h': 0.12},
#   'clouds': {'all': 40},
#   'dt': 1633028789,
#   'sys': {'type': 2,
#    'id': 2010198,
#    'country': 'US',
#    'sunrise': 1633018942,
#    'sunset': 1633061999},
#   'timezone': -36000,
#   'id': 5856195,
#   'name': 'Honolulu',
#   'cod': 200},
#  {'coord': {'lon': -116.2035, 'lat': 43.6135},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 63.77,
#    'feels_like': 61.59,
#    'temp_min': 60.42,
#    'temp_max': 67.39,
#    'pressure': 1026,
#    'humidity': 37},
#   'visibility': 10000,
#   'wind': {'speed': 10.36, 'deg': 160},
#   'clouds': {'all': 1},
#   'dt': 1633028714,
#   'sys': {'type': 2,
#    'id': 2037734,
#    'country': 'US',
#    'sunrise': 1633009287,
#    'sunset': 1633051665},
#   'timezone': -21600,
#   'id': 5586437,
#   'name': 'Boise',
#   'cod': 200},
#  {'coord': {'lon': -93.2982, 'lat': 37.2153},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 78.78,
#    'feels_like': 78.78,
#    'temp_min': 71.96,
#    'temp_max': 83.35,
#    'pressure': 1016,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 11.99, 'deg': 99, 'gust': 25.99},
#   'clouds': {'all': 20},
#   'dt': 1633028940,
#   'sys': {'type': 2,
#    'id': 2016620,
#    'country': 'US',
#    'sunrise': 1633003672,
#    'sunset': 1633046287},
#   'timezone': -18000,
#   'id': 4409896,
#   'name': 'Springfield',
#   'cod': 200},
#  {'coord': {'lon': -86.158, 'lat': 39.7684},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 79.65,
#    'feels_like': 79.65,
#    'temp_min': 77.05,
#    'temp_max': 83.21,
#    'pressure': 1021,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 130},
#   'clouds': {'all': 75},
#   'dt': 1633028758,
#   'sys': {'type': 2,
#    'id': 2002558,
#    'country': 'US',
#    'sunrise': 1633002000,
#    'sunset': 1633044533},
#   'timezone': -14400,
#   'id': 4259418,
#   'name': 'Indianapolis',
#   'cod': 200},
#  {'coord': {'lon': -85.0144, 'lat': 41.0706},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 75,
#    'feels_like': 73.99,
#    'temp_min': 72.3,
#    'temp_max': 77.45,
#    'pressure': 1023,
#    'humidity': 38},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 90},
#   'clouds': {'all': 75},
#   'dt': 1633028763,
#   'sys': {'type': 1,
#    'id': 4161,
#    'country': 'US',
#    'sunrise': 1633001749,
#    'sunset': 1633044236},
#   'timezone': -14400,
#   'id': 4917555,
#   'name': 'Allen',
#   'cod': 200},
#  {'coord': {'lon': -95.678, 'lat': 39.0483},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.21,
#    'feels_like': 79.07,
#    'temp_min': 76.69,
#    'temp_max': 82.71,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1633028862,
#   'sys': {'type': 1,
#    'id': 6052,
#    'country': 'US',
#    'sunrise': 1633004274,
#    'sunset': 1633046827},
#   'timezone': -18000,
#   'id': 4280539,
#   'name': 'Topeka',
#   'cod': 200},
#  {'coord': {'lon': 28.4833, 'lat': -27.2667},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 62.19,
#    'feels_like': 61.34,
#    'temp_min': 62.19,
#    'temp_max': 62.19,
#    'pressure': 1017,
#    'humidity': 69,
#    'sea_level': 1017,
#    'grnd_level': 853},
#   'visibility': 9241,
#   'wind': {'speed': 11.9, 'deg': 4, 'gust': 25.97},
#   'rain': {'1h': 0.35},
#   'clouds': {'all': 100},
#   'dt': 1633028982,
#   'sys': {'country': 'ZA', 'sunrise': 1632973582, 'sunset': 1633017936},
#   'timezone': 7200,
#   'id': 1003764,
#   'name': 'Frankfort',
#   'cod': 200},
#  {'coord': {'lon': -76.2749, 'lat': 36.819},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 76.48,
#    'feels_like': 75.85,
#    'temp_min': 72.97,
#    'temp_max': 80.02,
#    'pressure': 1018,
#    'humidity': 43},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 296, 'gust': 8.01},
#   'clouds': {'all': 1},
#   'dt': 1633028982,
#   'sys': {'type': 2,
#    'id': 2040363,
#    'country': 'US',
#    'sunrise': 1632999578,
#    'sunset': 1633042213},
#   'timezone': -14400,
#   'id': 4752186,
#   'name': 'Chesapeake',
#   'cod': 200},
#  {'coord': {'lon': 10.8833, 'lat': 48.3667},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 46.85,
#    'feels_like': 46.85,
#    'temp_min': 41.31,
#    'temp_max': 51.62,
#    'pressure': 1027,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 2.3, 'deg': 40},
#   'clouds': {'all': 0},
#   'dt': 1633028704,
#   'sys': {'type': 1,
#    'id': 1308,
#    'country': 'DE',
#    'sunrise': 1632978856,
#    'sunset': 1633021109},
#   'timezone': 7200,
#   'id': 2954172,
#   'name': 'Augsburg',
#   'cod': 200},
#  {'coord': {'lon': -76.4922, 'lat': 38.9785},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 72.55,
#    'feels_like': 72.09,
#    'temp_min': 68.56,
#    'temp_max': 76.32,
#    'pressure': 1018,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1633028704,
#   'sys': {'type': 1,
#    'id': 5056,
#    'country': 'US',
#    'sunrise': 1632999666,
#    'sunset': 1633042229},
#   'timezone': -14400,
#   'id': 4347242,
#   'name': 'Annapolis',
#   'cod': 200},
#  {'coord': {'lon': -71.0598, 'lat': 42.3584},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 59.13,
#    'feels_like': 57.65,
#    'temp_min': 56.16,
#    'temp_max': 62.22,
#    'pressure': 1017,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 325, 'gust': 15.01},
#   'clouds': {'all': 100},
#   'dt': 1633028940,
#   'sys': {'type': 2,
#    'id': 2013408,
#    'country': 'US',
#    'sunrise': 1632998420,
#    'sunset': 1633040867},
#   'timezone': -14400,
#   'id': 4930956,
#   'name': 'Boston',
#   'cod': 200},
#  {'coord': {'lon': -84.5555, 'lat': 42.7325},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 71.78,
#    'feels_like': 71.24,
#    'temp_min': 68.86,
#    'temp_max': 74.3,
#    'pressure': 1023,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1633028914,
#   'sys': {'type': 1,
#    'id': 4665,
#    'country': 'US',
#    'sunrise': 1633001669,
#    'sunset': 1633044095},
#   'timezone': -14400,
#   'id': 4998830,
#   'name': 'Lansing',
#   'cod': 200},
#  {'coord': {'lon': -74.3657, 'lat': 41.0668},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 61.39,
#    'feels_like': 59.92,
#    'temp_min': 57.76,
#    'temp_max': 64.9,
#    'pressure': 1018,
#    'humidity': 57,
#    'sea_level': 1018,
#    'grnd_level': 981},
#   'visibility': 10000,
#   'wind': {'speed': 8.59, 'deg': 327, 'gust': 12.57},
#   'clouds': {'all': 79},
#   'dt': 1633028837,
#   'sys': {'type': 2,
#    'id': 2002024,
#    'country': 'US',
#    'sunrise': 1632999191,
#    'sunset': 1633041683},
#   'timezone': -14400,
#   'id': 5102445,
#   'name': 'Passaic',
#   'cod': 200},
#  {'coord': {'lon': -122.8345, 'lat': 42.4165},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 62.47,
#    'feels_like': 60.67,
#    'temp_min': 61.75,
#    'temp_max': 62.47,
#    'pressure': 1022,
#    'humidity': 48},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1633028770,
#   'sys': {'type': 1,
#    'id': 4869,
#    'country': 'US',
#    'sunrise': 1633010857,
#    'sunset': 1633053277},
#   'timezone': -25200,
#   'id': 5733351,
#   'name': 'Jackson',
#   'cod': 200},
#  {'coord': {'lon': -79.9414, 'lat': 37.271},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 78.46,
#    'feels_like': 78.12,
#    'temp_min': 74.75,
#    'temp_max': 81.63,
#    'pressure': 1020,
#    'humidity': 45},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 322, 'gust': 8.99},
#   'clouds': {'all': 40},
#   'dt': 1633028881,
#   'sys': {'type': 2,
#    'id': 2031082,
#    'country': 'US',
#    'sunrise': 1633000466,
#    'sunset': 1633043084},
#   'timezone': -14400,
#   'id': 4782167,
#   'name': 'Roanoke',
#   'cod': 200},
#  {'coord': {'lon': -112.0361, 'lat': 46.5927},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 63.01,
#    'feels_like': 60.42,
#    'temp_min': 60.19,
#    'temp_max': 69.24,
#    'pressure': 1026,
#    'humidity': 30},
#   'visibility': 10000,
#   'wind': {'speed': 5.99, 'deg': 82, 'gust': 8.99},
#   'clouds': {'all': 1},
#   'dt': 1633028984,
#   'sys': {'type': 2,
#    'id': 2033674,
#    'country': 'US',
#    'sunrise': 1633008346,
#    'sunset': 1633050605},
#   'timezone': -21600,
#   'id': 5656882,
#   'name': 'Helena',
#   'cod': 200},
#  {'coord': {'lon': -96.667, 'lat': 40.8},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 77.11,
#    'feels_like': 77.95,
#    'temp_min': 74.25,
#    'temp_max': 83.66,
#    'pressure': 1016,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 248, 'gust': 7},
#   'clouds': {'all': 20},
#   'dt': 1633028944,
#   'sys': {'type': 2,
#    'id': 2007392,
#    'country': 'US',
#    'sunrise': 1633004542,
#    'sunset': 1633047034},
#   'timezone': -18000,
#   'id': 5072006,
#   'name': 'Lincoln',
#   'cod': 200},
#  {'coord': {'lon': -79.1423, 'lat': 37.4138},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 77.77,
#    'feels_like': 77.83,
#    'temp_min': 75.18,
#    'temp_max': 80.28,
#    'pressure': 1020,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1633028696,
#   'sys': {'type': 1,
#    'id': 4798,
#    'country': 'US',
#    'sunrise': 1633000276,
#    'sunset': 1633042890},
#   'timezone': -14400,
#   'id': 4771075,
#   'name': 'Lynchburg',
#   'cod': 200},
#  {'coord': {'lon': -122.0311, 'lat': 37.978},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.76,
#    'feels_like': 78.76,
#    'temp_min': 70.23,
#    'temp_max': 85.24,
#    'pressure': 1015,
#    'humidity': 25},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 0, 'gust': 5.99},
#   'clouds': {'all': 1},
#   'dt': 1633028902,
#   'sys': {'type': 2,
#    'id': 2009331,
#    'country': 'US',
#    'sunrise': 1633010585,
#    'sunset': 1633053163},
#   'timezone': -25200,
#   'id': 5339111,
#   'name': 'Concord',
#   'cod': 200},
#  {'coord': {'lon': -74.7429, 'lat': 40.217},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 66.87,
#    'feels_like': 65.61,
#    'temp_min': 63.88,
#    'temp_max': 69.94,
#    'pressure': 1016,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 308, 'gust': 4},
#   'clouds': {'all': 90},
#   'dt': 1633028759,
#   'sys': {'type': 2,
#    'id': 2021152,
#    'country': 'US',
#    'sunrise': 1632999267,
#    'sunset': 1633041788},
#   'timezone': -14400,
#   'id': 5105496,
#   'name': 'Trenton',
#   'cod': 200},
#  {'coord': {'lon': -106.6511, 'lat': 35.0845},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 57.97,
#    'feels_like': 57.04,
#    'temp_min': 53.4,
#    'temp_max': 61.48,
#    'pressure': 1022,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 12.66, 'deg': 110},
#   'rain': {'1h': 1},
#   'clouds': {'all': 90},
#   'dt': 1633028986,
#   'sys': {'type': 1,
#    'id': 3205,
#    'country': 'US',
#    'sunrise': 1633006844,
#    'sunset': 1633049523},
#   'timezone': -21600,
#   'id': 5454711,
#   'name': 'Albuquerque',
#   'cod': 200},
#  {'coord': {'lon': -73.9662, 'lat': 42.6001},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 56.52,
#    'feels_like': 55.02,
#    'temp_min': 53.62,
#    'temp_max': 59.04,
#    'pressure': 1017,
#    'humidity': 67},
#   'visibility': 10000,
#   'wind': {'speed': 7.81, 'deg': 320, 'gust': 12.55},
#   'clouds': {'all': 95},
#   'dt': 1633028986,
#   'sys': {'type': 2,
#    'id': 19530,
#    'country': 'US',
#    'sunrise': 1632999123,
#    'sunset': 1633041560},
#   'timezone': -14400,
#   'id': 5106841,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': -78.6386, 'lat': 35.7721},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 78.28,
#    'feels_like': 78.76,
#    'temp_min': 75,
#    'temp_max': 81.19,
#    'pressure': 1019,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 80},
#   'clouds': {'all': 75},
#   'dt': 1633028695,
#   'sys': {'type': 2,
#    'id': 2033469,
#    'country': 'US',
#    'sunrise': 1633000129,
#    'sunset': 1633042796},
#   'timezone': -14400,
#   'id': 4487042,
#   'name': 'Raleigh',
#   'cod': 200},
#  {'coord': {'lon': -100.7837, 'lat': 46.8083},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 72.34,
#    'feels_like': 71.15,
#    'temp_min': 69.82,
#    'temp_max': 75.04,
#    'pressure': 1022,
#    'humidity': 40},
#   'visibility': 10000,
#   'wind': {'speed': 9.22, 'deg': 340, 'gust': 19.57},
#   'clouds': {'all': 90},
#   'dt': 1633028987,
#   'sys': {'type': 1,
#    'id': 3441,
#    'country': 'US',
#    'sunrise': 1633005648,
#    'sunset': 1633047904},
#   'timezone': -18000,
#   'id': 5688025,
#   'name': 'Bismarck',
#   'cod': 200},
#  {'coord': {'lon': -122.2284, 'lat': 47.3073},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 57.15,
#    'feels_like': 56.79,
#    'temp_min': 53.83,
#    'temp_max': 60.21,
#    'pressure': 1023,
#    'humidity': 90},
#   'visibility': 10000,
#   'wind': {'speed': 8.01, 'deg': 203, 'gust': 15.01},
#   'rain': {'1h': 0.27},
#   'clouds': {'all': 90},
#   'dt': 1633028704,
#   'sys': {'type': 2,
#    'id': 2002678,
#    'country': 'US',
#    'sunrise': 1633010810,
#    'sunset': 1633053033},
#   'timezone': -25200,
#   'id': 5785965,
#   'name': 'Auburn',
#   'cod': 200},
#  {'coord': {'lon': 78.1667, 'lat': 11.65},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 73.63,
#    'feels_like': 75.16,
#    'temp_min': 73.63,
#    'temp_max': 73.63,
#    'pressure': 1010,
#    'humidity': 95,
#    'sea_level': 1010,
#    'grnd_level': 977},
#   'visibility': 6446,
#   'wind': {'speed': 1.59, 'deg': 174, 'gust': 3.02},
#   'clouds': {'all': 100},
#   'dt': 1633028801,
#   'sys': {'country': 'IN', 'sunrise': 1633048571, 'sunset': 1633091864},
#   'timezone': 19800,
#   'id': 1257629,
#   'name': 'Salem',
#   'cod': 200},
#  {'coord': {'lon': -76.8844, 'lat': 40.2737},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 65.43,
#    'feels_like': 64.29,
#    'temp_min': 62.91,
#    'temp_max': 68.67,
#    'pressure': 1019,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 310, 'gust': 10},
#   'clouds': {'all': 75},
#   'dt': 1633028848,
#   'sys': {'type': 2,
#    'id': 2001523,
#    'country': 'US',
#    'sunrise': 1632999782,
#    'sunset': 1633042301},
#   'timezone': -14400,
#   'id': 5192726,
#   'name': 'Harrisburg',
#   'cod': 200},
#  {'coord': {'lon': -71.4128, 'lat': 41.824},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 60.87,
#    'feels_like': 59.34,
#    'temp_min': 56.93,
#    'temp_max': 64.04,
#    'pressure': 1013,
#    'humidity': 57},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 77, 'gust': 15.01},
#   'clouds': {'all': 90},
#   'dt': 1633028988,
#   'sys': {'type': 2,
#    'id': 2007908,
#    'country': 'US',
#    'sunrise': 1632998495,
#    'sunset': 1633040962},
#   'timezone': -14400,
#   'id': 5224151,
#   'name': 'Providence',
#   'cod': 200},
#  {'coord': {'lon': -81.0348, 'lat': 34.0007},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 87.78,
#    'feels_like': 89.67,
#    'temp_min': 84.15,
#    'temp_max': 90.54,
#    'pressure': 1017,
#    'humidity': 47},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 328, 'gust': 3},
#   'clouds': {'all': 75},
#   'dt': 1633028804,
#   'sys': {'type': 2,
#    'id': 2037653,
#    'country': 'US',
#    'sunrise': 1633000677,
#    'sunset': 1633043398},
#   'timezone': -14400,
#   'id': 4575352,
#   'name': 'Columbia',
#   'cod': 200},
#  {'coord': {'lon': -100.351, 'lat': 44.3683},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 63.52,
#    'feels_like': 62.35,
#    'temp_min': 63.52,
#    'temp_max': 66.99,
#    'pressure': 1021,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 340},
#   'clouds': {'all': 90},
#   'dt': 1633028988,
#   'sys': {'type': 1,
#    'id': 5361,
#    'country': 'US',
#    'sunrise': 1633005494,
#    'sunset': 1633047850},
#   'timezone': -18000,
#   'id': 5767918,
#   'name': 'Pierre',
#   'cod': 200},
#  {'coord': {'lon': -86.7844, 'lat': 36.1659},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 83.55,
#    'feels_like': 85.39,
#    'temp_min': 79.79,
#    'temp_max': 86.34,
#    'pressure': 1011,
#    'humidity': 54},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 26, 'gust': 8.99},
#   'clouds': {'all': 1},
#   'dt': 1633028870,
#   'sys': {'type': 2,
#    'id': 2001447,
#    'country': 'US',
#    'sunrise': 1633002091,
#    'sunset': 1633044743},
#   'timezone': -18000,
#   'id': 4644585,
#   'name': 'Nashville',
#   'cod': 200},
#  {'coord': {'lon': -97.7431, 'lat': 30.2672},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 89.4,
#    'feels_like': 98.82,
#    'temp_min': 86.29,
#    'temp_max': 92.82,
#    'pressure': 1011,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 90, 'gust': 7},
#   'clouds': {'all': 40},
#   'dt': 1633028700,
#   'sys': {'type': 2,
#    'id': 2003218,
#    'country': 'US',
#    'sunrise': 1633004633,
#    'sunset': 1633047459},
#   'timezone': -18000,
#   'id': 4671654,
#   'name': 'Austin',
#   'cod': 200},
#  {'coord': {'lon': -111.6585, 'lat': 40.2338},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 59.74,
#    'feels_like': 57.38,
#    'temp_min': 57.02,
#    'temp_max': 69.48,
#    'pressure': 1024,
#    'humidity': 42},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 0},
#   'clouds': {'all': 40},
#   'dt': 1633028989,
#   'sys': {'type': 2,
#    'id': 2009866,
#    'country': 'US',
#    'sunrise': 1633008133,
#    'sunset': 1633050638},
#   'timezone': -21600,
#   'id': 5780026,
#   'name': 'Provo',
#   'cod': 200},
#  {'coord': {'lon': -72.5754, 'lat': 44.2601},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 54.36,
#    'feels_like': 52.5,
#    'temp_min': 49.98,
#    'temp_max': 58.1,
#    'pressure': 1020,
#    'humidity': 64},
#   'visibility': 10000,
#   'wind': {'speed': 10.36, 'deg': 300},
#   'clouds': {'all': 75},
#   'dt': 1633028990,
#   'sys': {'type': 1,
#    'id': 4960,
#    'country': 'US',
#    'sunrise': 1632998820,
#    'sunset': 1633041195},
#   'timezone': -14400,
#   'id': 5238685,
#   'name': 'Montpelier',
#   'cod': 200},
#  {'coord': {'lon': -77.4603, 'lat': 37.5538},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 76.26,
#    'feels_like': 75.65,
#    'temp_min': 72.1,
#    'temp_max': 80.26,
#    'pressure': 1020,
#    'humidity': 44},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 306, 'gust': 11.99},
#   'clouds': {'all': 40},
#   'dt': 1633028759,
#   'sys': {'type': 2,
#    'id': 2007417,
#    'country': 'US',
#    'sunrise': 1632999874,
#    'sunset': 1633042485},
#   'timezone': -14400,
#   'id': 4781708,
#   'name': 'Richmond',
#   'cod': 200},
#  {'coord': {'lon': -122.9007, 'lat': 47.0379},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 56.25,
#    'feels_like': 55.53,
#    'temp_min': 53.69,
#    'temp_max': 58.82,
#    'pressure': 1021,
#    'humidity': 84},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 289, 'gust': 4},
#   'rain': {'1h': 0.38},
#   'clouds': {'all': 90},
#   'dt': 1633028866,
#   'sys': {'type': 2,
#    'id': 2041693,
#    'country': 'US',
#    'sunrise': 1633010966,
#    'sunset': 1633053200},
#   'timezone': -25200,
#   'id': 5805687,
#   'name': 'Olympia',
#   'cod': 200},
#  {'coord': {'lon': -79.9309, 'lat': 32.7766},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.78,
#    'feels_like': 91.4,
#    'temp_min': 82.02,
#    'temp_max': 89.11,
#    'pressure': 1018,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 205, 'gust': 8.99},
#   'clouds': {'all': 1},
#   'dt': 1633028742,
#   'sys': {'type': 2,
#    'id': 2034523,
#    'country': 'US',
#    'sunrise': 1633000393,
#    'sunset': 1633043152},
#   'timezone': -14400,
#   'id': 4574324,
#   'name': 'Charleston',
#   'cod': 200},
#  {'coord': {'lon': -86.5667, 'lat': 34.7334},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 82.42,
#    'feels_like': 85.03,
#    'temp_min': 78.73,
#    'temp_max': 84.99,
#    'pressure': 1017,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 203, 'gust': 3},
#   'clouds': {'all': 75},
#   'dt': 1633028905,
#   'sys': {'type': 2,
#    'id': 2034804,
#    'country': 'US',
#    'sunrise': 1633002016,
#    'sunset': 1633044713},
#   'timezone': -18000,
#   'id': 4074277,
#   'name': 'Madison',
#   'cod': 200},
#  {'coord': {'lon': -88.2, 'lat': 30.7835},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 78.37,
#    'feels_like': 79.14,
#    'temp_min': 71.58,
#    'temp_max': 81.95,
#    'pressure': 1018,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 9.22, 'deg': 140},
#   'clouds': {'all': 75},
#   'dt': 1633028768,
#   'sys': {'type': 1,
#    'id': 4948,
#    'country': 'US',
#    'sunrise': 1633002349,
#    'sunset': 1633045164},
#   'timezone': -18000,
#   'id': 4076607,
#   'name': 'Mobile',
#   'cod': 200},
#  {'coord': {'lon': -86.5861, 'lat': 34.7304},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 82.9,
#    'feels_like': 85.77,
#    'temp_min': 79.16,
#    'temp_max': 85.44,
#    'pressure': 1017,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 116, 'gust': 5.01},
#   'clouds': {'all': 75},
#   'dt': 1633028991,
#   'sys': {'type': 2,
#    'id': 2009569,
#    'country': 'US',
#    'sunrise': 1633002021,
#    'sunset': 1633044718},
#   'timezone': -18000,
#   'id': 4068590,
#   'name': 'Huntsville',
#   'cod': 200},
#  {'coord': {'lon': -110.9265, 'lat': 32.2217},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 80.87,
#    'feels_like': 80.2,
#    'temp_min': 72.99,
#    'temp_max': 84.56,
#    'pressure': 1015,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 140, 'gust': 5.01},
#   'clouds': {'all': 1},
#   'dt': 1633028939,
#   'sys': {'type': 2,
#    'id': 2007774,
#    'country': 'US',
#    'sunrise': 1633007827,
#    'sunset': 1633050592},
#   'timezone': -25200,
#   'id': 5318313,
#   'name': 'Tucson',
#   'cod': 200},
#  {'coord': {'lon': -111.8226, 'lat': 33.4223},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.34,
#    'feels_like': 82.63,
#    'temp_min': 80.58,
#    'temp_max': 87.82,
#    'pressure': 1012,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 106, 'gust': 4},
#   'clouds': {'all': 1},
#   'dt': 1633028854,
#   'sys': {'type': 2,
#    'id': 2011301,
#    'country': 'US',
#    'sunrise': 1633008060,
#    'sunset': 1633050789},
#   'timezone': -25200,
#   'id': 5304391,
#   'name': 'Mesa',
#   'cod': 200},
#  {'coord': {'lon': -111.899, 'lat': 33.5092},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.56,
#    'feels_like': 82.96,
#    'temp_min': 81.3,
#    'temp_max': 87.76,
#    'pressure': 1013,
#    'humidity': 34},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 74, 'gust': 4},
#   'clouds': {'all': 1},
#   'dt': 1633028784,
#   'sys': {'type': 2,
#    'id': 2020223,
#    'country': 'US',
#    'sunrise': 1633008080,
#    'sunset': 1633050806},
#   'timezone': -25200,
#   'id': 5313457,
#   'name': 'Scottsdale',
#   'cod': 200},
#  {'coord': {'lon': -78.8784, 'lat': 35.0527},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.58,
#    'feels_like': 82.78,
#    'temp_min': 77.2,
#    'temp_max': 82.85,
#    'pressure': 1018,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 306, 'gust': 8.99},
#   'clouds': {'all': 90},
#   'dt': 1633028773,
#   'sys': {'type': 2,
#    'id': 2031362,
#    'country': 'US',
#    'sunrise': 1633000175,
#    'sunset': 1633042865},
#   'timezone': -14400,
#   'id': 4466033,
#   'name': 'Fayetteville',
#   'cod': 200},
#  {'coord': {'lon': -90.7043, 'lat': 35.8423},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 76.41,
#    'feels_like': 77.41,
#    'temp_min': 73.09,
#    'temp_max': 78.62,
#    'pressure': 1018,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 10, 'deg': 130},
#   'clouds': {'all': 75},
#   'dt': 1633028954,
#   'sys': {'type': 2,
#    'id': 47702,
#    'country': 'US',
#    'sunrise': 1633003027,
#    'sunset': 1633045688},
#   'timezone': -18000,
#   'id': 4116834,
#   'name': 'Jonesboro',
#   'cod': 200},
#  {'coord': {'lon': -71.2495, 'lat': 42.1668},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 59.11,
#    'feels_like': 57.69,
#    'temp_min': 55.89,
#    'temp_max': 62.85,
#    'pressure': 1016,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 93, 'gust': 8.99},
#   'clouds': {'all': 90},
#   'dt': 1633028993,
#   'sys': {'type': 2,
#    'id': 2002693,
#    'country': 'US',
#    'sunrise': 1632998462,
#    'sunset': 1633040916},
#   'timezone': -14400,
#   'id': 4945455,
#   'name': 'Norfolk',
#   'cod': 200},
#  {'coord': {'lon': -119.0187, 'lat': 35.3733},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 80.26,
#    'feels_like': 79.02,
#    'temp_min': 73.56,
#    'temp_max': 88.45,
#    'pressure': 1017,
#    'humidity': 25},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1633028889,
#   'sys': {'type': 1,
#    'id': 3419,
#    'country': 'US',
#    'sunrise': 1633009819,
#    'sunset': 1633052484},
#   'timezone': -25200,
#   'id': 5325738,
#   'name': 'Bakersfield',
#   'cod': 200},
#  {'coord': {'lon': -121.2908, 'lat': 37.9577},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 77.41,
#    'feels_like': 76.35,
#    'temp_min': 74.98,
#    'temp_max': 83.95,
#    'pressure': 1017,
#    'humidity': 32},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1633028927,
#   'sys': {'type': 1,
#    'id': 5789,
#    'country': 'US',
#    'sunrise': 1633010407,
#    'sunset': 1633052986},
#   'timezone': -25200,
#   'id': 5399020,
#   'name': 'Stockton',
#   'cod': 200},
#  {'coord': {'lon': -104.7091, 'lat': 40.4233},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 56.64,
#    'feels_like': 54.5,
#    'temp_min': 49.89,
#    'temp_max': 62.04,
#    'pressure': 1025,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 298, 'gust': 14},
#   'clouds': {'all': 1},
#   'dt': 1633028696,
#   'sys': {'type': 2,
#    'id': 2009345,
#    'country': 'US',
#    'sunrise': 1633006467,
#    'sunset': 1633048968},
#   'timezone': -21600,
#   'id': 5577592,
#   'name': 'Greeley',
#   'cod': 200},
#  {'coord': {'lon': -104.8319, 'lat': 39.7294},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 53.42,
#    'feels_like': 51.19,
#    'temp_min': 47.25,
#    'temp_max': 59.86,
#    'pressure': 1026,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 330},
#   'clouds': {'all': 90},
#   'dt': 1633028762,
#   'sys': {'type': 2,
#    'id': 2006451,
#    'country': 'US',
#    'sunrise': 1633006484,
#    'sunset': 1633049010},
#   'timezone': -21600,
#   'id': 5412347,
#   'name': 'Aurora',
#   'cod': 200},
#  {'coord': {'lon': -105.075, 'lat': 40.3978},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 53.83,
#    'feels_like': 51.75,
#    'temp_min': 48.78,
#    'temp_max': 60.91,
#    'pressure': 1027,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 211, 'gust': 7},
#   'clouds': {'all': 90},
#   'dt': 1633028937,
#   'sys': {'type': 2,
#    'id': 2041409,
#    'country': 'US',
#    'sunrise': 1633006554,
#    'sunset': 1633049057},
#   'timezone': -21600,
#   'id': 5579368,
#   'name': 'Loveland',
#   'cod': 200},
#  {'coord': {'lon': -73.5387, 'lat': 41.0534},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 63.7,
#    'feels_like': 62.44,
#    'temp_min': 60.31,
#    'temp_max': 67.44,
#    'pressure': 1019,
#    'humidity': 57},
#   'visibility': 10000,
#   'wind': {'speed': 8.01, 'deg': 269, 'gust': 17},
#   'clouds': {'all': 75},
#   'dt': 1633028946,
#   'sys': {'type': 2,
#    'id': 2020132,
#    'country': 'US',
#    'sunrise': 1632998992,
#    'sunset': 1633041485},
#   'timezone': -14400,
#   'id': 4843564,
#   'name': 'Stamford',
#   'cod': 200},
#  {'coord': {'lon': -118.0817, 'lat': 33.9022},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 84.97,
#    'feels_like': 82.94,
#    'temp_min': 72.3,
#    'temp_max': 94.33,
#    'pressure': 1014,
#    'humidity': 31},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 274, 'gust': 7},
#   'clouds': {'all': 1},
#   'dt': 1633028701,
#   'sys': {'type': 2,
#    'id': 2010205,
#    'country': 'US',
#    'sunrise': 1633009571,
#    'sunset': 1633052282},
#   'timezone': -25200,
#   'id': 5377995,
#   'name': 'Norwalk',
#   'cod': 200},
#  {'coord': {'lon': -77.9447, 'lat': 34.2257},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 78.19,
#    'feels_like': 78.67,
#    'temp_min': 75.85,
#    'temp_max': 81.97,
#    'pressure': 1019,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 120},
#   'clouds': {'all': 20},
#   'dt': 1633028995,
#   'sys': {'type': 1,
#    'id': 4521,
#    'country': 'US',
#    'sunrise': 1632999938,
#    'sunset': 1633042654},
#   'timezone': -14400,
#   'id': 4499379,
#   'name': 'Wilmington',
#   'cod': 200},
#  {'coord': {'lon': -81.6556, 'lat': 30.3322},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 85.91,
#    'feels_like': 89.56,
#    'temp_min': 82.38,
#    'temp_max': 89.11,
#    'pressure': 1017,
#    'humidity': 56},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 68, 'gust': 5.01},
#   'clouds': {'all': 75},
#   'dt': 1633028944,
#   'sys': {'type': 2,
#    'id': 2030923,
#    'country': 'US',
#    'sunrise': 1633000772,
#    'sunset': 1633043601},
#   'timezone': -14400,
#   'id': 4160021,
#   'name': 'Jacksonville',
#   'cod': 200},
#  {'coord': {'lon': -80.1937, 'lat': 25.7743},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 86.92,
#    'feels_like': 95.47,
#    'temp_min': 84,
#    'temp_max': 90.01,
#    'pressure': 1015,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 128, 'gust': 5.01},
#   'clouds': {'all': 75},
#   'dt': 1633028725,
#   'sys': {'type': 2,
#    'id': 2009435,
#    'country': 'US',
#    'sunrise': 1633000357,
#    'sunset': 1633043313},
#   'timezone': -14400,
#   'id': 4164138,
#   'name': 'Miami',
#   'cod': 200},
#  {'coord': {'lon': -82.4584, 'lat': 27.9475},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 88.95,
#    'feels_like': 91.53,
#    'temp_min': 85.95,
#    'temp_max': 91.42,
#    'pressure': 1016,
#    'humidity': 47},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 69, 'gust': 7},
#   'clouds': {'all': 90},
#   'dt': 1633028946,
#   'sys': {'type': 2,
#    'id': 2005199,
#    'country': 'US',
#    'sunrise': 1633000931,
#    'sunset': 1633043827},
#   'timezone': -14400,
#   'id': 4174757,
#   'name': 'Tampa',
#   'cod': 200},
#  {'coord': {'lon': -81.3792, 'lat': 28.5383},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 86.99,
#    'feels_like': 90.41,
#    'temp_min': 83.7,
#    'temp_max': 90.1,
#    'pressure': 1016,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 100},
#   'clouds': {'all': 40},
#   'dt': 1633028709,
#   'sys': {'type': 1,
#    'id': 5234,
#    'country': 'US',
#    'sunrise': 1633000680,
#    'sunset': 1633043560},
#   'timezone': -14400,
#   'id': 4167147,
#   'name': 'Orlando',
#   'cod': 200},
#  {'coord': {'lon': -118.3267, 'lat': 34.0983},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 84.33,
#    'feels_like': 83.01,
#    'temp_min': 73.85,
#    'temp_max': 93.36,
#    'pressure': 1014,
#    'humidity': 36},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 278, 'gust': 8.99},
#   'clouds': {'all': 1},
#   'dt': 1633028996,
#   'sys': {'type': 2,
#    'id': 2034962,
#    'country': 'US',
#    'sunrise': 1633009633,
#    'sunset': 1633052338},
#   'timezone': -25200,
#   'id': 5357527,
#   'name': 'Hollywood',
#   'cod': 200},
#  {'coord': {'lon': -95.2353, 'lat': 38.9717},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 81.46,
#    'feels_like': 84.52,
#    'temp_min': 77.99,
#    'temp_max': 85.68,
#    'pressure': 1016,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 6.91, 'deg': 230},
#   'clouds': {'all': 40},
#   'dt': 1633028996,
#   'sys': {'type': 1,
#    'id': 4784,
#    'country': 'US',
#    'sunrise': 1633004167,
#    'sunset': 1633046723},
#   'timezone': -18000,
#   'id': 4274277,
#   'name': 'Lawrence',
#   'cod': 200},
#  {'coord': {'lon': -83.6875, 'lat': 43.0125},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 71.47,
#    'feels_like': 70.66,
#    'temp_min': 67.73,
#    'temp_max': 73.96,
#    'pressure': 1023,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1633028775,
#   'sys': {'type': 2,
#    'id': 267346,
#    'country': 'US',
#    'sunrise': 1633001465,
#    'sunset': 1633043882},
#   'timezone': -14400,
#   'id': 4992982,
#   'name': 'Flint',
#   'cod': 200},
#  {'coord': {'lon': -83.1499, 'lat': 42.6056},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 70.72,
#    'feels_like': 69.84,
#    'temp_min': 67.44,
#    'temp_max': 74.17,
#    'pressure': 1023,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 319, 'gust': 5.01},
#   'clouds': {'all': 1},
#   'dt': 1633028722,
#   'sys': {'type': 2,
#    'id': 2005451,
#    'country': 'US',
#    'sunrise': 1633001329,
#    'sunset': 1633043761},
#   'timezone': -14400,
#   'id': 5012639,
#   'name': 'Troy',
#   'cod': 200},
#  {'coord': {'lon': -107.5009, 'lat': 43.0002},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 48.06,
#    'feels_like': 48.06,
#    'temp_min': 48.06,
#    'temp_max': 50.83,
#    'pressure': 1023,
#    'humidity': 40,
#    'sea_level': 1023,
#    'grnd_level': 819},
#   'visibility': 10000,
#   'wind': {'speed': 0.58, 'deg': 322, 'gust': 1.83},
#   'clouds': {'all': 100},
#   'dt': 1633028997,
#   'sys': {'type': 2,
#    'id': 2019293,
#    'country': 'US',
#    'sunrise': 1633007185,
#    'sunset': 1633049590},
#   'timezone': -21600,
#   'id': 5843591,
#   'name': 'State of Wyoming',
#   'cod': 200},
#  {'coord': {'lon': -92.1066, 'lat': 46.7833},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 70.05,
#    'feels_like': 70.05,
#    'temp_min': 63.28,
#    'temp_max': 86.59,
#    'pressure': 1021,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 62, 'gust': 7},
#   'clouds': {'all': 1},
#   'dt': 1633028998,
#   'sys': {'type': 2,
#    'id': 2005285,
#    'country': 'US',
#    'sunrise': 1633003563,
#    'sunset': 1633045825},
#   'timezone': -18000,
#   'id': 5024719,
#   'name': 'Duluth',
#   'cod': 200},
#  {'coord': {'lon': -70.8328, 'lat': 41.8334},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 60.58,
#    'feels_like': 59.25,
#    'temp_min': 57.16,
#    'temp_max': 63.68,
#    'pressure': 1017,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 9.22, 'deg': 10},
#   'clouds': {'all': 90},
#   'dt': 1633028998,
#   'sys': {'type': 2,
#    'id': 2002008,
#    'country': 'US',
#    'sunrise': 1632998356,
#    'sunset': 1633040822},
#   'timezone': -14400,
#   'id': 4947607,
#   'name': 'Plymouth',
#   'cod': 200},
#  {'coord': {'lon': -95.9378, 'lat': 41.2586},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 81.34,
#    'feels_like': 84.69,
#    'temp_min': 78.26,
#    'temp_max': 84.16,
#    'pressure': 1015,
#    'humidity': 67},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 161, 'gust': 10},
#   'clouds': {'all': 75},
#   'dt': 1633028706,
#   'sys': {'type': 2,
#    'id': 2003015,
#    'country': 'US',
#    'sunrise': 1633004375,
#    'sunset': 1633046851},
#   'timezone': -18000,
#   'id': 5074472,
#   'name': 'Omaha',
#   'cod': 200},
#  {'coord': {'lon': -114.9819, 'lat': 36.0397},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.39,
#    'feels_like': 76.62,
#    'temp_min': 76.12,
#    'temp_max': 81.12,
#    'pressure': 1019,
#    'humidity': 15},
#   'visibility': 10000,
#   'wind': {'speed': 14.97, 'deg': 10, 'gust': 24.16},
#   'clouds': {'all': 1},
#   'dt': 1633028700,
#   'sys': {'type': 2,
#    'id': 38662,
#    'country': 'US',
#    'sunrise': 1633008860,
#    'sunset': 1633051505},
#   'timezone': -25200,
#   'id': 5505411,
#   'name': 'Henderson',
#   'cod': 200},
#  {'coord': {'lon': -71.4676, 'lat': 42.7654},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 58.1,
#    'feels_like': 56.77,
#    'temp_min': 55.42,
#    'temp_max': 61.02,
#    'pressure': 1016,
#    'humidity': 67},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 284, 'gust': 4},
#   'clouds': {'all': 90},
#   'dt': 1633028999,
#   'sys': {'type': 2,
#    'id': 2023708,
#    'country': 'US',
#    'sunrise': 1632998526,
#    'sunset': 1633040958},
#   'timezone': -14400,
#   'id': 5090046,
#   'name': 'Nashua',
#   'cod': 200},
#  {'coord': {'lon': -74.1638, 'lat': 40.8584},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 64.99,
#    'feels_like': 63.59,
#    'temp_min': 61.21,
#    'temp_max': 67.95,
#    'pressure': 1018,
#    'humidity': 51},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 37, 'gust': 5.99},
#   'clouds': {'all': 75},
#   'dt': 1633028711,
#   'sys': {'type': 2,
#    'id': 2009441,
#    'country': 'US',
#    'sunrise': 1632999139,
# ...
#   'wind': {'speed': 1.01, 'deg': 270, 'gust': 3},
#   'clouds': {'all': 1},
#   'dt': 1633028849,
#   'sys': {'type': 2,
#    'id': 2010997,
#    'country': 'US',
#    'sunrise': 1633010420,
#    'sunset': 1633052972},
#   'timezone': -25200,
#   'id': 5388881,
#   'name': 'Roseville',
#   'cod': 200},
#  {'coord': {'lon': -119.2921, 'lat': 36.3302},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 79.79,
#    'feels_like': 79.79,
#    'temp_min': 73.35,
#    'temp_max': 86.18,
#    'pressure': 1017,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 200},
#   'clouds': {'all': 1},
#   'dt': 1633029030,
#   'sys': {'type': 1,
#    'id': 6173,
#    'country': 'US',
#    'sunrise': 1633009900,
#    'sunset': 1633052534},
#   'timezone': -25200,
#   'id': 5406567,
#   'name': 'Visalia',
#   'cod': 200},
#  {'coord': {'lon': -122.0363, 'lat': 37.3688},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 79.5,
#    'feels_like': 79.5,
#    'temp_min': 70.63,
#    'temp_max': 86.65,
#    'pressure': 1016,
#    'humidity': 28},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 328, 'gust': 5.99},
#   'clouds': {'all': 1},
#   'dt': 1633028739,
#   'sys': {'type': 2,
#    'id': 2038854,
#    'country': 'US',
#    'sunrise': 1633010576,
#    'sunset': 1633053175},
#   'timezone': -25200,
#   'id': 5400075,
#   'name': 'Sunnyvale',
#   'cod': 200},
#  {'coord': {'lon': -117.0864, 'lat': 33.1192},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 80.47,
#    'feels_like': 80.64,
#    'temp_min': 65.52,
#    'temp_max': 93.24,
#    'pressure': 1011,
#    'humidity': 44},
#   'visibility': 10000,
#   'wind': {'speed': 7, 'deg': 235},
#   'clouds': {'all': 1},
#   'dt': 1633029037,
#   'sys': {'type': 2,
#    'id': 2005618,
#    'country': 'US',
#    'sunrise': 1633009320,
#    'sunset': 1633052055},
#   'timezone': -25200,
#   'id': 5346827,
#   'name': 'Escondido',
#   'cod': 200},
#  {'coord': {'lon': -122.0808, 'lat': 37.6688},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.24,
#    'feels_like': 77.22,
#    'temp_min': 70.61,
#    'temp_max': 86.04,
#    'pressure': 1016,
#    'humidity': 31},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 265, 'gust': 5.99},
#   'clouds': {'all': 1},
#   'dt': 1633029037,
#   'sys': {'type': 2,
#    'id': 2002977,
#    'country': 'US',
#    'sunrise': 1633010592,
#    'sunset': 1633053180},
#   'timezone': -25200,
#   'id': 5355933,
#   'name': 'Hayward',
#   'cod': 200},
#  {'coord': {'lon': -118.3406, 'lat': 33.8359},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 81.36,
#    'feels_like': 82.49,
#    'temp_min': 73.17,
#    'temp_max': 94.01,
#    'pressure': 1014,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 220, 'gust': 5.99},
#   'clouds': {'all': 1},
#   'dt': 1633029038,
#   'sys': {'type': 2,
#    'id': 2032800,
#    'country': 'US',
#    'sunrise': 1633009632,
#    'sunset': 1633052345},
#   'timezone': -25200,
#   'id': 5403022,
#   'name': 'Torrance',
#   'cod': 200},
#  {'coord': {'lon': -117.7523, 'lat': 34.0553},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 86.65,
#    'feels_like': 83.16,
#    'temp_min': 71.22,
#    'temp_max': 91.65,
#    'pressure': 1015,
#    'humidity': 12},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 260},
#   'clouds': {'all': 1},
#   'dt': 1633028772,
#   'sys': {'type': 1,
#    'id': 5376,
#    'country': 'US',
#    'sunrise': 1633009494,
#    'sunset': 1633052201},
#   'timezone': -25200,
#   'id': 5384170,
#   'name': 'Pomona',
#   'cod': 200},
#  {'coord': {'lon': -121.6555, 'lat': 36.6777},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.12,
#    'feels_like': 77.41,
#    'temp_min': 69.24,
#    'temp_max': 86,
#    'pressure': 1016,
#    'humidity': 38},
#   'visibility': 10000,
#   'wind': {'speed': 6.91, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1633029038,
#   'sys': {'type': 1,
#    'id': 5885,
#    'country': 'US',
#    'sunrise': 1633010473,
#    'sunset': 1633053095},
#   'timezone': -25200,
#   'id': 5391295,
#   'name': 'Salinas',
#   'cod': 200},
#  {'coord': {'lon': -117.5664, 'lat': 33.8753},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 87.84,
#    'feels_like': 84.16,
#    'temp_min': 75.25,
#    'temp_max': 93.09,
#    'pressure': 1014,
#    'humidity': 9},
#   'visibility': 10000,
#   'wind': {'speed': 16.11, 'deg': 30, 'gust': 24.16},
#   'clouds': {'all': 1},
#   'dt': 1633028740,
#   'sys': {'type': 1,
#    'id': 3262,
#    'country': 'US',
#    'sunrise': 1633009447,
#    'sunset': 1633052159},
#   'timezone': -25200,
#   'id': 5339631,
#   'name': 'Corona',
#   'cod': 200},
#  {'coord': {'lon': -112.186, 'lat': 33.5387},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.05,
#    'feels_like': 83.26,
#    'temp_min': 81.88,
#    'temp_max': 87.96,
#    'pressure': 1008,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 297, 'gust': 5.99},
#   'clouds': {'all': 1},
#   'dt': 1633028958,
#   'sys': {'type': 2,
#    'id': 2033143,
#    'country': 'US',
#    'sunrise': 1633008149,
#    'sunset': 1633050874},
#   'timezone': -25200,
#   'id': 5295985,
#   'name': 'Glendale',
#   'cod': 200},
#  {'coord': {'lon': -117.8231, 'lat': 33.6695},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.42,
#    'feels_like': 85.39,
#    'temp_min': 72.45,
#    'temp_max': 95.34,
#    'pressure': 1013,
#    'humidity': 43},
#   'visibility': 10000,
#   'wind': {'speed': 9.22, 'deg': 220},
#   'clouds': {'all': 1},
#   'dt': 1633029040,
#   'sys': {'type': 2,
#    'id': 2009264,
#    'country': 'US',
#    'sunrise': 1633009505,
#    'sunset': 1633052224},
#   'timezone': -25200,
#   'id': 5359777,
#   'name': 'Irvine',
#   'cod': 200},
#  {'coord': {'lon': -117.3795, 'lat': 33.1959},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 80.24,
#    'feels_like': 82.33,
#    'temp_min': 67.55,
#    'temp_max': 95.29,
#    'pressure': 1013,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 290, 'gust': 8.99},
#   'clouds': {'all': 1},
#   'dt': 1633029041,
#   'sys': {'type': 2,
#    'id': 2009310,
#    'country': 'US',
#    'sunrise': 1633009391,
#    'sunset': 1633052125},
#   'timezone': -25200,
#   'id': 5378771,
#   'name': 'Oceanside',
#   'cod': 200},
#  {'coord': {'lon': -117.4351, 'lat': 34.0922},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.77,
#    'feels_like': 82.47,
#    'temp_min': 75.74,
#    'temp_max': 90.88,
#    'pressure': 1013,
#    'humidity': 11},
#   'visibility': 10000,
#   'wind': {'speed': 8.99, 'deg': 354, 'gust': 23},
#   'clouds': {'all': 1},
#   'dt': 1633029041,
#   'sys': {'type': 2,
#    'id': 2002705,
#    'country': 'US',
#    'sunrise': 1633009418,
#    'sunset': 1633052124},
#   'timezone': -25200,
#   'id': 5349755,
#   'name': 'Fontana',
#   'cod': 200},
#  {'coord': {'lon': -119.177, 'lat': 34.1975},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 90.82,
#    'feels_like': 86.61,
#    'temp_min': 78.67,
#    'temp_max': 95.65,
#    'pressure': 1014,
#    'humidity': 9},
#   'visibility': 10000,
#   'wind': {'speed': 13.8, 'deg': 70},
#   'clouds': {'all': 1},
#   'dt': 1633028860,
#   'sys': {'type': 1,
#    'id': 5254,
#    'country': 'US',
#    'sunrise': 1633009838,
#    'sunset': 1633052540},
#   'timezone': -25200,
#   'id': 5380184,
#   'name': 'Oxnard',
#   'cod': 200},
#  {'coord': {'lon': -120.9969, 'lat': 37.6391},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 77.18,
#    'feels_like': 76.06,
#    'temp_min': 74.71,
#    'temp_max': 84.13,
#    'pressure': 1017,
#    'humidity': 31},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1633029042,
#   'sys': {'type': 1,
#    'id': 4949,
#    'country': 'US',
#    'sunrise': 1633010331,
#    'sunset': 1633052921},
#   'timezone': -25200,
#   'id': 5373900,
#   'name': 'Modesto',
#   'cod': 200},
#  {'coord': {'lon': -121.9886, 'lat': 37.5483},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 78.91,
#    'feels_like': 78.91,
#    'temp_min': 71.42,
#    'temp_max': 86.29,
#    'pressure': 1015,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 223, 'gust': 7},
#   'clouds': {'all': 1},
#   'dt': 1633028993,
#   'sys': {'type': 2,
#    'id': 2036492,
#    'country': 'US',
#    'sunrise': 1633010567,
#    'sunset': 1633053160},
#   'timezone': -25200,
#   'id': 5350734,
#   'name': 'Fremont',
#   'cod': 200},
#  {'coord': {'lon': -117.9145, 'lat': 33.8353},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 86.41,
#    'feels_like': 84.15,
#    'temp_min': 72.16,
#    'temp_max': 94.1,
#    'pressure': 1013,
#    'humidity': 30},
#   'visibility': 10000,
#   'wind': {'speed': 5.99, 'deg': 219, 'gust': 11.01},
#   'clouds': {'all': 1},
#   'dt': 1633029042,
#   'sys': {'type': 2,
#    'id': 2001654,
#    'country': 'US',
#    'sunrise': 1633009530,
#    'sunset': 1633052243},
#   'timezone': -25200,
#   'id': 5323810,
#   'name': 'Anaheim',
#   'cod': 200},
#  {'coord': {'lon': -83.3999, 'lat': 42.6667},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 70.25,
#    'feels_like': 69.33,
#    'temp_min': 66.56,
#    'temp_max': 73.98,
#    'pressure': 1023,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1633028966,
#   'sys': {'type': 1,
#    'id': 5424,
#    'country': 'US',
#    'sunrise': 1633001390,
#    'sunset': 1633043820},
#   'timezone': -14400,
#   'id': 5004223,
#   'name': 'Oakland',
#   'cod': 200},
#  {'coord': {'lon': -119.8343, 'lat': 36.6666},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 78.71,
#    'feels_like': 78.71,
#    'temp_min': 75.07,
#    'temp_max': 84,
#    'pressure': 1017,
#    'humidity': 30},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 290},
#   'clouds': {'all': 1},
#   'dt': 1633029043,
#   'sys': {'type': 2,
#    'id': 2019405,
#    'country': 'US',
#    'sunrise': 1633010036,
#    'sunset': 1633052658},
#   'timezone': -25200,
#   'id': 5350964,
#   'name': 'Fresno',
#   'cod': 200},
#  {'coord': {'lon': -94.1288, 'lat': 36.1867},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 81.81,
#    'feels_like': 84.51,
#    'temp_min': 77.32,
#    'temp_max': 85.48,
#    'pressure': 1016,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 5.99, 'deg': 120},
#   'clouds': {'all': 40},
#   'dt': 1633028878,
#   'sys': {'type': 2,
#    'id': 47685,
#    'country': 'US',
#    'sunrise': 1633003855,
#    'sunset': 1633046503},
#   'timezone': -18000,
#   'id': 4132093,
#   'name': 'Springdale',
#   'cod': 200},
#  {'coord': {'lon': -112.3496, 'lat': 33.4356},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 85.57,
#    'feels_like': 83.48,
#    'temp_min': 82.51,
#    'temp_max': 88.61,
#    'pressure': 1014,
#    'humidity': 31},
#   'visibility': 10000,
#   'wind': {'speed': 9.22, 'deg': 90},
#   'clouds': {'all': 20},
#   'dt': 1633029044,
#   'sys': {'type': 1,
#    'id': 4294,
#    'country': 'US',
#    'sunrise': 1633008187,
#    'sunset': 1633050915},
#   'timezone': -25200,
#   'id': 5552301,
#   'name': 'Avondale',
#   'cod': 200},
#  {'coord': {'lon': -114.6244, 'lat': 32.7253},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 89.49,
#    'feels_like': 85.53,
#    'temp_min': 88.23,
#    'temp_max': 91.89,
#    'pressure': 1012,
#    'humidity': 15},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 10, 'gust': 18.41},
#   'clouds': {'all': 1},
#   'dt': 1633029044,
#   'sys': {'type': 1,
#    'id': 5136,
#    'country': 'US',
#    'sunrise': 1633008723,
#    'sunset': 1633051471},
#   'timezone': -25200,
#   'id': 5322053,
#   'name': 'Yuma',
#   'cod': 200},
#  {'coord': {'lon': -112.3332, 'lat': 33.6306},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.05,
#    'feels_like': 83.26,
#    'temp_min': 81.79,
#    'temp_max': 88.05,
#    'pressure': 1009,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 153, 'gust': 7},
#   'clouds': {'all': 1},
#   'dt': 1633028900,
#   'sys': {'type': 2,
#    'id': 2011266,
#    'country': 'US',
#    'sunrise': 1633008186,
#    'sunset': 1633050908},
#   'timezone': -25200,
#   'id': 5316428,
#   'name': 'Surprise',
#   'cod': 200},
#  {'coord': {'lon': -111.9093, 'lat': 33.4148},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 84.74,
#    'feels_like': 82.99,
#    'temp_min': 81.57,
#    'temp_max': 87.85,
#    'pressure': 1012,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 3, 'deg': 51, 'gust': 7},
#   'clouds': {'all': 20},
#   'dt': 1633029008,
#   'sys': {'type': 2,
#    'id': 2040762,
#    'country': 'US',
#    'sunrise': 1633008081,
#    'sunset': 1633050810},
#   'timezone': -25200,
#   'id': 5317058,
#   'name': 'Tempe',
#   'cod': 200},
#  {'coord': {'lon': -111.789, 'lat': 33.3528},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 84.45,
#    'feels_like': 82.72,
#    'temp_min': 80.94,
#    'temp_max': 87.84,
#    'pressure': 1012,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 1.01, 'deg': 68, 'gust': 5.99},
#   'clouds': {'all': 20},
#   'dt': 1633028926,
#   'sys': {'type': 2,
#    'id': 2005405,
#    'country': 'US',
#    'sunrise': 1633008051,
#    'sunset': 1633050782},
#   'timezone': -25200,
#   'id': 5295903,
#   'name': 'Gilbert',
#   'cod': 200},
#  {'coord': {'lon': -82.3248, 'lat': 29.6516},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 86.31,
#    'feels_like': 89.58,
#    'temp_min': 84.04,
#    'temp_max': 89.31,
#    'pressure': 1018,
#    'humidity': 54},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 60},
#   'clouds': {'all': 20},
#   'dt': 1633028956,
#   'sys': {'type': 2,
#    'id': 2007294,
#    'country': 'US',
#    'sunrise': 1633000922,
#    'sunset': 1633043771},
#   'timezone': -14400,
#   'id': 4156404,
#   'name': 'Gainesville',
#   'cod': 200},
#  {'coord': {'lon': -80.2318, 'lat': 26.1342},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 86.81,
#    'feels_like': 94.78,
#    'temp_min': 82.98,
#    'temp_max': 90.01,
#    'pressure': 1015,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 5.01, 'deg': 71, 'gust': 11.01},
#   'clouds': {'all': 20},
#   'dt': 1633029046,
#   'sys': {'type': 2,
#    'id': 2040204,
#    'country': 'US',
#    'sunrise': 1633000371,
#    'sunset': 1633043318},
#   'timezone': -14400,
#   'id': 4168782,
#   'name': 'Plantation',
#   'cod': 200}]

# %%
#Check legth ofw weather data
len(weather_json)
# Out:
# 211

# %%
#Write out json to text file 
with open ('7_day_weather_data.txt', 'w') as convert_file:
    convert_file.write(json.dumps(weather_json))
